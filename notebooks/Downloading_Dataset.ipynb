# %%
# Install required packages
# !pip install biopython

# %% [markdown]
# # Acinetobacter baumannii

# %%
# Imports
import os
import csv
import time
import gzip
import shutil
from Bio import Entrez
from google.colab import drive

# Set your email (required by NCBI)
Entrez.email = "s-salma.hatem@zewailcity.edu.eg"  # <-- Change this to your email!

# File and folder paths
input_csv = "mbio.02852-24-s0002.csv"  # <-- Upload this file to Colab
output_dir = "/content/fasta_files"

# Google Drive mount point
drive_mount = "/content/drive/MyDrive/MRSA datasets/Datasets/Acinetobacter baumannii/PRJNA1014981"

# Mount Google Drive
drive.mount('/content/drive')

# Create directories
os.makedirs(output_dir, exist_ok=True)
os.makedirs(drive_mount, exist_ok=True)

# Read accession numbers from CSV
def get_sample_ids(csv_file):
    sample_ids = []
    with open(csv_file, 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip header if present
        for row in reader:
            sample_id = row[0].strip()
            if sample_id:
                sample_ids.append(sample_id)
    return sample_ids

# Search NCBI for assembly ID
def search_ncbi(sample_id):
    try:
        handle = Entrez.esearch(db="assembly", term=f"{sample_id}[Assembly Accession]", retmax=1)
        record = Entrez.read(handle)
        handle.close()
        return record["IdList"]
    except Exception as e:
        print(f"Error searching for {sample_id}: {e}")
        return []

# Get FTP link
def get_assembly_info(assembly_id):
    try:
        handle = Entrez.esummary(db="assembly", id=assembly_id, report="full")
        record = Entrez.read(handle)
        handle.close()
        return record["DocumentSummarySet"]["DocumentSummary"][0]
    except Exception as e:
        print(f"Error getting info for {assembly_id}: {e}")
        return None

# Download and unzip FASTA
def download_fna(ftp_path, sample_id):
    try:
        base = ftp_path.split('/')[-1]
        url = f"{ftp_path}/{base}_genomic.fna.gz"
        gz_path = os.path.join(output_dir, f"{sample_id}.fna.gz")
        fasta_path = os.path.join(output_dir, f"{sample_id}.fna")

        # Download
        os.system(f"wget -q -O {gz_path} {url}")

        # Decompress
        with gzip.open(gz_path, 'rb') as f_in:
            with open(fasta_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)

        os.remove(gz_path)
        print(f"✅ Downloaded and extracted: {sample_id}.fna")
        return fasta_path
    except Exception as e:
        print(f"❌ Error for {sample_id}: {e}")
        return None

# Copy to Google Drive
def upload_to_drive(local_file):
    try:
        filename = os.path.basename(local_file)
        dest_path = os.path.join(drive_mount, filename)

        # Check if file already exists on Google Drive
        if os.path.exists(dest_path):
            print(f"⏩ Skipped (already on Drive): {filename}")
            return

        shutil.copy(local_file, dest_path)
        print(f"📁 Uploaded to Drive: {filename}")
    except Exception as e:
        print(f"❌ Upload failed for {filename}: {e}")

# Main logic
def process_all():
    sample_ids = get_sample_ids(input_csv)
    print(f"🔍 Found {len(sample_ids)} accession IDs")

    for idx, sample_id in enumerate(sample_ids, 1):
        print(f"\n[{idx}/{len(sample_ids)}] Processing: {sample_id}")
        dest_filename = f"{sample_id}.fna"
        drive_path = os.path.join(drive_mount, dest_filename)

        # Skip if already on Drive
        if os.path.exists(drive_path):
            print(f"⏩ Skipped (already on Drive): {dest_filename}")
            continue

        assembly_ids = search_ncbi(sample_id)
        time.sleep(1)

        if not assembly_ids:
            print(f"❌ No assembly ID for {sample_id}")
            continue

        info = get_assembly_info(assembly_ids[0])
        time.sleep(1)

        ftp_path = info.get("FtpPath_RefSeq") or info.get("FtpPath_GenBank")
        if not ftp_path:
            print(f"❌ No FTP path for {sample_id}")
            continue

        fasta_file = download_fna(ftp_path, sample_id)
        if fasta_file:
            upload_to_drive(fasta_file)


# Run the process
process_all()

# %%
# Imports
import os
import csv
import time
import gzip
import shutil
import requests
from Bio import Entrez
from google.colab import drive

# Set your email (required by NCBI)
Entrez.email = "s-salma.hatem@zewailcity.edu.eg"  # <-- Change this to your email!

# File and folder paths
input_csv = "mbio.02852-24-s0002.csv"  # <-- Upload this file to Colab
output_dir = "/content/fasta_files"

# Google Drive mount point
drive_mount = "/content/drive/MyDrive/MRSA datasets/Datasets/Acinetobacter baumannii/PRJNA1014981"

# Mount Google Drive
drive.mount('/content/drive')

# Create directories
os.makedirs(output_dir, exist_ok=True)
os.makedirs(drive_mount, exist_ok=True)

# --- Utilities ---

def get_sample_ids(csv_file):
    sample_ids = []
    with open(csv_file, 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip header if present
        for row in reader:
            sample_id = row[0].strip()
            if sample_id:
                sample_ids.append(sample_id)
    return sample_ids

def search_ncbi(sample_id):
    try:
        handle = Entrez.esearch(db="assembly", term=f"{sample_id}[Assembly Accession]", retmax=1)
        record = Entrez.read(handle)
        handle.close()
        return record["IdList"]
    except Exception as e:
        print(f"Error searching for {sample_id}: {e}")
        return []

def get_assembly_info(assembly_id):
    try:
        handle = Entrez.esummary(db="assembly", id=assembly_id, report="full")
        record = Entrez.read(handle)
        handle.close()
        return record["DocumentSummarySet"]["DocumentSummary"][0]
    except Exception as e:
        print(f"Error getting info for {assembly_id}: {e}")
        return None

def download_fna(ftp_path, sample_id):
    try:
        base = ftp_path.split('/')[-1]
        url = f"{ftp_path}/{base}_genomic.fna.gz"
        gz_path = os.path.join(output_dir, f"{sample_id}.fna.gz")
        fasta_path = os.path.join(output_dir, f"{sample_id}.fna")

        # Download
        os.system(f"wget -q -O {gz_path} {url}")

        # Decompress
        with gzip.open(gz_path, 'rb') as f_in:
            with open(fasta_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)

        os.remove(gz_path)
        print(f"✅ Downloaded and extracted: {sample_id}.fna")
        return fasta_path
    except Exception as e:
        print(f"❌ Error for {sample_id}: {e}")
        return None

def upload_to_drive(local_file):
    try:
        filename = os.path.basename(local_file)
        dest_path = os.path.join(drive_mount, filename)
        shutil.copy(local_file, dest_path)
        print(f"📁 Uploaded to Drive: {filename}")
    except Exception as e:
        print(f"❌ Upload failed for {filename}: {e}")

def get_sample_accession_from_ena(sra_id):
    try:
        url = f"https://www.ebi.ac.uk/ena/portal/api/filereport?accession={sra_id}&result=read_run&fields=sample_accession&format=json"
        r = requests.get(url)
        data = r.json()
        if data and "sample_accession" in data[0]:
            return data[0]["sample_accession"]
        else:
            print(f"❌ No sample accession found for {sra_id} in ENA")
            return None
    except Exception as e:
        print(f"❌ ENA lookup error for {sra_id}: {e}")
        return None

def download_from_bvbrc(sample_accession, sample_id):
    try:
        # Step 1: Get genome_id via biosample lookup
        genome_url = f"https://www.bv-brc.org/api/genome/?eq(biosample_accession,{sample_accession})&select(genome_id,genome_name)&http_accept=application/json"
        genome_response = requests.get(genome_url)

        if genome_response.status_code != 200:
            print(f"❌ BV-BRC API error ({genome_response.status_code}) for {sample_accession}")
            return None

        try:
            genome_data = genome_response.json()
        except ValueError:
            print(f"❌ Failed to parse genome JSON for {sample_accession}")
            return None

        if not genome_data:
            print(f"❌ No genome found for BioSample {sample_accession}")
            return None

        genome_id = genome_data[0]["genome_id"]
        genome_name = genome_data[0]["genome_name"]
        print(f"🔗 Found Genome: {genome_id} - {genome_name}")

        # Step 2: Query genome_sequence for actual file paths
        seq_url = f"https://www.bv-brc.org/api/genome_sequence/?eq(genome_id,{genome_id})&http_accept=application/json"
        seq_response = requests.get(seq_url)

        if seq_response.status_code != 200:
            print(f"❌ Failed to query genome_sequence API for {genome_id}")
            return None

        try:
            seq_data = seq_response.json()
        except ValueError:
            print(f"❌ Failed to parse sequence JSON for {genome_id}")
            return None

        # Step 3: Pick the best sequence file
        fasta_url = None
        for seq in seq_data:
            accession = seq.get("accession")
            if accession and any(ext in accession.lower() for ext in ['.fna', '.fa', '.fasta']):
                # BV-BRC file structure
                fasta_url = f"https://www.bv-brc.org/downloads/{genome_id}/{accession}"
                break

        if not fasta_url:
            print(f"❌ No usable FASTA file found for genome {genome_id}")
            return None

        # Step 4: Download the file
        dest_path = os.path.join(output_dir, f"{sample_id}.fna")

        r = requests.get(fasta_url, stream=True)
        if r.status_code != 200:
            print(f"❌ File not found at {fasta_url}")
            return None

        if fasta_url.endswith(".gz"):
            # If gzipped, decompress
            temp_path = dest_path + ".gz"
            with open(temp_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
            with gzip.open(temp_path, 'rb') as f_in, open(dest_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
            os.remove(temp_path)
        else:
            with open(dest_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)

        print(f"✅ Downloaded dynamic FASTA from BV-BRC for {sample_id}")
        return dest_path

    except Exception as e:
        print(f"❌ Error downloading from BV-BRC for {sample_accession}: {e}")
        return None




# --- Main Process ---

def process_all():
    sample_ids = get_sample_ids(input_csv)
    print(f"🔍 Found {len(sample_ids)} accession IDs")

    for idx, sample_id in enumerate(sample_ids, 1):
        print(f"\n[{idx}/{len(sample_ids)}] Processing: {sample_id}")
        dest_filename = f"{sample_id}.fna"
        drive_path = os.path.join(drive_mount, dest_filename)

        # Skip if already on Drive
        if os.path.exists(drive_path):
            print(f"⏩ Skipped (already on Drive): {dest_filename}")
            continue

        # --- Handle SRA accessions ---
        if sample_id.startswith(("SRR", "ERR", "DRR")):
            sample_accession = get_sample_accession_from_ena(sample_id)
            if not sample_accession:
                continue
            fasta_file = download_from_bvbrc(sample_accession, sample_id)
            if fasta_file:
                upload_to_drive(fasta_file)
            continue  # move to next sample

        # --- Handle Assembly accessions ---
        assembly_ids = search_ncbi(sample_id)
        time.sleep(1)

        if not assembly_ids:
            print(f"❌ No assembly ID for {sample_id}")
            continue

        info = get_assembly_info(assembly_ids[0])
        time.sleep(1)

        ftp_path = info.get("FtpPath_RefSeq") or info.get("FtpPath_GenBank")
        if not ftp_path:
            print(f"❌ No FTP path for {sample_id}")
            continue

        fasta_file = download_fna(ftp_path, sample_id)
        if fasta_file:
            upload_to_drive(fasta_file)

# Run the process
process_all()

# %% [markdown]
# # Salmonella enterica

# %%
# !pip install biopython requests

import os
import csv
import time
import gzip
import shutil
import requests
import pandas as pd
from Bio import Entrez
from google.colab import drive

# 🔧 Configuration
Entrez.email = "s-salma.hatem@zewailcity.edu.eg"  # 🔁 CHANGE THIS
csv_file = "PRJNA292666_PRJNA292661_labels.xlsx"
output_dir = "/content/fasta_files"
drive_dir = "/content/drive/MyDrive/MRSA datasets/Datasets/Salmonella enterica/PRJNA292666 & PRJNA292661"

# 📂 Mount Google Drive
drive.mount('/content/drive')
os.makedirs(output_dir, exist_ok=True)
os.makedirs(drive_dir, exist_ok=True)

# 🧾 Read SRR IDs from CSV
def get_sra_ids(excel_file):
    df = pd.read_excel(excel_file)

    if "SRA Run Accession" not in df.columns:
        raise ValueError("Column 'SRA Run Accession' not found in Excel file.")

    sra_ids = df["SRA Run Accession"].dropna().astype(str).unique().tolist()
    return sra_ids

# 🔗 Step 1: SRR ➝ ENA ➝ Sample Accession (ERSxxx)
def get_sample_accession_from_ena(sra_id):
    try:
        url = f"https://www.ebi.ac.uk/ena/portal/api/filereport?accession={sra_id}&result=read_run&fields=sample_accession&format=json"
        r = requests.get(url)
        data = r.json()
        if data and "sample_accession" in data[0]:
            return data[0]["sample_accession"]
        else:
            print(f"❌ No sample accession found for {sra_id} in ENA")
            return None
    except Exception as e:
        print(f"❌ ENA lookup error for {sra_id}: {e}")
        return None

# 🔗 Step 2: Sample Accession ➝ Assembly ➝ FTP path
def get_assembly_ftp_from_ncbi(sample_accession):
    try:
        # Search assembly DB with sample accession
        handle = Entrez.esearch(db="assembly", term=f"{sample_accession}[Sample]", retmax=1)
        result = Entrez.read(handle)
        if not result["IdList"]:
            print(f"❌ No assembly found for {sample_accession}")
            return None

        assembly_id = result["IdList"][0]
        handle = Entrez.esummary(db="assembly", id=assembly_id, report="full")
        summary = Entrez.read(handle)
        doc = summary["DocumentSummarySet"]["DocumentSummary"][0]

        # Prefer RefSeq path
        ftp_path = doc["FtpPath_RefSeq"] or doc["FtpPath_GenBank"]
        return ftp_path
    except Exception as e:
        print(f"❌ Error getting FTP path for {sample_accession}: {e}")
        return None

# ⬇️ Step 3: Download and extract .fna.gz
def download_fna_file(ftp_path, sra_id):
    try:
        base = ftp_path.split("/")[-1]
        url = f"{ftp_path}/{base}_genomic.fna.gz"
        gz_path = os.path.join(output_dir, f"{sra_id}.fna.gz")
        out_path = os.path.join(output_dir, f"{sra_id}.fna")

        os.system(f"wget -q -O {gz_path} {url}")

        # ✅ Validate if it's a real gzip file
        with open(gz_path, 'rb') as test_f:
            magic = test_f.read(2)
            if magic != b'\x1f\x8b':
                raise ValueError("Not a valid gzip file — probably a 404 page.")

        # If it passed, proceed to decompress
        with gzip.open(gz_path, 'rb') as f_in, open(out_path, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
        os.remove(gz_path)
        print(f"✅ Downloaded and extracted {sra_id}.fna")
        return out_path

    except Exception as e:
        print(f"❌ Download error for {sra_id}: {e}")
        if os.path.exists(gz_path):
            os.remove(gz_path)
        return None


# ☁️ Step 4: Upload to Google Drive
def upload_to_drive(filepath):
    try:
        dest = os.path.join(drive_dir, os.path.basename(filepath))
        shutil.copy(filepath, dest)
        print(f"☁️ Uploaded to Drive: {os.path.basename(filepath)}")
    except Exception as e:
        print(f"❌ Drive upload error: {e}")

# ▶️ Main pipeline
# ▶️ Main pipeline with skip-if-exists check
def process_sra_ids():
    sra_ids = get_sra_ids(csv_file)
    print(f"🔍 Found {len(sra_ids)} SRA IDs")

    for idx, sra_id in enumerate(sra_ids, 1):
        print(f"\n[{idx}/{len(sra_ids)}] Processing {sra_id}...")

        drive_file_path = os.path.join(drive_dir, f"{sra_id}.fna")
        if os.path.exists(drive_file_path):
            print(f"⏭️  Skipping {sra_id} — already exists in Drive.")
            continue

        sample_accession = get_sample_accession_from_ena(sra_id)
        if not sample_accession:
            continue

        ftp_path = get_assembly_ftp_from_ncbi(sample_accession)
        if not ftp_path:
            continue

        fna_file = download_fna_file(ftp_path, sra_id)
        if fna_file:
            upload_to_drive(fna_file)


process_sra_ids()
# Out:
# Streaming output truncated to the last 5000 lines.
# ☁️ Uploaded to Drive: SRR1982114.fna
#
# [4004/5278] Processing SRR1773838...
# ✅ Downloaded and extracted SRR1773838.fna
# ☁️ Uploaded to Drive: SRR1773838.fna
#
# [4005/5278] Processing SRR3295918...
# ✅ Downloaded and extracted SRR3295918.fna
# ☁️ Uploaded to Drive: SRR3295918.fna
#
# [4006/5278] Processing SRR3115182...
# ✅ Downloaded and extracted SRR3115182.fna
# ☁️ Uploaded to Drive: SRR3115182.fna
#
# [4007/5278] Processing SRR1573573...
# ✅ Downloaded and extracted SRR1573573.fna
# ☁️ Uploaded to Drive: SRR1573573.fna
#
# [4008/5278] Processing SRR3198632...
# ✅ Downloaded and extracted SRR3198632.fna
# ☁️ Uploaded to Drive: SRR3198632.fna
#
# [4009/5278] Processing SRR2407619...
# ✅ Downloaded and extracted SRR2407619.fna
# ☁️ Uploaded to Drive: SRR2407619.fna
#
# [4010/5278] Processing SRR3295589...
# ✅ Downloaded and extracted SRR3295589.fna
# ☁️ Uploaded to Drive: SRR3295589.fna
#
# [4011/5278] Processing SRR2542458...
# ❌ No sample accession found for SRR2542458 in ENA
#
# [4012/5278] Processing SRR3295919...
# ✅ Downloaded and extracted SRR3295919.fna
# ☁️ Uploaded to Drive: SRR3295919.fna
#
# [4013/5278] Processing SRR2567152...
# ✅ Downloaded and extracted SRR2567152.fna
# ☁️ Uploaded to Drive: SRR2567152.fna
#
# [4014/5278] Processing SRR3740194...
# ✅ Downloaded and extracted SRR3740194.fna
# ☁️ Uploaded to Drive: SRR3740194.fna
#
# [4015/5278] Processing SRR3665030...
# ✅ Downloaded and extracted SRR3665030.fna
# ☁️ Uploaded to Drive: SRR3665030.fna
#
# [4016/5278] Processing SRR3199871...
# ❌ No sample accession found for SRR3199871 in ENA
#
# [4017/5278] Processing SRR1299315...
# ✅ Downloaded and extracted SRR1299315.fna
# ☁️ Uploaded to Drive: SRR1299315.fna
#
# [4018/5278] Processing SRR2407620...
# ✅ Downloaded and extracted SRR2407620.fna
# ☁️ Uploaded to Drive: SRR2407620.fna
#
# [4019/5278] Processing SRR3295590...
# ✅ Downloaded and extracted SRR3295590.fna
# ☁️ Uploaded to Drive: SRR3295590.fna
#
# [4020/5278] Processing SRR4280623...
# ✅ Downloaded and extracted SRR4280623.fna
# ☁️ Uploaded to Drive: SRR4280623.fna
#
# [4021/5278] Processing SRR1982132...
# ✅ Downloaded and extracted SRR1982132.fna
# ☁️ Uploaded to Drive: SRR1982132.fna
#
# [4022/5278] Processing SRR2918184...
# ✅ Downloaded and extracted SRR2918184.fna
# ☁️ Uploaded to Drive: SRR2918184.fna
#
# [4023/5278] Processing SRR3115183...
# ✅ Downloaded and extracted SRR3115183.fna
# ☁️ Uploaded to Drive: SRR3115183.fna
#
# [4024/5278] Processing SRR3199872...
# ❌ No sample accession found for SRR3199872 in ENA
#
# [4025/5278] Processing SRR1573574...
# ✅ Downloaded and extracted SRR1573574.fna
# ☁️ Uploaded to Drive: SRR1573574.fna
#
# [4026/5278] Processing SRR2567153...
# ✅ Downloaded and extracted SRR2567153.fna
# ☁️ Uploaded to Drive: SRR2567153.fna
#
# [4027/5278] Processing SRR2407621...
# ✅ Downloaded and extracted SRR2407621.fna
# ☁️ Uploaded to Drive: SRR2407621.fna
#
# [4028/5278] Processing SRR3295591...
# ✅ Downloaded and extracted SRR3295591.fna
# ☁️ Uploaded to Drive: SRR3295591.fna
#
# [4029/5278] Processing SRR3199873...
# ❌ No sample accession found for SRR3199873 in ENA
#
# [4030/5278] Processing SRR1982138...
# ✅ Downloaded and extracted SRR1982138.fna
# ☁️ Uploaded to Drive: SRR1982138.fna
#
# [4031/5278] Processing SRR3115184...
# ✅ Downloaded and extracted SRR3115184.fna
# ☁️ Uploaded to Drive: SRR3115184.fna
#
# [4032/5278] Processing SRR2542460...
# ✅ Downloaded and extracted SRR2542460.fna
# ☁️ Uploaded to Drive: SRR2542460.fna
#
# [4033/5278] Processing SRR2567154...
# ✅ Downloaded and extracted SRR2567154.fna
# ☁️ Uploaded to Drive: SRR2567154.fna
#
# [4034/5278] Processing SRR2407622...
# ✅ Downloaded and extracted SRR2407622.fna
# ☁️ Uploaded to Drive: SRR2407622.fna
#
# [4035/5278] Processing SRR3295592...
# ✅ Downloaded and extracted SRR3295592.fna
# ☁️ Uploaded to Drive: SRR3295592.fna
#
# [4036/5278] Processing SRR1299355...
# ✅ Downloaded and extracted SRR1299355.fna
# ☁️ Uploaded to Drive: SRR1299355.fna
#
# [4037/5278] Processing SRR3115185...
# ✅ Downloaded and extracted SRR3115185.fna
# ☁️ Uploaded to Drive: SRR3115185.fna
#
# [4038/5278] Processing SRR1982151...
# ✅ Downloaded and extracted SRR1982151.fna
# ☁️ Uploaded to Drive: SRR1982151.fna
#
# [4039/5278] Processing SRR4280624...
# ✅ Downloaded and extracted SRR4280624.fna
# ☁️ Uploaded to Drive: SRR4280624.fna
#
# [4040/5278] Processing SRR2407623...
# ✅ Downloaded and extracted SRR2407623.fna
# ☁️ Uploaded to Drive: SRR2407623.fna
#
# [4041/5278] Processing SRR1774017...
# ✅ Downloaded and extracted SRR1774017.fna
# ☁️ Uploaded to Drive: SRR1774017.fna
#
# [4042/5278] Processing SRR3740195...
# ✅ Downloaded and extracted SRR3740195.fna
# ☁️ Uploaded to Drive: SRR3740195.fna
#
# [4043/5278] Processing SRR2918185...
# ✅ Downloaded and extracted SRR2918185.fna
# ☁️ Uploaded to Drive: SRR2918185.fna
#
# [4044/5278] Processing SRR3295920...
# ✅ Downloaded and extracted SRR3295920.fna
# ☁️ Uploaded to Drive: SRR3295920.fna
#
# [4045/5278] Processing SRR3115186...
# ✅ Downloaded and extracted SRR3115186.fna
# ☁️ Uploaded to Drive: SRR3115186.fna
#
# [4046/5278] Processing SRR1573575...
# ✅ Downloaded and extracted SRR1573575.fna
# ☁️ Uploaded to Drive: SRR1573575.fna
#
# [4047/5278] Processing SRR3199874...
# ❌ No sample accession found for SRR3199874 in ENA
#
# [4048/5278] Processing SRR3295593...
# ✅ Downloaded and extracted SRR3295593.fna
# ☁️ Uploaded to Drive: SRR3295593.fna
#
# [4049/5278] Processing SRR2542461...
# ❌ No sample accession found for SRR2542461 in ENA
#
# [4050/5278] Processing SRR2407624...
# ✅ Downloaded and extracted SRR2407624.fna
# ☁️ Uploaded to Drive: SRR2407624.fna
#
# [4051/5278] Processing SRR3665032...
# ✅ Downloaded and extracted SRR3665032.fna
# ☁️ Uploaded to Drive: SRR3665032.fna
#
# [4052/5278] Processing SRR1774021...
# ✅ Downloaded and extracted SRR1774021.fna
# ☁️ Uploaded to Drive: SRR1774021.fna
#
# [4053/5278] Processing SRR1982165...
# ✅ Downloaded and extracted SRR1982165.fna
# ☁️ Uploaded to Drive: SRR1982165.fna
#
# [4054/5278] Processing SRR1299356...
# ✅ Downloaded and extracted SRR1299356.fna
# ☁️ Uploaded to Drive: SRR1299356.fna
#
# [4055/5278] Processing SRR2407625...
# ✅ Downloaded and extracted SRR2407625.fna
# ☁️ Uploaded to Drive: SRR2407625.fna
#
# [4056/5278] Processing SRR3665033...
# ✅ Downloaded and extracted SRR3665033.fna
# ☁️ Uploaded to Drive: SRR3665033.fna
#
# [4057/5278] Processing SRR3199875...
# ❌ No sample accession found for SRR3199875 in ENA
#
# [4058/5278] Processing SRR2567155...
# ✅ Downloaded and extracted SRR2567155.fna
# ☁️ Uploaded to Drive: SRR2567155.fna
#
# [4059/5278] Processing SRR3295594...
# ✅ Downloaded and extracted SRR3295594.fna
# ☁️ Uploaded to Drive: SRR3295594.fna
#
# [4060/5278] Processing SRR1982179...
# ✅ Downloaded and extracted SRR1982179.fna
# ☁️ Uploaded to Drive: SRR1982179.fna
#
# [4061/5278] Processing SRR3115187...
# ✅ Downloaded and extracted SRR3115187.fna
# ☁️ Uploaded to Drive: SRR3115187.fna
#
# [4062/5278] Processing SRR3295921...
# ✅ Downloaded and extracted SRR3295921.fna
# ☁️ Uploaded to Drive: SRR3295921.fna
#
# [4063/5278] Processing SRR2407626...
# ✅ Downloaded and extracted SRR2407626.fna
# ☁️ Uploaded to Drive: SRR2407626.fna
#
# [4064/5278] Processing SRR4280625...
# ✅ Downloaded and extracted SRR4280625.fna
# ☁️ Uploaded to Drive: SRR4280625.fna
#
# [4065/5278] Processing SRR3740196...
# ✅ Downloaded and extracted SRR3740196.fna
# ☁️ Uploaded to Drive: SRR3740196.fna
#
# [4066/5278] Processing SRR3199876...
# ❌ No sample accession found for SRR3199876 in ENA
#
# [4067/5278] Processing SRR1774022...
# ✅ Downloaded and extracted SRR1774022.fna
# ☁️ Uploaded to Drive: SRR1774022.fna
#
# [4068/5278] Processing SRR3295595...
# ✅ Downloaded and extracted SRR3295595.fna
# ☁️ Uploaded to Drive: SRR3295595.fna
#
# [4069/5278] Processing SRR3115188...
# ✅ Downloaded and extracted SRR3115188.fna
# ☁️ Uploaded to Drive: SRR3115188.fna
#
# [4070/5278] Processing SRR1982187...
# ✅ Downloaded and extracted SRR1982187.fna
# ☁️ Uploaded to Drive: SRR1982187.fna
#
# [4071/5278] Processing SRR2542477...
# ✅ Downloaded and extracted SRR2542477.fna
# ☁️ Uploaded to Drive: SRR2542477.fna
#
# [4072/5278] Processing SRR1299357...
# ✅ Downloaded and extracted SRR1299357.fna
# ☁️ Uploaded to Drive: SRR1299357.fna
#
# [4073/5278] Processing SRR4280626...
# ✅ Downloaded and extracted SRR4280626.fna
# ☁️ Uploaded to Drive: SRR4280626.fna
#
# [4074/5278] Processing SRR3199877...
# ❌ No sample accession found for SRR3199877 in ENA
#
# [4075/5278] Processing SRR3295922...
# ✅ Downloaded and extracted SRR3295922.fna
# ☁️ Uploaded to Drive: SRR3295922.fna
#
# [4076/5278] Processing SRR2567156...
# ✅ Downloaded and extracted SRR2567156.fna
# ☁️ Uploaded to Drive: SRR2567156.fna
#
# [4077/5278] Processing SRR3115189...
# ✅ Downloaded and extracted SRR3115189.fna
# ☁️ Uploaded to Drive: SRR3115189.fna
#
# [4078/5278] Processing SRR1573576...
# ✅ Downloaded and extracted SRR1573576.fna
# ☁️ Uploaded to Drive: SRR1573576.fna
#
# [4079/5278] Processing SRR1774031...
# ✅ Downloaded and extracted SRR1774031.fna
# ☁️ Uploaded to Drive: SRR1774031.fna
#
# [4080/5278] Processing SRR2918187...
# ✅ Downloaded and extracted SRR2918187.fna
# ☁️ Uploaded to Drive: SRR2918187.fna
#
# [4081/5278] Processing SRR3665035...
# ✅ Downloaded and extracted SRR3665035.fna
# ☁️ Uploaded to Drive: SRR3665035.fna
#
# [4082/5278] Processing SRR2407627...
# ✅ Downloaded and extracted SRR2407627.fna
# ☁️ Uploaded to Drive: SRR2407627.fna
#
# [4083/5278] Processing SRR3295596...
# ✅ Downloaded and extracted SRR3295596.fna
# ☁️ Uploaded to Drive: SRR3295596.fna
#
# [4084/5278] Processing SRR1299361...
# ✅ Downloaded and extracted SRR1299361.fna
# ☁️ Uploaded to Drive: SRR1299361.fna
#
# [4085/5278] Processing SRR1573577...
# ✅ Downloaded and extracted SRR1573577.fna
# ☁️ Uploaded to Drive: SRR1573577.fna
#
# [4086/5278] Processing SRR3199878...
# ❌ No sample accession found for SRR3199878 in ENA
#
# [4087/5278] Processing SRR3665036...
# ✅ Downloaded and extracted SRR3665036.fna
# ☁️ Uploaded to Drive: SRR3665036.fna
#
# [4088/5278] Processing SRR3115190...
# ✅ Downloaded and extracted SRR3115190.fna
# ☁️ Uploaded to Drive: SRR3115190.fna
#
# [4089/5278] Processing SRR4280627...
# ✅ Downloaded and extracted SRR4280627.fna
# ☁️ Uploaded to Drive: SRR4280627.fna
#
# [4090/5278] Processing SRR1982193...
# ✅ Downloaded and extracted SRR1982193.fna
# ☁️ Uploaded to Drive: SRR1982193.fna
#
# [4091/5278] Processing SRR3295923...
# ✅ Downloaded and extracted SRR3295923.fna
# ☁️ Uploaded to Drive: SRR3295923.fna
#
# [4092/5278] Processing SRR2407628...
# ✅ Downloaded and extracted SRR2407628.fna
# ☁️ Uploaded to Drive: SRR2407628.fna
#
# [4093/5278] Processing SRR2567157...
# ✅ Downloaded and extracted SRR2567157.fna
# ☁️ Uploaded to Drive: SRR2567157.fna
#
# [4094/5278] Processing SRR3740197...
# ✅ Downloaded and extracted SRR3740197.fna
# ☁️ Uploaded to Drive: SRR3740197.fna
#
# [4095/5278] Processing SRR1777667...
# ✅ Downloaded and extracted SRR1777667.fna
# ☁️ Uploaded to Drive: SRR1777667.fna
#
# [4096/5278] Processing SRR1574255...
# ✅ Downloaded and extracted SRR1574255.fna
# ☁️ Uploaded to Drive: SRR1574255.fna
#
# [4097/5278] Processing SRR3115191...
# ✅ Downloaded and extracted SRR3115191.fna
# ☁️ Uploaded to Drive: SRR3115191.fna
#
# [4098/5278] Processing SRR4280628...
# ✅ Downloaded and extracted SRR4280628.fna
# ☁️ Uploaded to Drive: SRR4280628.fna
#
# [4099/5278] Processing SRR3295597...
# ✅ Downloaded and extracted SRR3295597.fna
# ☁️ Uploaded to Drive: SRR3295597.fna
#
# [4100/5278] Processing SRR1777668...
# ✅ Downloaded and extracted SRR1777668.fna
# ☁️ Uploaded to Drive: SRR1777668.fna
#
# [4101/5278] Processing SRR3665037...
# ✅ Downloaded and extracted SRR3665037.fna
# ☁️ Uploaded to Drive: SRR3665037.fna
#
# [4102/5278] Processing SRR3199879...
# ✅ Downloaded and extracted SRR3199879.fna
# ☁️ Uploaded to Drive: SRR3199879.fna
#
# [4103/5278] Processing SRR1299362...
# ✅ Downloaded and extracted SRR1299362.fna
# ☁️ Uploaded to Drive: SRR1299362.fna
#
# [4104/5278] Processing SRR2542478...
# ✅ Downloaded and extracted SRR2542478.fna
# ☁️ Uploaded to Drive: SRR2542478.fna
#
# [4105/5278] Processing SRR2407629...
# ✅ Downloaded and extracted SRR2407629.fna
# ☁️ Uploaded to Drive: SRR2407629.fna
#
# [4106/5278] Processing SRR1982194...
# ✅ Downloaded and extracted SRR1982194.fna
# ☁️ Uploaded to Drive: SRR1982194.fna
#
# [4107/5278] Processing SRR3740198...
# ✅ Downloaded and extracted SRR3740198.fna
# ☁️ Uploaded to Drive: SRR3740198.fna
#
# [4108/5278] Processing SRR3199880...
# ✅ Downloaded and extracted SRR3199880.fna
# ☁️ Uploaded to Drive: SRR3199880.fna
#
# [4109/5278] Processing SRR3115192...
# ✅ Downloaded and extracted SRR3115192.fna
# ☁️ Uploaded to Drive: SRR3115192.fna
#
# [4110/5278] Processing SRR3295598...
# ✅ Downloaded and extracted SRR3295598.fna
# ☁️ Uploaded to Drive: SRR3295598.fna
#
# [4111/5278] Processing SRR2918189...
# ✅ Downloaded and extracted SRR2918189.fna
# ☁️ Uploaded to Drive: SRR2918189.fna
#
# [4112/5278] Processing SRR2567158...
# ✅ Downloaded and extracted SRR2567158.fna
# ☁️ Uploaded to Drive: SRR2567158.fna
#
# [4113/5278] Processing SRR1777669...
# ✅ Downloaded and extracted SRR1777669.fna
# ☁️ Uploaded to Drive: SRR1777669.fna
#
# [4114/5278] Processing SRR4280629...
# ✅ Downloaded and extracted SRR4280629.fna
# ☁️ Uploaded to Drive: SRR4280629.fna
#
# [4115/5278] Processing SRR3295924...
# ✅ Downloaded and extracted SRR3295924.fna
# ☁️ Uploaded to Drive: SRR3295924.fna
#
# [4116/5278] Processing SRR2542480...
# ✅ Downloaded and extracted SRR2542480.fna
# ☁️ Uploaded to Drive: SRR2542480.fna
#
# [4117/5278] Processing SRR2407630...
# ✅ Downloaded and extracted SRR2407630.fna
# ☁️ Uploaded to Drive: SRR2407630.fna
#
# [4118/5278] Processing SRR3665038...
# ✅ Downloaded and extracted SRR3665038.fna
# ☁️ Uploaded to Drive: SRR3665038.fna
#
# [4119/5278] Processing SRR3295599...
# ✅ Downloaded and extracted SRR3295599.fna
# ☁️ Uploaded to Drive: SRR3295599.fna
#
# [4120/5278] Processing SRR1982201...
# ✅ Downloaded and extracted SRR1982201.fna
# ☁️ Uploaded to Drive: SRR1982201.fna
#
# [4121/5278] Processing SRR4280630...
# ✅ Downloaded and extracted SRR4280630.fna
# ☁️ Uploaded to Drive: SRR4280630.fna
#
# [4122/5278] Processing SRR1574259...
# ✅ Downloaded and extracted SRR1574259.fna
# ☁️ Uploaded to Drive: SRR1574259.fna
#
# [4123/5278] Processing SRR1299363...
# ✅ Downloaded and extracted SRR1299363.fna
# ☁️ Uploaded to Drive: SRR1299363.fna
#
# [4124/5278] Processing SRR1777670...
# ✅ Downloaded and extracted SRR1777670.fna
# ☁️ Uploaded to Drive: SRR1777670.fna
#
# [4125/5278] Processing SRR3115200...
# ✅ Downloaded and extracted SRR3115200.fna
# ☁️ Uploaded to Drive: SRR3115200.fna
#
# [4126/5278] Processing SRR3740199...
# ✅ Downloaded and extracted SRR3740199.fna
# ☁️ Uploaded to Drive: SRR3740199.fna
#
# [4127/5278] Processing SRR4280631...
# ✅ Downloaded and extracted SRR4280631.fna
# ☁️ Uploaded to Drive: SRR4280631.fna
#
# [4128/5278] Processing SRR2407631...
# ✅ Downloaded and extracted SRR2407631.fna
# ☁️ Uploaded to Drive: SRR2407631.fna
#
# [4129/5278] Processing SRR3295600...
# ✅ Downloaded and extracted SRR3295600.fna
# ☁️ Uploaded to Drive: SRR3295600.fna
#
# [4130/5278] Processing SRR3295925...
# ✅ Downloaded and extracted SRR3295925.fna
# ☁️ Uploaded to Drive: SRR3295925.fna
#
# [4131/5278] Processing SRR1574261...
# ✅ Downloaded and extracted SRR1574261.fna
# ☁️ Uploaded to Drive: SRR1574261.fna
#
# [4132/5278] Processing SRR1982207...
# ✅ Downloaded and extracted SRR1982207.fna
# ☁️ Uploaded to Drive: SRR1982207.fna
#
# [4133/5278] Processing SRR3115201...
# ✅ Downloaded and extracted SRR3115201.fna
# ☁️ Uploaded to Drive: SRR3115201.fna
#
# [4134/5278] Processing SRR4280632...
# ✅ Downloaded and extracted SRR4280632.fna
# ☁️ Uploaded to Drive: SRR4280632.fna
#
# [4135/5278] Processing SRR2918190...
# ✅ Downloaded and extracted SRR2918190.fna
# ☁️ Uploaded to Drive: SRR2918190.fna
#
# [4136/5278] Processing SRR3199881...
# ✅ Downloaded and extracted SRR3199881.fna
# ☁️ Uploaded to Drive: SRR3199881.fna
#
# [4137/5278] Processing SRR2407632...
# ✅ Downloaded and extracted SRR2407632.fna
# ☁️ Uploaded to Drive: SRR2407632.fna
#
# [4138/5278] Processing SRR2567159...
# ✅ Downloaded and extracted SRR2567159.fna
# ☁️ Uploaded to Drive: SRR2567159.fna
#
# [4139/5278] Processing SRR1299364...
# ✅ Downloaded and extracted SRR1299364.fna
# ☁️ Uploaded to Drive: SRR1299364.fna
#
# [4140/5278] Processing SRR3295601...
# ✅ Downloaded and extracted SRR3295601.fna
# ☁️ Uploaded to Drive: SRR3295601.fna
#
# [4141/5278] Processing SRR1777672...
# ✅ Downloaded and extracted SRR1777672.fna
# ☁️ Uploaded to Drive: SRR1777672.fna
#
# [4142/5278] Processing SRR2542481...
# ✅ Downloaded and extracted SRR2542481.fna
# ☁️ Uploaded to Drive: SRR2542481.fna
#
# [4143/5278] Processing SRR3740200...
# ✅ Downloaded and extracted SRR3740200.fna
# ☁️ Uploaded to Drive: SRR3740200.fna
#
# [4144/5278] Processing SRR4280633...
# ✅ Downloaded and extracted SRR4280633.fna
# ☁️ Uploaded to Drive: SRR4280633.fna
#
# [4145/5278] Processing SRR1574265...
# ✅ Downloaded and extracted SRR1574265.fna
# ☁️ Uploaded to Drive: SRR1574265.fna
#
# [4146/5278] Processing SRR3115202...
# ✅ Downloaded and extracted SRR3115202.fna
# ☁️ Uploaded to Drive: SRR3115202.fna
#
# [4147/5278] Processing SRR1982211...
# ✅ Downloaded and extracted SRR1982211.fna
# ☁️ Uploaded to Drive: SRR1982211.fna
#
# [4148/5278] Processing SRR2407633...
# ✅ Downloaded and extracted SRR2407633.fna
# ☁️ Uploaded to Drive: SRR2407633.fna
#
# [4149/5278] Processing SRR3199882...
# ✅ Downloaded and extracted SRR3199882.fna
# ☁️ Uploaded to Drive: SRR3199882.fna
#
# [4150/5278] Processing SRR1299366...
# ✅ Downloaded and extracted SRR1299366.fna
# ☁️ Uploaded to Drive: SRR1299366.fna
#
# [4151/5278] Processing SRR3295926...
# ✅ Downloaded and extracted SRR3295926.fna
# ☁️ Uploaded to Drive: SRR3295926.fna
#
# [4152/5278] Processing SRR1777673...
# ✅ Downloaded and extracted SRR1777673.fna
# ☁️ Uploaded to Drive: SRR1777673.fna
#
# [4153/5278] Processing SRR3740201...
# ✅ Downloaded and extracted SRR3740201.fna
# ☁️ Uploaded to Drive: SRR3740201.fna
#
# [4154/5278] Processing SRR2567160...
# ✅ Downloaded and extracted SRR2567160.fna
# ☁️ Uploaded to Drive: SRR2567160.fna
#
# [4155/5278] Processing SRR3295602...
# ✅ Downloaded and extracted SRR3295602.fna
# ☁️ Uploaded to Drive: SRR3295602.fna
#
# [4156/5278] Processing SRR4280634...
# ✅ Downloaded and extracted SRR4280634.fna
# ☁️ Uploaded to Drive: SRR4280634.fna
#
# [4157/5278] Processing SRR3115218...
# ✅ Downloaded and extracted SRR3115218.fna
# ☁️ Uploaded to Drive: SRR3115218.fna
#
# [4158/5278] Processing SRR3295603...
# ✅ Downloaded and extracted SRR3295603.fna
# ☁️ Uploaded to Drive: SRR3295603.fna
#
# [4159/5278] Processing SRR3665042...
# ✅ Downloaded and extracted SRR3665042.fna
# ☁️ Uploaded to Drive: SRR3665042.fna
#
# [4160/5278] Processing SRR1299367...
# ✅ Downloaded and extracted SRR1299367.fna
# ☁️ Uploaded to Drive: SRR1299367.fna
#
# [4161/5278] Processing SRR2918194...
# ✅ Downloaded and extracted SRR2918194.fna
# ☁️ Uploaded to Drive: SRR2918194.fna
#
# [4162/5278] Processing SRR3295927...
# ✅ Downloaded and extracted SRR3295927.fna
# ☁️ Uploaded to Drive: SRR3295927.fna
#
# [4163/5278] Processing SRR1574278...
# ✅ Downloaded and extracted SRR1574278.fna
# ☁️ Uploaded to Drive: SRR1574278.fna
#
# [4164/5278] Processing SRR2542482...
# ✅ Downloaded and extracted SRR2542482.fna
# ☁️ Uploaded to Drive: SRR2542482.fna
#
# [4165/5278] Processing SRR1982219...
# ✅ Downloaded and extracted SRR1982219.fna
# ☁️ Uploaded to Drive: SRR1982219.fna
#
# [4166/5278] Processing SRR3199883...
# ✅ Downloaded and extracted SRR3199883.fna
# ☁️ Uploaded to Drive: SRR3199883.fna
#
# [4167/5278] Processing SRR3115221...
# ✅ Downloaded and extracted SRR3115221.fna
# ☁️ Uploaded to Drive: SRR3115221.fna
#
# [4168/5278] Processing SRR2407634...
# ✅ Downloaded and extracted SRR2407634.fna
# ☁️ Uploaded to Drive: SRR2407634.fna
#
# [4169/5278] Processing SRR3295604...
# ✅ Downloaded and extracted SRR3295604.fna
# ☁️ Uploaded to Drive: SRR3295604.fna
#
# [4170/5278] Processing SRR3295928...
# ✅ Downloaded and extracted SRR3295928.fna
# ☁️ Uploaded to Drive: SRR3295928.fna
#
# [4171/5278] Processing SRR2567161...
# ✅ Downloaded and extracted SRR2567161.fna
# ☁️ Uploaded to Drive: SRR2567161.fna
#
# [4172/5278] Processing SRR4280635...
# ✅ Downloaded and extracted SRR4280635.fna
# ☁️ Uploaded to Drive: SRR4280635.fna
#
# [4173/5278] Processing SRR1982220...
# ✅ Downloaded and extracted SRR1982220.fna
# ☁️ Uploaded to Drive: SRR1982220.fna
#
# [4174/5278] Processing SRR3115222...
# ✅ Downloaded and extracted SRR3115222.fna
# ☁️ Uploaded to Drive: SRR3115222.fna
#
# [4175/5278] Processing SRR1777682...
# ✅ Downloaded and extracted SRR1777682.fna
# ☁️ Uploaded to Drive: SRR1777682.fna
#
# [4176/5278] Processing SRR1299372...
# ✅ Downloaded and extracted SRR1299372.fna
# ☁️ Uploaded to Drive: SRR1299372.fna
#
# [4177/5278] Processing SRR3295605...
# ✅ Downloaded and extracted SRR3295605.fna
# ☁️ Uploaded to Drive: SRR3295605.fna
#
# [4178/5278] Processing SRR2542483...
# ✅ Downloaded and extracted SRR2542483.fna
# ☁️ Uploaded to Drive: SRR2542483.fna
#
# [4179/5278] Processing SRR4280636...
# ✅ Downloaded and extracted SRR4280636.fna
# ☁️ Uploaded to Drive: SRR4280636.fna
#
# [4180/5278] Processing SRR3665045...
# ✅ Downloaded and extracted SRR3665045.fna
# ☁️ Uploaded to Drive: SRR3665045.fna
#
# [4181/5278] Processing SRR1574279...
# ✅ Downloaded and extracted SRR1574279.fna
# ☁️ Uploaded to Drive: SRR1574279.fna
#
# [4182/5278] Processing SRR3745542...
# ✅ Downloaded and extracted SRR3745542.fna
# ☁️ Uploaded to Drive: SRR3745542.fna
#
# [4183/5278] Processing SRR2567162...
# ✅ Downloaded and extracted SRR2567162.fna
# ☁️ Uploaded to Drive: SRR2567162.fna
#
# [4184/5278] Processing SRR3199884...
# ❌ No sample accession found for SRR3199884 in ENA
#
# [4185/5278] Processing SRR1982229...
# ✅ Downloaded and extracted SRR1982229.fna
# ☁️ Uploaded to Drive: SRR1982229.fna
#
# [4186/5278] Processing SRR2407635...
# ✅ Downloaded and extracted SRR2407635.fna
# ☁️ Uploaded to Drive: SRR2407635.fna
#
# [4187/5278] Processing SRR3115223...
# ✅ Downloaded and extracted SRR3115223.fna
# ☁️ Uploaded to Drive: SRR3115223.fna
#
# [4188/5278] Processing SRR3295929...
# ✅ Downloaded and extracted SRR3295929.fna
# ☁️ Uploaded to Drive: SRR3295929.fna
#
# [4189/5278] Processing SRR4280637...
# ✅ Downloaded and extracted SRR4280637.fna
# ☁️ Uploaded to Drive: SRR4280637.fna
#
# [4190/5278] Processing SRR2567163...
# ✅ Downloaded and extracted SRR2567163.fna
# ☁️ Uploaded to Drive: SRR2567163.fna
#
# [4191/5278] Processing SRR3665047...
# ✅ Downloaded and extracted SRR3665047.fna
# ☁️ Uploaded to Drive: SRR3665047.fna
#
# [4192/5278] Processing SRR3745543...
# ✅ Downloaded and extracted SRR3745543.fna
# ☁️ Uploaded to Drive: SRR3745543.fna
#
# [4193/5278] Processing SRR1982235...
# ✅ Downloaded and extracted SRR1982235.fna
# ☁️ Uploaded to Drive: SRR1982235.fna
#
# [4194/5278] Processing SRR3199885...
# ❌ No sample accession found for SRR3199885 in ENA
#
# [4195/5278] Processing SRR2918195...
# ✅ Downloaded and extracted SRR2918195.fna
# ☁️ Uploaded to Drive: SRR2918195.fna
#
# [4196/5278] Processing SRR2542484...
# ✅ Downloaded and extracted SRR2542484.fna
# ☁️ Uploaded to Drive: SRR2542484.fna
#
# [4197/5278] Processing SRR3295606...
# ✅ Downloaded and extracted SRR3295606.fna
# ☁️ Uploaded to Drive: SRR3295606.fna
#
# [4198/5278] Processing SRR1574281...
# ✅ Downloaded and extracted SRR1574281.fna
# ☁️ Uploaded to Drive: SRR1574281.fna
#
# [4199/5278] Processing SRR3745544...
# ✅ Downloaded and extracted SRR3745544.fna
# ☁️ Uploaded to Drive: SRR3745544.fna
#
# [4200/5278] Processing SRR3115224...
# ✅ Downloaded and extracted SRR3115224.fna
# ☁️ Uploaded to Drive: SRR3115224.fna
#
# [4201/5278] Processing SRR1998955...
# ✅ Downloaded and extracted SRR1998955.fna
# ☁️ Uploaded to Drive: SRR1998955.fna
#
# [4202/5278] Processing SRR1777683...
# ✅ Downloaded and extracted SRR1777683.fna
# ☁️ Uploaded to Drive: SRR1777683.fna
#
# [4203/5278] Processing SRR3210379...
# ✅ Downloaded and extracted SRR3210379.fna
# ☁️ Uploaded to Drive: SRR3210379.fna
#
# [4204/5278] Processing SRR1299373...
# ✅ Downloaded and extracted SRR1299373.fna
# ☁️ Uploaded to Drive: SRR1299373.fna
#
# [4205/5278] Processing SRR4280638...
# ✅ Downloaded and extracted SRR4280638.fna
# ☁️ Uploaded to Drive: SRR4280638.fna
#
# [4206/5278] Processing SRR3295930...
# ✅ Downloaded and extracted SRR3295930.fna
# ☁️ Uploaded to Drive: SRR3295930.fna
#
# [4207/5278] Processing SRR3295607...
# ✅ Downloaded and extracted SRR3295607.fna
# ☁️ Uploaded to Drive: SRR3295607.fna
#
# [4208/5278] Processing SRR2407636...
# ✅ Downloaded and extracted SRR2407636.fna
# ☁️ Uploaded to Drive: SRR2407636.fna
#
# [4209/5278] Processing SRR1299378...
# ✅ Downloaded and extracted SRR1299378.fna
# ☁️ Uploaded to Drive: SRR1299378.fna
#
# [4210/5278] Processing SRR2542485...
# ✅ Downloaded and extracted SRR2542485.fna
# ☁️ Uploaded to Drive: SRR2542485.fna
#
# [4211/5278] Processing SRR3745545...
# ✅ Downloaded and extracted SRR3745545.fna
# ☁️ Uploaded to Drive: SRR3745545.fna
#
# [4212/5278] Processing SRR4280639...
# ✅ Downloaded and extracted SRR4280639.fna
# ☁️ Uploaded to Drive: SRR4280639.fna
#
# [4213/5278] Processing SRR3115225...
# ✅ Downloaded and extracted SRR3115225.fna
# ☁️ Uploaded to Drive: SRR3115225.fna
#
# [4214/5278] Processing SRR2567164...
# ✅ Downloaded and extracted SRR2567164.fna
# ☁️ Uploaded to Drive: SRR2567164.fna
#
# [4215/5278] Processing SRR1998972...
# ✅ Downloaded and extracted SRR1998972.fna
# ☁️ Uploaded to Drive: SRR1998972.fna
#
# [4216/5278] Processing SRR1777690...
# ✅ Downloaded and extracted SRR1777690.fna
# ☁️ Uploaded to Drive: SRR1777690.fna
#
# [4217/5278] Processing SRR4280640...
# ✅ Downloaded and extracted SRR4280640.fna
# ☁️ Uploaded to Drive: SRR4280640.fna
#
# [4218/5278] Processing SRR3295931...
# ✅ Downloaded and extracted SRR3295931.fna
# ☁️ Uploaded to Drive: SRR3295931.fna
#
# [4219/5278] Processing SRR3210380...
# ✅ Downloaded and extracted SRR3210380.fna
# ☁️ Uploaded to Drive: SRR3210380.fna
#
# [4220/5278] Processing SRR3295608...
# ✅ Downloaded and extracted SRR3295608.fna
# ☁️ Uploaded to Drive: SRR3295608.fna
#
# [4221/5278] Processing SRR1777697...
# ✅ Downloaded and extracted SRR1777697.fna
# ☁️ Uploaded to Drive: SRR1777697.fna
#
# [4222/5278] Processing SRR1998976...
# ✅ Downloaded and extracted SRR1998976.fna
# ☁️ Uploaded to Drive: SRR1998976.fna
#
# [4223/5278] Processing SRR3745546...
# ✅ Downloaded and extracted SRR3745546.fna
# ☁️ Uploaded to Drive: SRR3745546.fna
#
# [4224/5278] Processing SRR1998980...
# ✅ Downloaded and extracted SRR1998980.fna
# ☁️ Uploaded to Drive: SRR1998980.fna
#
# [4225/5278] Processing SRR3115226...
# ✅ Downloaded and extracted SRR3115226.fna
# ☁️ Uploaded to Drive: SRR3115226.fna
#
# [4226/5278] Processing SRR1574288...
# ✅ Downloaded and extracted SRR1574288.fna
# ☁️ Uploaded to Drive: SRR1574288.fna
#
# [4227/5278] Processing SRR2542486...
# ✅ Downloaded and extracted SRR2542486.fna
# ☁️ Uploaded to Drive: SRR2542486.fna
#
# [4228/5278] Processing SRR1299379...
# ✅ Downloaded and extracted SRR1299379.fna
# ☁️ Uploaded to Drive: SRR1299379.fna
#
# [4229/5278] Processing SRR3295932...
# ✅ Downloaded and extracted SRR3295932.fna
# ☁️ Uploaded to Drive: SRR3295932.fna
#
# [4230/5278] Processing SRR2407637...
# ✅ Downloaded and extracted SRR2407637.fna
# ☁️ Uploaded to Drive: SRR2407637.fna
#
# [4231/5278] Processing SRR3295609...
# ✅ Downloaded and extracted SRR3295609.fna
# ☁️ Uploaded to Drive: SRR3295609.fna
#
# [4232/5278] Processing SRR3764681...
# ✅ Downloaded and extracted SRR3764681.fna
# ☁️ Uploaded to Drive: SRR3764681.fna
#
# [4233/5278] Processing SRR4280641...
# ✅ Downloaded and extracted SRR4280641.fna
# ☁️ Uploaded to Drive: SRR4280641.fna
#
# [4234/5278] Processing SRR3665050...
# ✅ Downloaded and extracted SRR3665050.fna
# ☁️ Uploaded to Drive: SRR3665050.fna
#
# [4235/5278] Processing SRR2918196...
# ✅ Downloaded and extracted SRR2918196.fna
# ☁️ Uploaded to Drive: SRR2918196.fna
#
# [4236/5278] Processing SRR3115230...
# ✅ Downloaded and extracted SRR3115230.fna
# ☁️ Uploaded to Drive: SRR3115230.fna
#
# [4237/5278] Processing SRR1777701...
# ✅ Downloaded and extracted SRR1777701.fna
# ☁️ Uploaded to Drive: SRR1777701.fna
#
# [4238/5278] Processing SRR2567165...
# ✅ Downloaded and extracted SRR2567165.fna
# ☁️ Uploaded to Drive: SRR2567165.fna
#
# [4239/5278] Processing SRR2002451...
# ❌ No assembly found for SAMN03291590
#
# [4240/5278] Processing SRR3210381...
# ✅ Downloaded and extracted SRR3210381.fna
# ☁️ Uploaded to Drive: SRR3210381.fna
#
# [4241/5278] Processing SRR3295933...
# ✅ Downloaded and extracted SRR3295933.fna
# ☁️ Uploaded to Drive: SRR3295933.fna
#
# [4242/5278] Processing SRR2407638...
# ✅ Downloaded and extracted SRR2407638.fna
# ☁️ Uploaded to Drive: SRR2407638.fna
#
# [4243/5278] Processing SRR1299380...
# ✅ Downloaded and extracted SRR1299380.fna
# ☁️ Uploaded to Drive: SRR1299380.fna
#
# [4244/5278] Processing SRR3295610...
# ✅ Downloaded and extracted SRR3295610.fna
# ☁️ Uploaded to Drive: SRR3295610.fna
#
# [4245/5278] Processing SRR3665051...
# ✅ Downloaded and extracted SRR3665051.fna
# ☁️ Uploaded to Drive: SRR3665051.fna
#
# [4246/5278] Processing SRR1777702...
# ✅ Downloaded and extracted SRR1777702.fna
# ☁️ Uploaded to Drive: SRR1777702.fna
#
# [4247/5278] Processing SRR2939004...
# ✅ Downloaded and extracted SRR2939004.fna
# ☁️ Uploaded to Drive: SRR2939004.fna
#
# [4248/5278] Processing SRR3295611...
# ✅ Downloaded and extracted SRR3295611.fna
# ☁️ Uploaded to Drive: SRR3295611.fna
#
# [4249/5278] Processing SRR3115231...
# ✅ Downloaded and extracted SRR3115231.fna
# ☁️ Uploaded to Drive: SRR3115231.fna
#
# [4250/5278] Processing SRR1574289...
# ✅ Downloaded and extracted SRR1574289.fna
# ☁️ Uploaded to Drive: SRR1574289.fna
#
# [4251/5278] Processing SRR4280642...
# ✅ Downloaded and extracted SRR4280642.fna
# ☁️ Uploaded to Drive: SRR4280642.fna
#
# [4252/5278] Processing SRR3764719...
# ✅ Downloaded and extracted SRR3764719.fna
# ☁️ Uploaded to Drive: SRR3764719.fna
#
# [4253/5278] Processing SRR2407639...
# ✅ Downloaded and extracted SRR2407639.fna
# ☁️ Uploaded to Drive: SRR2407639.fna
#
# [4254/5278] Processing SRR3210382...
# ✅ Downloaded and extracted SRR3210382.fna
# ☁️ Uploaded to Drive: SRR3210382.fna
#
# [4255/5278] Processing SRR4280643...
# ✅ Downloaded and extracted SRR4280643.fna
# ☁️ Uploaded to Drive: SRR4280643.fna
#
# [4256/5278] Processing SRR2567166...
# ✅ Downloaded and extracted SRR2567166.fna
# ☁️ Uploaded to Drive: SRR2567166.fna
#
# [4257/5278] Processing SRR1574295...
# ✅ Downloaded and extracted SRR1574295.fna
# ☁️ Uploaded to Drive: SRR1574295.fna
#
# [4258/5278] Processing SRR3665052...
# ✅ Downloaded and extracted SRR3665052.fna
# ☁️ Uploaded to Drive: SRR3665052.fna
#
# [4259/5278] Processing SRR3295934...
# ✅ Downloaded and extracted SRR3295934.fna
# ☁️ Uploaded to Drive: SRR3295934.fna
#
# [4260/5278] Processing SRR1299389...
# ✅ Downloaded and extracted SRR1299389.fna
# ☁️ Uploaded to Drive: SRR1299389.fna
#
# [4261/5278] Processing SRR1777703...
# ✅ Downloaded and extracted SRR1777703.fna
# ☁️ Uploaded to Drive: SRR1777703.fna
#
# [4262/5278] Processing SRR3115232...
# ✅ Downloaded and extracted SRR3115232.fna
# ☁️ Uploaded to Drive: SRR3115232.fna
#
# [4263/5278] Processing SRR2002456...
# ✅ Downloaded and extracted SRR2002456.fna
# ☁️ Uploaded to Drive: SRR2002456.fna
#
# [4264/5278] Processing SRR3295612...
# ✅ Downloaded and extracted SRR3295612.fna
# ☁️ Uploaded to Drive: SRR3295612.fna
#
# [4265/5278] Processing SRR2542487...
# ✅ Downloaded and extracted SRR2542487.fna
# ☁️ Uploaded to Drive: SRR2542487.fna
#
# [4266/5278] Processing SRR3295935...
# ✅ Downloaded and extracted SRR3295935.fna
# ☁️ Uploaded to Drive: SRR3295935.fna
#
# [4267/5278] Processing SRR2939005...
# ✅ Downloaded and extracted SRR2939005.fna
# ☁️ Uploaded to Drive: SRR2939005.fna
#
# [4268/5278] Processing SRR2567167...
# ✅ Downloaded and extracted SRR2567167.fna
# ☁️ Uploaded to Drive: SRR2567167.fna
#
# [4269/5278] Processing SRR3665053...
# ✅ Downloaded and extracted SRR3665053.fna
# ☁️ Uploaded to Drive: SRR3665053.fna
#
# [4270/5278] Processing SRR3210383...
# ✅ Downloaded and extracted SRR3210383.fna
# ☁️ Uploaded to Drive: SRR3210383.fna
#
# [4271/5278] Processing SRR4280644...
# ✅ Downloaded and extracted SRR4280644.fna
# ☁️ Uploaded to Drive: SRR4280644.fna
#
# [4272/5278] Processing SRR1777705...
# ✅ Downloaded and extracted SRR1777705.fna
# ☁️ Uploaded to Drive: SRR1777705.fna
#
# [4273/5278] Processing SRR2407640...
# ✅ Downloaded and extracted SRR2407640.fna
# ☁️ Uploaded to Drive: SRR2407640.fna
#
# [4274/5278] Processing SRR3115233...
# ✅ Downloaded and extracted SRR3115233.fna
# ☁️ Uploaded to Drive: SRR3115233.fna
#
# [4275/5278] Processing SRR2542488...
# ✅ Downloaded and extracted SRR2542488.fna
# ☁️ Uploaded to Drive: SRR2542488.fna
#
# [4276/5278] Processing SRR3764720...
# ✅ Downloaded and extracted SRR3764720.fna
# ☁️ Uploaded to Drive: SRR3764720.fna
#
# [4277/5278] Processing SRR3295936...
# ✅ Downloaded and extracted SRR3295936.fna
# ☁️ Uploaded to Drive: SRR3295936.fna
#
# [4278/5278] Processing SRR1299393...
# ✅ Downloaded and extracted SRR1299393.fna
# ☁️ Uploaded to Drive: SRR1299393.fna
#
# [4279/5278] Processing SRR3665054...
# ✅ Downloaded and extracted SRR3665054.fna
# ☁️ Uploaded to Drive: SRR3665054.fna
#
# [4280/5278] Processing SRR3295613...
# ✅ Downloaded and extracted SRR3295613.fna
# ☁️ Uploaded to Drive: SRR3295613.fna
#
# [4281/5278] Processing SRR4280645...
# ✅ Downloaded and extracted SRR4280645.fna
# ☁️ Uploaded to Drive: SRR4280645.fna
#
# [4282/5278] Processing SRR3295937...
# ✅ Downloaded and extracted SRR3295937.fna
# ☁️ Uploaded to Drive: SRR3295937.fna
#
# [4283/5278] Processing SRR1777706...
# ✅ Downloaded and extracted SRR1777706.fna
# ☁️ Uploaded to Drive: SRR1777706.fna
#
# [4284/5278] Processing SRR1574310...
# ✅ Downloaded and extracted SRR1574310.fna
# ☁️ Uploaded to Drive: SRR1574310.fna
#
# [4285/5278] Processing SRR2567168...
# ✅ Downloaded and extracted SRR2567168.fna
# ☁️ Uploaded to Drive: SRR2567168.fna
#
# [4286/5278] Processing SRR3210384...
# ✅ Downloaded and extracted SRR3210384.fna
# ☁️ Uploaded to Drive: SRR3210384.fna
#
# [4287/5278] Processing SRR3115234...
# ✅ Downloaded and extracted SRR3115234.fna
# ☁️ Uploaded to Drive: SRR3115234.fna
#
# [4288/5278] Processing SRR3665055...
# ✅ Downloaded and extracted SRR3665055.fna
# ☁️ Uploaded to Drive: SRR3665055.fna
#
# [4289/5278] Processing SRR2939006...
# ✅ Downloaded and extracted SRR2939006.fna
# ☁️ Uploaded to Drive: SRR2939006.fna
#
# [4290/5278] Processing SRR2002457...
# ❌ No assembly found for SAMN03291596
#
# [4291/5278] Processing SRR4280646...
# ✅ Downloaded and extracted SRR4280646.fna
# ☁️ Uploaded to Drive: SRR4280646.fna
#
# [4292/5278] Processing SRR1299398...
# ✅ Downloaded and extracted SRR1299398.fna
# ☁️ Uploaded to Drive: SRR1299398.fna
#
# [4293/5278] Processing SRR3765010...
# ✅ Downloaded and extracted SRR3765010.fna
# ☁️ Uploaded to Drive: SRR3765010.fna
#
# [4294/5278] Processing SRR2542489...
# ✅ Downloaded and extracted SRR2542489.fna
# ☁️ Uploaded to Drive: SRR2542489.fna
#
# [4295/5278] Processing SRR3295614...
# ✅ Downloaded and extracted SRR3295614.fna
# ☁️ Uploaded to Drive: SRR3295614.fna
#
# [4296/5278] Processing SRR2407641...
# ✅ Downloaded and extracted SRR2407641.fna
# ☁️ Uploaded to Drive: SRR2407641.fna
#
# [4297/5278] Processing SRR3295938...
# ✅ Downloaded and extracted SRR3295938.fna
# ☁️ Uploaded to Drive: SRR3295938.fna
#
# [4298/5278] Processing SRR1574311...
# ✅ Downloaded and extracted SRR1574311.fna
# ☁️ Uploaded to Drive: SRR1574311.fna
#
# [4299/5278] Processing SRR3210385...
# ✅ Downloaded and extracted SRR3210385.fna
# ☁️ Uploaded to Drive: SRR3210385.fna
#
# [4300/5278] Processing SRR2407642...
# ✅ Downloaded and extracted SRR2407642.fna
# ☁️ Uploaded to Drive: SRR2407642.fna
#
# [4301/5278] Processing SRR4280647...
# ✅ Downloaded and extracted SRR4280647.fna
# ☁️ Uploaded to Drive: SRR4280647.fna
#
# [4302/5278] Processing SRR2002463...
# ❌ No assembly found for SAMN03291584
#
# [4303/5278] Processing SRR2567169...
# ✅ Downloaded and extracted SRR2567169.fna
# ☁️ Uploaded to Drive: SRR2567169.fna
#
# [4304/5278] Processing SRR1777707...
# ✅ Downloaded and extracted SRR1777707.fna
# ☁️ Uploaded to Drive: SRR1777707.fna
#
# [4305/5278] Processing SRR3115236...
# ✅ Downloaded and extracted SRR3115236.fna
# ☁️ Uploaded to Drive: SRR3115236.fna
#
# [4306/5278] Processing SRR3295615...
# ✅ Downloaded and extracted SRR3295615.fna
# ☁️ Uploaded to Drive: SRR3295615.fna
#
# [4307/5278] Processing SRR3665057...
# ✅ Downloaded and extracted SRR3665057.fna
# ☁️ Uploaded to Drive: SRR3665057.fna
#
# [4308/5278] Processing SRR3765051...
# ✅ Downloaded and extracted SRR3765051.fna
# ☁️ Uploaded to Drive: SRR3765051.fna
#
# [4309/5278] Processing SRR2002464...
# ❌ No assembly found for SAMN03291592
#
# [4310/5278] Processing SRR3295939...
# ✅ Downloaded and extracted SRR3295939.fna
# ☁️ Uploaded to Drive: SRR3295939.fna
#
# [4311/5278] Processing SRR1574314...
# ✅ Downloaded and extracted SRR1574314.fna
# ☁️ Uploaded to Drive: SRR1574314.fna
#
# [4312/5278] Processing SRR2939007...
# ✅ Downloaded and extracted SRR2939007.fna
# ☁️ Uploaded to Drive: SRR2939007.fna
#
# [4313/5278] Processing SRR1299421...
# ✅ Downloaded and extracted SRR1299421.fna
# ☁️ Uploaded to Drive: SRR1299421.fna
#
# [4314/5278] Processing SRR2407643...
# ✅ Downloaded and extracted SRR2407643.fna
# ☁️ Uploaded to Drive: SRR2407643.fna
#
# [4315/5278] Processing SRR1777996...
# ✅ Downloaded and extracted SRR1777996.fna
# ☁️ Uploaded to Drive: SRR1777996.fna
#
# [4316/5278] Processing SRR2567170...
# ✅ Downloaded and extracted SRR2567170.fna
# ☁️ Uploaded to Drive: SRR2567170.fna
#
# [4317/5278] Processing SRR3115237...
# ✅ Downloaded and extracted SRR3115237.fna
# ☁️ Uploaded to Drive: SRR3115237.fna
#
# [4318/5278] Processing SRR2542493...
# ✅ Downloaded and extracted SRR2542493.fna
# ☁️ Uploaded to Drive: SRR2542493.fna
#
# [4319/5278] Processing SRR3295616...
# ✅ Downloaded and extracted SRR3295616.fna
# ☁️ Uploaded to Drive: SRR3295616.fna
#
# [4320/5278] Processing SRR3210386...
# ✅ Downloaded and extracted SRR3210386.fna
# ☁️ Uploaded to Drive: SRR3210386.fna
#
# [4321/5278] Processing SRR2939119...
# ✅ Downloaded and extracted SRR2939119.fna
# ☁️ Uploaded to Drive: SRR2939119.fna
#
# [4322/5278] Processing SRR1574315...
# ✅ Downloaded and extracted SRR1574315.fna
# ☁️ Uploaded to Drive: SRR1574315.fna
#
# [4323/5278] Processing SRR2407644...
# ✅ Downloaded and extracted SRR2407644.fna
# ☁️ Uploaded to Drive: SRR2407644.fna
#
# [4324/5278] Processing SRR3115238...
# ✅ Downloaded and extracted SRR3115238.fna
# ☁️ Uploaded to Drive: SRR3115238.fna
#
# [4325/5278] Processing SRR2567171...
# ✅ Downloaded and extracted SRR2567171.fna
# ☁️ Uploaded to Drive: SRR2567171.fna
#
# [4326/5278] Processing SRR1574316...
# ✅ Downloaded and extracted SRR1574316.fna
# ☁️ Uploaded to Drive: SRR1574316.fna
#
# [4327/5278] Processing SRR3295940...
# ✅ Downloaded and extracted SRR3295940.fna
# ☁️ Uploaded to Drive: SRR3295940.fna
#
# [4328/5278] Processing SRR3210387...
# ✅ Downloaded and extracted SRR3210387.fna
# ☁️ Uploaded to Drive: SRR3210387.fna
#
# [4329/5278] Processing SRR1777998...
# ✅ Downloaded and extracted SRR1777998.fna
# ☁️ Uploaded to Drive: SRR1777998.fna
#
# [4330/5278] Processing SRR3295617...
# ✅ Downloaded and extracted SRR3295617.fna
# ☁️ Uploaded to Drive: SRR3295617.fna
#
# [4331/5278] Processing SRR3765052...
# ✅ Downloaded and extracted SRR3765052.fna
# ☁️ Uploaded to Drive: SRR3765052.fna
#
# [4332/5278] Processing SRR2407645...
# ✅ Downloaded and extracted SRR2407645.fna
# ☁️ Uploaded to Drive: SRR2407645.fna
#
# [4333/5278] Processing SRR1299423...
# ✅ Downloaded and extracted SRR1299423.fna
# ☁️ Uploaded to Drive: SRR1299423.fna
#
# [4334/5278] Processing SRR3665059...
# ✅ Downloaded and extracted SRR3665059.fna
# ☁️ Uploaded to Drive: SRR3665059.fna
#
# [4335/5278] Processing SRR3295618...
# ✅ Downloaded and extracted SRR3295618.fna
# ☁️ Uploaded to Drive: SRR3295618.fna
#
# [4336/5278] Processing SRR3295941...
# ✅ Downloaded and extracted SRR3295941.fna
# ☁️ Uploaded to Drive: SRR3295941.fna
#
# [4337/5278] Processing SRR3115239...
# ✅ Downloaded and extracted SRR3115239.fna
# ☁️ Uploaded to Drive: SRR3115239.fna
#
# [4338/5278] Processing SRR2407646...
# ✅ Downloaded and extracted SRR2407646.fna
# ☁️ Uploaded to Drive: SRR2407646.fna
#
# [4339/5278] Processing SRR2939120...
# ✅ Downloaded and extracted SRR2939120.fna
# ☁️ Uploaded to Drive: SRR2939120.fna
#
# [4340/5278] Processing SRR1574320...
# ✅ Downloaded and extracted SRR1574320.fna
# ☁️ Uploaded to Drive: SRR1574320.fna
#
# [4341/5278] Processing SRR2407647...
# ✅ Downloaded and extracted SRR2407647.fna
# ☁️ Uploaded to Drive: SRR2407647.fna
#
# [4342/5278] Processing SRR3295631...
# ✅ Downloaded and extracted SRR3295631.fna
# ☁️ Uploaded to Drive: SRR3295631.fna
#
# [4343/5278] Processing SRR2002468...
# ❌ No assembly found for SAMN03291583
#
# [4344/5278] Processing SRR3295942...
# ✅ Downloaded and extracted SRR3295942.fna
# ☁️ Uploaded to Drive: SRR3295942.fna
#
# [4345/5278] Processing SRR3765053...
# ✅ Downloaded and extracted SRR3765053.fna
# ☁️ Uploaded to Drive: SRR3765053.fna
#
# [4346/5278] Processing SRR2567172...
# ✅ Downloaded and extracted SRR2567172.fna
# ☁️ Uploaded to Drive: SRR2567172.fna
#
# [4347/5278] Processing SRR1299428...
# ✅ Downloaded and extracted SRR1299428.fna
# ☁️ Uploaded to Drive: SRR1299428.fna
#
# [4348/5278] Processing SRR3210388...
# ✅ Downloaded and extracted SRR3210388.fna
# ☁️ Uploaded to Drive: SRR3210388.fna
#
# [4349/5278] Processing SRR2542494...
# ✅ Downloaded and extracted SRR2542494.fna
# ☁️ Uploaded to Drive: SRR2542494.fna
#
# [4350/5278] Processing SRR2407648...
# ✅ Downloaded and extracted SRR2407648.fna
# ☁️ Uploaded to Drive: SRR2407648.fna
#
# [4351/5278] Processing SRR3295632...
# ✅ Downloaded and extracted SRR3295632.fna
# ☁️ Uploaded to Drive: SRR3295632.fna
#
# [4352/5278] Processing SRR3115242...
# ✅ Downloaded and extracted SRR3115242.fna
# ☁️ Uploaded to Drive: SRR3115242.fna
#
# [4353/5278] Processing SRR1575954...
# ✅ Downloaded and extracted SRR1575954.fna
# ☁️ Uploaded to Drive: SRR1575954.fna
#
# [4354/5278] Processing SRR3210389...
# ✅ Downloaded and extracted SRR3210389.fna
# ☁️ Uploaded to Drive: SRR3210389.fna
#
# [4355/5278] Processing SRR3295943...
# ✅ Downloaded and extracted SRR3295943.fna
# ☁️ Uploaded to Drive: SRR3295943.fna
#
# [4356/5278] Processing SRR2939121...
# ✅ Downloaded and extracted SRR2939121.fna
# ☁️ Uploaded to Drive: SRR2939121.fna
#
# [4357/5278] Processing SRR2567173...
# ✅ Downloaded and extracted SRR2567173.fna
# ☁️ Uploaded to Drive: SRR2567173.fna
#
# [4358/5278] Processing SRR2002470...
# ✅ Downloaded and extracted SRR2002470.fna
# ☁️ Uploaded to Drive: SRR2002470.fna
#
# [4359/5278] Processing SRR3765054...
# ✅ Downloaded and extracted SRR3765054.fna
# ☁️ Uploaded to Drive: SRR3765054.fna
#
# [4360/5278] Processing SRR1299430...
# ✅ Downloaded and extracted SRR1299430.fna
# ☁️ Uploaded to Drive: SRR1299430.fna
#
# [4361/5278] Processing SRR2939122...
# ✅ Downloaded and extracted SRR2939122.fna
# ☁️ Uploaded to Drive: SRR2939122.fna
#
# [4362/5278] Processing SRR1778000...
# ✅ Downloaded and extracted SRR1778000.fna
# ☁️ Uploaded to Drive: SRR1778000.fna
#
# [4363/5278] Processing SRR2542497...
# ❌ No sample accession found for SRR2542497 in ENA
#
# [4364/5278] Processing SRR2407649...
# ✅ Downloaded and extracted SRR2407649.fna
# ☁️ Uploaded to Drive: SRR2407649.fna
#
# [4365/5278] Processing SRR2939123...
# ✅ Downloaded and extracted SRR2939123.fna
# ☁️ Uploaded to Drive: SRR2939123.fna
#
# [4366/5278] Processing SRR2002476...
# ✅ Downloaded and extracted SRR2002476.fna
# ☁️ Uploaded to Drive: SRR2002476.fna
#
# [4367/5278] Processing SRR3295633...
# ✅ Downloaded and extracted SRR3295633.fna
# ☁️ Uploaded to Drive: SRR3295633.fna
#
# [4368/5278] Processing SRR2939124...
# ✅ Downloaded and extracted SRR2939124.fna
# ☁️ Uploaded to Drive: SRR2939124.fna
#
# [4369/5278] Processing SRR1575958...
# ✅ Downloaded and extracted SRR1575958.fna
# ☁️ Uploaded to Drive: SRR1575958.fna
#
# [4370/5278] Processing SRR2407650...
# ✅ Downloaded and extracted SRR2407650.fna
# ☁️ Uploaded to Drive: SRR2407650.fna
#
# [4371/5278] Processing SRR2939125...
# ✅ Downloaded and extracted SRR2939125.fna
# ☁️ Uploaded to Drive: SRR2939125.fna
#
# [4372/5278] Processing SRR3295634...
# ✅ Downloaded and extracted SRR3295634.fna
# ☁️ Uploaded to Drive: SRR3295634.fna
#
# [4373/5278] Processing SRR2567174...
# ✅ Downloaded and extracted SRR2567174.fna
# ☁️ Uploaded to Drive: SRR2567174.fna
#
# [4374/5278] Processing SRR2939127...
# ✅ Downloaded and extracted SRR2939127.fna
# ☁️ Uploaded to Drive: SRR2939127.fna
#
# [4375/5278] Processing SRR3295944...
# ✅ Downloaded and extracted SRR3295944.fna
# ☁️ Uploaded to Drive: SRR3295944.fna
#
# [4376/5278] Processing SRR3115243...
# ✅ Downloaded and extracted SRR3115243.fna
# ☁️ Uploaded to Drive: SRR3115243.fna
#
# [4377/5278] Processing SRR3210390...
# ✅ Downloaded and extracted SRR3210390.fna
# ☁️ Uploaded to Drive: SRR3210390.fna
#
# [4378/5278] Processing SRR3665062...
# ✅ Downloaded and extracted SRR3665062.fna
# ☁️ Uploaded to Drive: SRR3665062.fna
#
# [4379/5278] Processing SRR2002479...
# ✅ Downloaded and extracted SRR2002479.fna
# ☁️ Uploaded to Drive: SRR2002479.fna
#
# [4380/5278] Processing SRR1299431...
# ✅ Downloaded and extracted SRR1299431.fna
# ☁️ Uploaded to Drive: SRR1299431.fna
#
# [4381/5278] Processing SRR1778004...
# ✅ Downloaded and extracted SRR1778004.fna
# ☁️ Uploaded to Drive: SRR1778004.fna
#
# [4382/5278] Processing SRR2939128...
# ✅ Downloaded and extracted SRR2939128.fna
# ☁️ Uploaded to Drive: SRR2939128.fna
#
# [4383/5278] Processing SRR2407651...
# ✅ Downloaded and extracted SRR2407651.fna
# ☁️ Uploaded to Drive: SRR2407651.fna
#
# [4384/5278] Processing SRR2567175...
# ✅ Downloaded and extracted SRR2567175.fna
# ☁️ Uploaded to Drive: SRR2567175.fna
#
# [4385/5278] Processing SRR2962356...
# ✅ Downloaded and extracted SRR2962356.fna
# ☁️ Uploaded to Drive: SRR2962356.fna
#
# [4386/5278] Processing SRR3765176...
# ✅ Downloaded and extracted SRR3765176.fna
# ☁️ Uploaded to Drive: SRR3765176.fna
#
# [4387/5278] Processing SRR2407652...
# ✅ Downloaded and extracted SRR2407652.fna
# ☁️ Uploaded to Drive: SRR2407652.fna
#
# [4388/5278] Processing SRR1575963...
# ✅ Downloaded and extracted SRR1575963.fna
# ☁️ Uploaded to Drive: SRR1575963.fna
#
# [4389/5278] Processing SRR3665063...
# ✅ Downloaded and extracted SRR3665063.fna
# ☁️ Uploaded to Drive: SRR3665063.fna
#
# [4390/5278] Processing SRR3295945...
# ✅ Downloaded and extracted SRR3295945.fna
# ☁️ Uploaded to Drive: SRR3295945.fna
#
# [4391/5278] Processing SRR2002480...
# ✅ Downloaded and extracted SRR2002480.fna
# ☁️ Uploaded to Drive: SRR2002480.fna
#
# [4392/5278] Processing SRR2542498...
# ❌ No sample accession found for SRR2542498 in ENA
#
# [4393/5278] Processing SRR3295635...
# ✅ Downloaded and extracted SRR3295635.fna
# ☁️ Uploaded to Drive: SRR3295635.fna
#
# [4394/5278] Processing SRR3116153...
# ✅ Downloaded and extracted SRR3116153.fna
# ☁️ Uploaded to Drive: SRR3116153.fna
#
# [4395/5278] Processing SRR2962357...
# ✅ Downloaded and extracted SRR2962357.fna
# ☁️ Uploaded to Drive: SRR2962357.fna
#
# [4396/5278] Processing SRR1300553...
# ✅ Downloaded and extracted SRR1300553.fna
# ☁️ Uploaded to Drive: SRR1300553.fna
#
# [4397/5278] Processing SRR1778009...
# ✅ Downloaded and extracted SRR1778009.fna
# ☁️ Uploaded to Drive: SRR1778009.fna
#
# [4398/5278] Processing SRR3210391...
# ✅ Downloaded and extracted SRR3210391.fna
# ☁️ Uploaded to Drive: SRR3210391.fna
#
# [4399/5278] Processing SRR2567176...
# ✅ Downloaded and extracted SRR2567176.fna
# ☁️ Uploaded to Drive: SRR2567176.fna
#
# [4400/5278] Processing SRR3665064...
# ✅ Downloaded and extracted SRR3665064.fna
# ☁️ Uploaded to Drive: SRR3665064.fna
#
# [4401/5278] Processing SRR2407653...
# ✅ Downloaded and extracted SRR2407653.fna
# ☁️ Uploaded to Drive: SRR2407653.fna
#
# [4402/5278] Processing SRR3295946...
# ✅ Downloaded and extracted SRR3295946.fna
# ☁️ Uploaded to Drive: SRR3295946.fna
#
# [4403/5278] Processing SRR3765177...
# ✅ Downloaded and extracted SRR3765177.fna
# ☁️ Uploaded to Drive: SRR3765177.fna
#
# [4404/5278] Processing SRR1300555...
# ✅ Downloaded and extracted SRR1300555.fna
# ☁️ Uploaded to Drive: SRR1300555.fna
#
# [4405/5278] Processing SRR2567177...
# ✅ Downloaded and extracted SRR2567177.fna
# ☁️ Uploaded to Drive: SRR2567177.fna
#
# [4406/5278] Processing SRR1576018...
# ✅ Downloaded and extracted SRR1576018.fna
# ☁️ Uploaded to Drive: SRR1576018.fna
#
# [4407/5278] Processing SRR3295636...
# ✅ Downloaded and extracted SRR3295636.fna
# ☁️ Uploaded to Drive: SRR3295636.fna
#
# [4408/5278] Processing SRR1778020...
# ✅ Downloaded and extracted SRR1778020.fna
# ☁️ Uploaded to Drive: SRR1778020.fna
#
# [4409/5278] Processing SRR2962358...
# ✅ Downloaded and extracted SRR2962358.fna
# ☁️ Uploaded to Drive: SRR2962358.fna
#
# [4410/5278] Processing SRR3665065...
# ✅ Downloaded and extracted SRR3665065.fna
# ☁️ Uploaded to Drive: SRR3665065.fna
#
# [4411/5278] Processing SRR3116154...
# ✅ Downloaded and extracted SRR3116154.fna
# ☁️ Uploaded to Drive: SRR3116154.fna
#
# [4412/5278] Processing SRR3295947...
# ✅ Downloaded and extracted SRR3295947.fna
# ☁️ Uploaded to Drive: SRR3295947.fna
#
# [4413/5278] Processing SRR2002481...
# ✅ Downloaded and extracted SRR2002481.fna
# ☁️ Uploaded to Drive: SRR2002481.fna
#
# [4414/5278] Processing SRR1778032...
# ✅ Downloaded and extracted SRR1778032.fna
# ☁️ Uploaded to Drive: SRR1778032.fna
#
# [4415/5278] Processing SRR2407654...
# ✅ Downloaded and extracted SRR2407654.fna
# ☁️ Uploaded to Drive: SRR2407654.fna
#
# [4416/5278] Processing SRR1582149...
# ✅ Downloaded and extracted SRR1582149.fna
# ☁️ Uploaded to Drive: SRR1582149.fna
#
# [4417/5278] Processing SRR3210392...
# ✅ Downloaded and extracted SRR3210392.fna
# ☁️ Uploaded to Drive: SRR3210392.fna
#
# [4418/5278] Processing SRR3295637...
# ✅ Downloaded and extracted SRR3295637.fna
# ...
#
# [5142/5278] Processing SRR1631187...
# ✅ Downloaded and extracted SRR1631187.fna
# ☁️ Uploaded to Drive: SRR1631187.fna
#
# [5143/5278] Processing SRR2993936...
# ✅ Downloaded and extracted SRR2993936.fna
# ☁️ Uploaded to Drive: SRR2993936.fna
#
# [5144/5278] Processing SRR1363301...
# ✅ Downloaded and extracted SRR1363301.fna
# ☁️ Uploaded to Drive: SRR1363301.fna
#
# [5145/5278] Processing SRR2993937...
# ✅ Downloaded and extracted SRR2993937.fna
# ☁️ Uploaded to Drive: SRR2993937.fna
#
# [5146/5278] Processing SRR1363303...
# ✅ Downloaded and extracted SRR1363303.fna
# ☁️ Uploaded to Drive: SRR1363303.fna
#
# [5147/5278] Processing SRR2993938...
# ✅ Downloaded and extracted SRR2993938.fna
# ☁️ Uploaded to Drive: SRR2993938.fna
#
# [5148/5278] Processing SRR2999646...
# ✅ Downloaded and extracted SRR2999646.fna
# ☁️ Uploaded to Drive: SRR2999646.fna
#
# [5149/5278] Processing SRR1363307...
# ✅ Downloaded and extracted SRR1363307.fna
# ☁️ Uploaded to Drive: SRR1363307.fna
#
# [5150/5278] Processing SRR2999647...
# ✅ Downloaded and extracted SRR2999647.fna
# ☁️ Uploaded to Drive: SRR2999647.fna
#
# [5151/5278] Processing SRR1363308...
# ✅ Downloaded and extracted SRR1363308.fna
# ☁️ Uploaded to Drive: SRR1363308.fna
#
# [5152/5278] Processing SRR1363310...
# ✅ Downloaded and extracted SRR1363310.fna
# ☁️ Uploaded to Drive: SRR1363310.fna
#
# [5153/5278] Processing SRR2999648...
# ✅ Downloaded and extracted SRR2999648.fna
# ☁️ Uploaded to Drive: SRR2999648.fna
#
# [5154/5278] Processing SRR1363311...
# ✅ Downloaded and extracted SRR1363311.fna
# ☁️ Uploaded to Drive: SRR1363311.fna
#
# [5155/5278] Processing SRR2999649...
# ✅ Downloaded and extracted SRR2999649.fna
# ☁️ Uploaded to Drive: SRR2999649.fna
#
# [5156/5278] Processing SRR2999650...
# ✅ Downloaded and extracted SRR2999650.fna
# ☁️ Uploaded to Drive: SRR2999650.fna
#
# [5157/5278] Processing SRR2999651...
# ✅ Downloaded and extracted SRR2999651.fna
# ☁️ Uploaded to Drive: SRR2999651.fna
#
# [5158/5278] Processing SRR1363313...
# ✅ Downloaded and extracted SRR1363313.fna
# ☁️ Uploaded to Drive: SRR1363313.fna
#
# [5159/5278] Processing SRR2999652...
# ✅ Downloaded and extracted SRR2999652.fna
# ☁️ Uploaded to Drive: SRR2999652.fna
#
# [5160/5278] Processing SRR3021486...
# ✅ Downloaded and extracted SRR3021486.fna
# ☁️ Uploaded to Drive: SRR3021486.fna
#
# [5161/5278] Processing SRR1363314...
# ✅ Downloaded and extracted SRR1363314.fna
# ☁️ Uploaded to Drive: SRR1363314.fna
#
# [5162/5278] Processing SRR3021487...
# ✅ Downloaded and extracted SRR3021487.fna
# ☁️ Uploaded to Drive: SRR3021487.fna
#
# [5163/5278] Processing SRR1363315...
# ✅ Downloaded and extracted SRR1363315.fna
# ☁️ Uploaded to Drive: SRR1363315.fna
#
# [5164/5278] Processing SRR1363316...
# ✅ Downloaded and extracted SRR1363316.fna
# ☁️ Uploaded to Drive: SRR1363316.fna
#
# [5165/5278] Processing SRR3021488...
# ✅ Downloaded and extracted SRR3021488.fna
# ☁️ Uploaded to Drive: SRR3021488.fna
#
# [5166/5278] Processing SRR1363326...
# ✅ Downloaded and extracted SRR1363326.fna
# ☁️ Uploaded to Drive: SRR1363326.fna
#
# [5167/5278] Processing SRR3021489...
# ✅ Downloaded and extracted SRR3021489.fna
# ☁️ Uploaded to Drive: SRR3021489.fna
#
# [5168/5278] Processing SRR1363328...
# ✅ Downloaded and extracted SRR1363328.fna
# ☁️ Uploaded to Drive: SRR1363328.fna
#
# [5169/5278] Processing SRR3021490...
# ✅ Downloaded and extracted SRR3021490.fna
# ☁️ Uploaded to Drive: SRR3021490.fna
#
# [5170/5278] Processing SRR1363330...
# ✅ Downloaded and extracted SRR1363330.fna
# ☁️ Uploaded to Drive: SRR1363330.fna
#
# [5171/5278] Processing SRR1363331...
# ✅ Downloaded and extracted SRR1363331.fna
# ☁️ Uploaded to Drive: SRR1363331.fna
#
# [5172/5278] Processing SRR3021491...
# ✅ Downloaded and extracted SRR3021491.fna
# ☁️ Uploaded to Drive: SRR3021491.fna
#
# [5173/5278] Processing SRR1363339...
# ✅ Downloaded and extracted SRR1363339.fna
# ☁️ Uploaded to Drive: SRR1363339.fna
#
# [5174/5278] Processing SRR3021492...
# ✅ Downloaded and extracted SRR3021492.fna
# ☁️ Uploaded to Drive: SRR3021492.fna
#
# [5175/5278] Processing SRR1363342...
# ✅ Downloaded and extracted SRR1363342.fna
# ☁️ Uploaded to Drive: SRR1363342.fna
#
# [5176/5278] Processing SRR3021493...
# ✅ Downloaded and extracted SRR3021493.fna
# ☁️ Uploaded to Drive: SRR3021493.fna
#
# [5177/5278] Processing SRR1363345...
# ✅ Downloaded and extracted SRR1363345.fna
# ☁️ Uploaded to Drive: SRR1363345.fna
#
# [5178/5278] Processing SRR3021494...
# ✅ Downloaded and extracted SRR3021494.fna
# ☁️ Uploaded to Drive: SRR3021494.fna
#
# [5179/5278] Processing SRR1363348...
# ✅ Downloaded and extracted SRR1363348.fna
# ☁️ Uploaded to Drive: SRR1363348.fna
#
# [5180/5278] Processing SRR3021495...
# ✅ Downloaded and extracted SRR3021495.fna
# ☁️ Uploaded to Drive: SRR3021495.fna
#
# [5181/5278] Processing SRR1448877...
# ✅ Downloaded and extracted SRR1448877.fna
# ☁️ Uploaded to Drive: SRR1448877.fna
#
# [5182/5278] Processing SRR3045969...
# ✅ Downloaded and extracted SRR3045969.fna
# ☁️ Uploaded to Drive: SRR3045969.fna
#
# [5183/5278] Processing SRR1448884...
# ✅ Downloaded and extracted SRR1448884.fna
# ☁️ Uploaded to Drive: SRR1448884.fna
#
# [5184/5278] Processing SRR3045970...
# ✅ Downloaded and extracted SRR3045970.fna
# ☁️ Uploaded to Drive: SRR3045970.fna
#
# [5185/5278] Processing SRR3045972...
# ✅ Downloaded and extracted SRR3045972.fna
# ☁️ Uploaded to Drive: SRR3045972.fna
#
# [5186/5278] Processing SRR1514699...
# ✅ Downloaded and extracted SRR1514699.fna
# ☁️ Uploaded to Drive: SRR1514699.fna
#
# [5187/5278] Processing SRR1514700...
# ✅ Downloaded and extracted SRR1514700.fna
# ☁️ Uploaded to Drive: SRR1514700.fna
#
# [5188/5278] Processing SRR3045973...
# ✅ Downloaded and extracted SRR3045973.fna
# ☁️ Uploaded to Drive: SRR3045973.fna
#
# [5189/5278] Processing SRR1514713...
# ✅ Downloaded and extracted SRR1514713.fna
# ☁️ Uploaded to Drive: SRR1514713.fna
#
# [5190/5278] Processing SRR3045974...
# ✅ Downloaded and extracted SRR3045974.fna
# ☁️ Uploaded to Drive: SRR3045974.fna
#
# [5191/5278] Processing SRR1514719...
# ✅ Downloaded and extracted SRR1514719.fna
# ☁️ Uploaded to Drive: SRR1514719.fna
#
# [5192/5278] Processing SRR3045975...
# ✅ Downloaded and extracted SRR3045975.fna
# ☁️ Uploaded to Drive: SRR3045975.fna
#
# [5193/5278] Processing SRR1514721...
# ✅ Downloaded and extracted SRR1514721.fna
# ☁️ Uploaded to Drive: SRR1514721.fna
#
# [5194/5278] Processing SRR3045976...
# ✅ Downloaded and extracted SRR3045976.fna
# ☁️ Uploaded to Drive: SRR3045976.fna
#
# [5195/5278] Processing SRR1514723...
# ✅ Downloaded and extracted SRR1514723.fna
# ☁️ Uploaded to Drive: SRR1514723.fna
#
# [5196/5278] Processing SRR3045977...
# ❌ No assembly found for SAMN04256026
#
# [5197/5278] Processing SRR1514724...
# ✅ Downloaded and extracted SRR1514724.fna
# ☁️ Uploaded to Drive: SRR1514724.fna
#
# [5198/5278] Processing SRR3045981...
# ✅ Downloaded and extracted SRR3045981.fna
# ☁️ Uploaded to Drive: SRR3045981.fna
#
# [5199/5278] Processing SRR1514740...
# ✅ Downloaded and extracted SRR1514740.fna
# ☁️ Uploaded to Drive: SRR1514740.fna
#
# [5200/5278] Processing SRR3045983...
# ✅ Downloaded and extracted SRR3045983.fna
# ☁️ Uploaded to Drive: SRR3045983.fna
#
# [5201/5278] Processing SRR1514742...
# ✅ Downloaded and extracted SRR1514742.fna
# ☁️ Uploaded to Drive: SRR1514742.fna
#
# [5202/5278] Processing SRR3045984...
# ✅ Downloaded and extracted SRR3045984.fna
# ☁️ Uploaded to Drive: SRR3045984.fna
#
# [5203/5278] Processing SRR1514746...
# ✅ Downloaded and extracted SRR1514746.fna
# ☁️ Uploaded to Drive: SRR1514746.fna
#
# [5204/5278] Processing SRR1514750...
# ✅ Downloaded and extracted SRR1514750.fna
# ☁️ Uploaded to Drive: SRR1514750.fna
#
# [5205/5278] Processing SRR3052017...
# ✅ Downloaded and extracted SRR3052017.fna
# ☁️ Uploaded to Drive: SRR3052017.fna
#
# [5206/5278] Processing SRR1514768...
# ✅ Downloaded and extracted SRR1514768.fna
# ☁️ Uploaded to Drive: SRR1514768.fna
#
# [5207/5278] Processing SRR3052018...
# ✅ Downloaded and extracted SRR3052018.fna
# ☁️ Uploaded to Drive: SRR3052018.fna
#
# [5208/5278] Processing SRR3052019...
# ✅ Downloaded and extracted SRR3052019.fna
# ☁️ Uploaded to Drive: SRR3052019.fna
#
# [5209/5278] Processing SRR3052020...
# ✅ Downloaded and extracted SRR3052020.fna
# ☁️ Uploaded to Drive: SRR3052020.fna
#
# [5210/5278] Processing SRR1521518...
# ✅ Downloaded and extracted SRR1521518.fna
# ☁️ Uploaded to Drive: SRR1521518.fna
#
# [5211/5278] Processing SRR3052021...
# ✅ Downloaded and extracted SRR3052021.fna
# ☁️ Uploaded to Drive: SRR3052021.fna
#
# [5212/5278] Processing SRR3052022...
# ✅ Downloaded and extracted SRR3052022.fna
# ☁️ Uploaded to Drive: SRR3052022.fna
#
# [5213/5278] Processing SRR3052023...
# ✅ Downloaded and extracted SRR3052023.fna
# ☁️ Uploaded to Drive: SRR3052023.fna
#
# [5214/5278] Processing SRR3052024...
# ✅ Downloaded and extracted SRR3052024.fna
# ☁️ Uploaded to Drive: SRR3052024.fna
#
# [5215/5278] Processing SRR3052025...
# ✅ Downloaded and extracted SRR3052025.fna
# ☁️ Uploaded to Drive: SRR3052025.fna
#
# [5216/5278] Processing SRR3052026...
# ✅ Downloaded and extracted SRR3052026.fna
# ☁️ Uploaded to Drive: SRR3052026.fna
#
# [5217/5278] Processing SRR3052027...
# ✅ Downloaded and extracted SRR3052027.fna
# ☁️ Uploaded to Drive: SRR3052027.fna
#
# [5218/5278] Processing SRR3052028...
# ✅ Downloaded and extracted SRR3052028.fna
# ☁️ Uploaded to Drive: SRR3052028.fna
#
# [5219/5278] Processing SRR3052029...
# ✅ Downloaded and extracted SRR3052029.fna
# ☁️ Uploaded to Drive: SRR3052029.fna
#
# [5220/5278] Processing SRR3052030...
# ✅ Downloaded and extracted SRR3052030.fna
# ☁️ Uploaded to Drive: SRR3052030.fna
#
# [5221/5278] Processing SRR3055284...
# ✅ Downloaded and extracted SRR3055284.fna
# ☁️ Uploaded to Drive: SRR3055284.fna
#
# [5222/5278] Processing SRR3055287...
# ✅ Downloaded and extracted SRR3055287.fna
# ☁️ Uploaded to Drive: SRR3055287.fna
#
# [5223/5278] Processing SRR3055288...
# ✅ Downloaded and extracted SRR3055288.fna
# ☁️ Uploaded to Drive: SRR3055288.fna
#
# [5224/5278] Processing SRR3055289...
# ✅ Downloaded and extracted SRR3055289.fna
# ☁️ Uploaded to Drive: SRR3055289.fna
#
# [5225/5278] Processing SRR3055290...
# ✅ Downloaded and extracted SRR3055290.fna
# ☁️ Uploaded to Drive: SRR3055290.fna
#
# [5226/5278] Processing SRR2078282...
# ✅ Downloaded and extracted SRR2078282.fna
# ☁️ Uploaded to Drive: SRR2078282.fna
#
# [5227/5278] Processing SRR2566991...
# ✅ Downloaded and extracted SRR2566991.fna
# ☁️ Uploaded to Drive: SRR2566991.fna
#
# [5228/5278] Processing SRR1646947...
# ✅ Downloaded and extracted SRR1646947.fna
# ☁️ Uploaded to Drive: SRR1646947.fna
#
# [5229/5278] Processing SRR3295749...
# ✅ Downloaded and extracted SRR3295749.fna
# ☁️ Uploaded to Drive: SRR3295749.fna
#
# [5230/5278] Processing SRR1534885...
# ✅ Downloaded and extracted SRR1534885.fna
# ☁️ Uploaded to Drive: SRR1534885.fna
#
# [5231/5278] Processing SRR2566994...
# ✅ Downloaded and extracted SRR2566994.fna
# ☁️ Uploaded to Drive: SRR2566994.fna
#
# [5232/5278] Processing SRR3665180...
# ✅ Downloaded and extracted SRR3665180.fna
# ☁️ Uploaded to Drive: SRR3665180.fna
#
# [5233/5278] Processing SRR1637043...
# ✅ Downloaded and extracted SRR1637043.fna
# ☁️ Uploaded to Drive: SRR1637043.fna
#
# [5234/5278] Processing SRR3664696...
# ✅ Downloaded and extracted SRR3664696.fna
# ☁️ Uploaded to Drive: SRR3664696.fna
#
# [5235/5278] Processing SRR3509885...
# ✅ Downloaded and extracted SRR3509885.fna
# ☁️ Uploaded to Drive: SRR3509885.fna
#
# [5236/5278] Processing SRR2407715...
# ✅ Downloaded and extracted SRR2407715.fna
# ☁️ Uploaded to Drive: SRR2407715.fna
#
# [5237/5278] Processing SRR3665096...
# ✅ Downloaded and extracted SRR3665096.fna
# ☁️ Uploaded to Drive: SRR3665096.fna
#
# [5238/5278] Processing SRR3330244...
# ✅ Downloaded and extracted SRR3330244.fna
# ☁️ Uploaded to Drive: SRR3330244.fna
#
# [5239/5278] Processing SRR2566926...
# ✅ Downloaded and extracted SRR2566926.fna
# ☁️ Uploaded to Drive: SRR2566926.fna
#
# [5240/5278] Processing SRR2566925...
# ✅ Downloaded and extracted SRR2566925.fna
# ☁️ Uploaded to Drive: SRR2566925.fna
#
# [5241/5278] Processing SRR1177360...
# ✅ Downloaded and extracted SRR1177360.fna
# ☁️ Uploaded to Drive: SRR1177360.fna
#
# [5242/5278] Processing SRR2064125...
# ✅ Downloaded and extracted SRR2064125.fna
# ☁️ Uploaded to Drive: SRR2064125.fna
#
# [5243/5278] Processing SRR1812835...
# ✅ Downloaded and extracted SRR1812835.fna
# ☁️ Uploaded to Drive: SRR1812835.fna
#
# [5244/5278] Processing SRR3224089...
# ✅ Downloaded and extracted SRR3224089.fna
# ☁️ Uploaded to Drive: SRR3224089.fna
#
# [5245/5278] Processing SRR1812858...
# ✅ Downloaded and extracted SRR1812858.fna
# ☁️ Uploaded to Drive: SRR1812858.fna
#
# [5246/5278] Processing SRR2407775...
# ✅ Downloaded and extracted SRR2407775.fna
# ☁️ Uploaded to Drive: SRR2407775.fna
#
# [5247/5278] Processing SRR3091332...
# ✅ Downloaded and extracted SRR3091332.fna
# ☁️ Uploaded to Drive: SRR3091332.fna
#
# [5248/5278] Processing SRR3091340...
# ✅ Downloaded and extracted SRR3091340.fna
# ☁️ Uploaded to Drive: SRR3091340.fna
#
# [5249/5278] Processing SRR1195671...
# ✅ Downloaded and extracted SRR1195671.fna
# ☁️ Uploaded to Drive: SRR1195671.fna
#
# [5250/5278] Processing SRR3295734...
# ✅ Downloaded and extracted SRR3295734.fna
# ☁️ Uploaded to Drive: SRR3295734.fna
#
# [5251/5278] Processing SRR1822310...
# ✅ Downloaded and extracted SRR1822310.fna
# ☁️ Uploaded to Drive: SRR1822310.fna
#
# [5252/5278] Processing SRR3933000...
# ✅ Downloaded and extracted SRR3933000.fna
# ☁️ Uploaded to Drive: SRR3933000.fna
#
# [5253/5278] Processing SRR3295751...
# ✅ Downloaded and extracted SRR3295751.fna
# ☁️ Uploaded to Drive: SRR3295751.fna
#
# [5254/5278] Processing SRR2082840...
# ✅ Downloaded and extracted SRR2082840.fna
# ☁️ Uploaded to Drive: SRR2082840.fna
#
# [5255/5278] Processing SRR3173555...
# ✅ Downloaded and extracted SRR3173555.fna
# ☁️ Uploaded to Drive: SRR3173555.fna
#
# [5256/5278] Processing SRR2648198...
# ✅ Downloaded and extracted SRR2648198.fna
# ☁️ Uploaded to Drive: SRR2648198.fna
#
# [5257/5278] Processing SRR1534888...
# ✅ Downloaded and extracted SRR1534888.fna
# ☁️ Uploaded to Drive: SRR1534888.fna
#
# [5258/5278] Processing SRR3096031...
# ✅ Downloaded and extracted SRR3096031.fna
# ☁️ Uploaded to Drive: SRR3096031.fna
#
# [5259/5278] Processing SRR3664856...
# ✅ Downloaded and extracted SRR3664856.fna
# ☁️ Uploaded to Drive: SRR3664856.fna
#
# [5260/5278] Processing SRR2566995...
# ✅ Downloaded and extracted SRR2566995.fna
# ☁️ Uploaded to Drive: SRR2566995.fna
#
# [5261/5278] Processing SRR3933001...
# ✅ Downloaded and extracted SRR3933001.fna
# ☁️ Uploaded to Drive: SRR3933001.fna
#
# [5262/5278] Processing SRR3242343...
# ✅ Downloaded and extracted SRR3242343.fna
# ☁️ Uploaded to Drive: SRR3242343.fna
#
# [5263/5278] Processing SRR3664857...
# ✅ Downloaded and extracted SRR3664857.fna
# ☁️ Uploaded to Drive: SRR3664857.fna
#
# [5264/5278] Processing SRR3295752...
# ✅ Downloaded and extracted SRR3295752.fna
# ☁️ Uploaded to Drive: SRR3295752.fna
#
# [5265/5278] Processing SRR3933002...
# ✅ Downloaded and extracted SRR3933002.fna
# ☁️ Uploaded to Drive: SRR3933002.fna
#
# [5266/5278] Processing SRR2532633...
# ✅ Downloaded and extracted SRR2532633.fna
# ☁️ Uploaded to Drive: SRR2532633.fna
#
# [5267/5278] Processing SRR2082856...
# ✅ Downloaded and extracted SRR2082856.fna
# ☁️ Uploaded to Drive: SRR2082856.fna
#
# [5268/5278] Processing SRR3242352...
# ✅ Downloaded and extracted SRR3242352.fna
# ☁️ Uploaded to Drive: SRR3242352.fna
#
# [5269/5278] Processing SRR3242362...
# ✅ Downloaded and extracted SRR3242362.fna
# ☁️ Uploaded to Drive: SRR3242362.fna
#
# [5270/5278] Processing SRR2567060...
# ✅ Downloaded and extracted SRR2567060.fna
# ☁️ Uploaded to Drive: SRR2567060.fna
#
# [5271/5278] Processing SRR3933079...
# ✅ Downloaded and extracted SRR3933079.fna
# ☁️ Uploaded to Drive: SRR3933079.fna
#
# [5272/5278] Processing SRR1257300...
# ✅ Downloaded and extracted SRR1257300.fna
# ☁️ Uploaded to Drive: SRR1257300.fna
#
# [5273/5278] Processing SRR4280580...
# ✅ Downloaded and extracted SRR4280580.fna
# ☁️ Uploaded to Drive: SRR4280580.fna
#
# [5274/5278] Processing SRR2407576...
# ✅ Downloaded and extracted SRR2407576.fna
# ☁️ Uploaded to Drive: SRR2407576.fna
#
# [5275/5278] Processing SRR2567127...
# ✅ Downloaded and extracted SRR2567127.fna
# ☁️ Uploaded to Drive: SRR2567127.fna
#
# [5276/5278] Processing SRR4280588...
# ✅ Downloaded and extracted SRR4280588.fna
# ☁️ Uploaded to Drive: SRR4280588.fna
#
# [5277/5278] Processing SRR3295553...
# ✅ Downloaded and extracted SRR3295553.fna
# ☁️ Uploaded to Drive: SRR3295553.fna
#
# [5278/5278] Processing SRR3664859...
# ✅ Downloaded and extracted SRR3664859.fna
# ☁️ Uploaded to Drive: SRR3664859.fna

# %% [markdown]
# # Mycobacterium tuberculosis

# %%
# !pip install biopython openpyxl requests

import os
import gzip
import shutil
import requests
import pandas as pd
from Bio import Entrez
from google.colab import drive

# 🔧 Configuration
Entrez.email = "s-salma.hatem@zewailcity.edu.eg"
excel_file = "master_table_resistance - Copy.csv"
sample_column = "accessions"
output_dir = "/content/fasta_downloads"
drive_dir = "/content/drive/MyDrive/Ncbi_Fasta_Downloads"

# %%
import os
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/MRSA datasets/Datasets/Mycobacterium tuberculosis/PRJNA343736')
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/13LGqe__ULhjG0hZmpgxz8WqE0fNXsVNQ/MRSA datasets/Datasets/Mycobacterium tuberculosis/PRJNA343736

# %%
# !pip install biopython openpyxl requests

import os
import gzip
import shutil
import requests
import pandas as pd
from Bio import Entrez
from google.colab import drive

# 🔧 Configuration
Entrez.email = "s-salma.hatem@zewailcity.edu.eg"
excel_file = "master_table_resistance.csv"
sample_column = "accessions"
output_dir = "/content/fasta_downloads"
drive_dir = "/content/drive/My Drive/MRSA datasets/Datasets/Mycobacterium tuberculosis/PRJNA343736"

# 📂 Mount Google Drive
drive.mount('/content/drive')
os.makedirs(output_dir, exist_ok=True)
os.makedirs(drive_dir, exist_ok=True)

# 🧾 Read sample accessions from Excel
def get_sample_accessions(file):
    df = pd.read_csv(file)
    if sample_column not in df.columns:
        raise ValueError(f"Column '{sample_column}' not found.")
    return df[sample_column].dropna().astype(str).unique().tolist()

# 🔗 Sample ➝ Assembly ➝ FTP path
def get_assembly_ftp_from_ncbi(sample_accession):
    try:
        handle = Entrez.esearch(db="assembly", term=f"{sample_accession}[Sample]", retmax=1)
        result = Entrez.read(handle)
        if not result["IdList"]:
            print(f"❌ No assembly found for {sample_accession}")
            return None

        assembly_id = result["IdList"][0]
        handle = Entrez.esummary(db="assembly", id=assembly_id, report="full")
        summary = Entrez.read(handle)
        doc = summary["DocumentSummarySet"]["DocumentSummary"][0]

        ftp_path = doc["FtpPath_RefSeq"] or doc["FtpPath_GenBank"]
        return ftp_path
    except Exception as e:
        print(f"❌ FTP path error for {sample_accession}: {e}")
        return None

# ⬇️ Download and extract .fna.gz
def download_fna_file(ftp_path, sample_id):
    try:
        base = ftp_path.split("/")[-1]
        url = f"{ftp_path}/{base}_genomic.fna.gz"
        gz_path = os.path.join(output_dir, f"{sample_id}.fna.gz")
        out_path = os.path.join(output_dir, f"{sample_id}.fna")

        os.system(f"wget -q -O {gz_path} {url}")

        # Validate gzip
        with open(gz_path, 'rb') as test_f:
            if test_f.read(2) != b'\x1f\x8b':
                raise ValueError("Invalid .gz file (probably a 404 page).")

        with gzip.open(gz_path, 'rb') as f_in, open(out_path, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
        os.remove(gz_path)
        print(f"✅ Downloaded and extracted: {sample_id}.fna")
        return out_path
    except Exception as e:
        print(f"❌ Download error for {sample_id}: {e}")
        if os.path.exists(gz_path):
            os.remove(gz_path)
        return None

# ☁️ Upload to Google Drive
def upload_to_drive(filepath):
    try:
        dest = os.path.join(drive_dir, os.path.basename(filepath))
        shutil.copy(filepath, dest)
        print(f"☁️ Uploaded to Drive: {os.path.basename(filepath)}")
    except Exception as e:
        print(f"❌ Upload error: {e}")

# ▶️ Main runner (goal: 5000 total files in Drive)
def process_samples():
    sample_ids = get_sample_accessions(excel_file)
    print(f"🔍 Found {len(sample_ids)} sample accessions")

    # Count existing files in Drive
    existing_files = [f for f in os.listdir(drive_dir) if f.endswith(".fna")]
    existing_count = len(existing_files)
    print(f"📁 {existing_count} files already exist in Drive.")

    max_total = 5000
    needed = max_total - existing_count

    if needed <= 0:
        print("✅ Already have 5000 or more files in Drive. No download needed.")
        return

    print(f"🚀 Attempting to download {needed} more files to reach 5000.")

    success_count = 0

    for idx, sample_id in enumerate(sample_ids, 1):
        if success_count >= needed:
            break

        print(f"\n[{idx}/{len(sample_ids)}] Processing: {sample_id}")

        drive_file_path = os.path.join(drive_dir, f"{sample_id}.fna")
        if os.path.exists(drive_file_path):
            print(f"⏭️ Skipping {sample_id} — already exists in Drive.")
            continue

        ftp_path = get_assembly_ftp_from_ncbi(sample_id)
        if not ftp_path:
            continue

        fna_file = download_fna_file(ftp_path, sample_id)
        if fna_file:
            upload_to_drive(fna_file)
            success_count += 1
            print(f"📦 Total new downloads this session: {success_count}")

    print(f"\n✅ Finished. Total files in Drive should now be: {existing_count + success_count}")


# 🚀 Run the pipeline
process_samples()

# %% [markdown]
# # Escherichia coli

# %%
import os
import urllib.request
import pandas as pd
from google.colab import drive
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed

# 🔧 CONFIGURATION
csv_file_path = "PATRIC_e.coli.xlsx"  # Change to your file name
column_name = "Genome ID"
local_download_dir = "/content/genome_fna_files"
drive_mount_path = "/content/drive"
drive_target_dir = os.path.join(drive_mount_path, "My Drive/MRSA datasets/Datasets/Escherichia coli/PATRIC_e.coli")
MAX_WORKERS = 5  # 🔁 Number of parallel downloads (adjust based on performance)

# 📂 Mount Google Drive
drive.mount(drive_mount_path)
os.makedirs(local_download_dir, exist_ok=True)
os.makedirs(drive_target_dir, exist_ok=True)

# 📄 Load genome IDs
df = pd.read_excel(csv_file_path)
genome_ids = df[column_name].dropna().astype(str).unique()
print(f"🔍 Found {len(genome_ids)} genome IDs to process.")

# 🔁 Function for downloading and uploading
def download_and_upload(genome_id):
    file_name = f"{genome_id}.fna"
    ftp_url = f"ftp://ftp.patricbrc.org/genomes/{genome_id}/{file_name}"
    local_path = os.path.join(local_download_dir, file_name)
    drive_path = os.path.join(drive_target_dir, file_name)

    if os.path.exists(drive_path):
        return f"☁️ Skipping {file_name} — already in Drive."

    try:
        # ⬇️ Download
        urllib.request.urlretrieve(ftp_url, local_path)

        # ☁️ Copy to Drive
        shutil.copy(local_path, drive_path)

        # 🧹 Remove local file
        os.remove(local_path)

        return f"✅ Downloaded and uploaded: {file_name}"
    except Exception as e:
        return f"❌ Failed for {genome_id}: {e}"

# 🚀 Run downloads concurrently
results = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_id = {executor.submit(download_and_upload, gid): gid for gid in genome_ids}
    for i, future in enumerate(as_completed(future_to_id), 1):
        result = future.result()
        print(f"[{i}/{len(genome_ids)}] {result}")

# 🔄 Ensure everything is synced
drive.flush_and_unmount()

# %% [markdown]
# # Staphylococcus aureus

# %%
import os
import urllib.request
import pandas as pd
from google.colab import drive
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed

# 🔧 CONFIGURATION
csv_file_path = "PATRIC_genomes.csv"  # Change to your file name
column_name = "genome_id"
local_download_dir = "/content/genome_fna_files"
drive_mount_path = "/content/drive"
drive_target_dir = os.path.join(drive_mount_path, "My Drive/MRSA datasets/Datasets/Staphylococcus aureus/PATRIC_genomes")
MAX_WORKERS = 5  # 🔁 Number of parallel downloads (adjust based on performance)

# 📂 Mount Google Drive
drive.mount(drive_mount_path)
os.makedirs(local_download_dir, exist_ok=True)
os.makedirs(drive_target_dir, exist_ok=True)

# 📄 Load genome IDs
df = pd.read_csv(csv_file_path)
genome_ids = df[column_name].dropna().astype(str).unique()
print(f"🔍 Found {len(genome_ids)} genome IDs to process.")

# 🔁 Function for downloading and uploading
def download_and_upload(genome_id):
    file_name = f"{genome_id}.fna"
    ftp_url = f"ftp://ftp.patricbrc.org/genomes/{genome_id}/{file_name}"
    local_path = os.path.join(local_download_dir, file_name)
    drive_path = os.path.join(drive_target_dir, file_name)

    if os.path.exists(drive_path):
        return f"☁️ Skipping {file_name} — already in Drive."

    try:
        # ⬇️ Download
        urllib.request.urlretrieve(ftp_url, local_path)

        # ☁️ Copy to Drive
        shutil.copy(local_path, drive_path)

        # 🧹 Remove local file
        os.remove(local_path)

        return f"✅ Downloaded and uploaded: {file_name}"
    except Exception as e:
        return f"❌ Failed for {genome_id}: {e}"

# 🚀 Run downloads concurrently
results = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_id = {executor.submit(download_and_upload, gid): gid for gid in genome_ids}
    for i, future in enumerate(as_completed(future_to_id), 1):
        result = future.result()
        print(f"[{i}/{len(genome_ids)}] {result}")

# 🔄 Ensure everything is synced
drive.flush_and_unmount()
# Out:
# Streaming output truncated to the last 5000 lines.
# [771/5770] ☁️ Skipping 1280.25102.fna — already in Drive.
# [772/5770] ☁️ Skipping 1280.25103.fna — already in Drive.
# [773/5770] ☁️ Skipping 1280.25104.fna — already in Drive.
# [774/5770] ☁️ Skipping 1280.25101.fna — already in Drive.
# [775/5770] ☁️ Skipping 1280.25106.fna — already in Drive.
# [776/5770] ☁️ Skipping 1280.25107.fna — already in Drive.
# [777/5770] ☁️ Skipping 1280.25105.fna — already in Drive.
# [778/5770] ☁️ Skipping 1280.25108.fna — already in Drive.
# [779/5770] ☁️ Skipping 1280.25111.fna — already in Drive.
# [780/5770] ☁️ Skipping 1280.25109.fna — already in Drive.
# [781/5770] ☁️ Skipping 1280.25112.fna — already in Drive.
# [782/5770] ☁️ Skipping 1280.25113.fna — already in Drive.
# [783/5770] ☁️ Skipping 1280.25115.fna — already in Drive.
# [784/5770] ☁️ Skipping 1280.25114.fna — already in Drive.
# [785/5770] ☁️ Skipping 1280.25117.fna — already in Drive.
# [786/5770] ☁️ Skipping 1280.25116.fna — already in Drive.
# [787/5770] ☁️ Skipping 1280.25118.fna — already in Drive.
# [788/5770] ☁️ Skipping 1280.25119.fna — already in Drive.
# [789/5770] ☁️ Skipping 1280.25121.fna — already in Drive.
# [790/5770] ☁️ Skipping 1280.25122.fna — already in Drive.
# [791/5770] ☁️ Skipping 1280.25123.fna — already in Drive.
# [792/5770] ☁️ Skipping 1280.25124.fna — already in Drive.
# [793/5770] ☁️ Skipping 1280.25125.fna — already in Drive.
# [794/5770] ☁️ Skipping 1280.25126.fna — already in Drive.
# [795/5770] ☁️ Skipping 1280.25127.fna — already in Drive.
# [796/5770] ☁️ Skipping 1280.25128.fna — already in Drive.
# [797/5770] ☁️ Skipping 1280.25129.fna — already in Drive.
# [798/5770] ❌ Failed for 1280.2513: <urlopen error 550 genomes/1280.2513: No such file or directory>
# [799/5770] ❌ Failed for 1280.251: <urlopen error 550 genomes/1280.251: No such file or directory>
# [800/5770] ❌ Failed for 1280.2511: <urlopen error 550 genomes/1280.2511: No such file or directory>
# [801/5770] ❌ Failed for 1280.2512: <urlopen error 550 genomes/1280.2512: No such file or directory>
# [802/5770] ☁️ Skipping 1280.25132.fna — already in Drive.
# [803/5770] ❌ Failed for 1280.2509: <urlopen error 550 genomes/1280.2509: No such file or directory>
# [804/5770] ☁️ Skipping 1280.25131.fna — already in Drive.
# [805/5770] ☁️ Skipping 1280.25135.fna — already in Drive.
# [806/5770] ☁️ Skipping 1280.25134.fna — already in Drive.
# [807/5770] ☁️ Skipping 1280.25133.fna — already in Drive.
# [808/5770] ☁️ Skipping 1280.25136.fna — already in Drive.
# [809/5770] ☁️ Skipping 1280.25137.fna — already in Drive.
# [810/5770] ☁️ Skipping 1280.25141.fna — already in Drive.
# [811/5770] ☁️ Skipping 1280.25138.fna — already in Drive.
# [812/5770] ☁️ Skipping 1280.25139.fna — already in Drive.
# [813/5770] ☁️ Skipping 1280.25142.fna — already in Drive.
# [814/5770] ☁️ Skipping 1280.25143.fna — already in Drive.
# [815/5770] ☁️ Skipping 1280.25144.fna — already in Drive.
# [816/5770] ☁️ Skipping 1280.25146.fna — already in Drive.
# [817/5770] ☁️ Skipping 1280.25145.fna — already in Drive.
# [818/5770] ☁️ Skipping 1280.25147.fna — already in Drive.
# [819/5770] ☁️ Skipping 1280.25148.fna — already in Drive.
# [820/5770] ☁️ Skipping 1280.25149.fna — already in Drive.
# [821/5770] ☁️ Skipping 1280.25152.fna — already in Drive.
# [822/5770] ☁️ Skipping 1280.25153.fna — already in Drive.
# [823/5770] ☁️ Skipping 1280.25151.fna — already in Drive.
# [824/5770] ☁️ Skipping 1280.25154.fna — already in Drive.
# [825/5770] ☁️ Skipping 1280.25156.fna — already in Drive.
# [826/5770] ☁️ Skipping 1280.25157.fna — already in Drive.
# [827/5770] ☁️ Skipping 1280.25155.fna — already in Drive.
# [828/5770] ☁️ Skipping 1280.25158.fna — already in Drive.
# [829/5770] ☁️ Skipping 1280.25159.fna — already in Drive.
# [830/5770] ☁️ Skipping 1280.25162.fna — already in Drive.
# [831/5770] ☁️ Skipping 1280.25163.fna — already in Drive.
# [832/5770] ☁️ Skipping 1280.25164.fna — already in Drive.
# [833/5770] ☁️ Skipping 1280.25161.fna — already in Drive.
# [834/5770] ☁️ Skipping 1280.25165.fna — already in Drive.
# [835/5770] ☁️ Skipping 1280.25166.fna — already in Drive.
# [836/5770] ☁️ Skipping 1280.25168.fna — already in Drive.
# [837/5770] ☁️ Skipping 1280.25167.fna — already in Drive.
# [838/5770] ☁️ Skipping 1280.25169.fna — already in Drive.
# [839/5770] ☁️ Skipping 1280.25171.fna — already in Drive.
# [840/5770] ☁️ Skipping 1280.25172.fna — already in Drive.
# [841/5770] ☁️ Skipping 1280.25173.fna — already in Drive.
# [842/5770] ☁️ Skipping 1280.25174.fna — already in Drive.
# [843/5770] ☁️ Skipping 1280.25175.fna — already in Drive.
# [844/5770] ☁️ Skipping 1280.25176.fna — already in Drive.
# [845/5770] ☁️ Skipping 1280.25972.fna — already in Drive.
# [846/5770] ☁️ Skipping 1280.25973.fna — already in Drive.
# [847/5770] ☁️ Skipping 1280.25974.fna — already in Drive.
# [848/5770] ☁️ Skipping 1280.25975.fna — already in Drive.
# [849/5770] ☁️ Skipping 1280.25976.fna — already in Drive.
# [850/5770] ☁️ Skipping 1280.25977.fna — already in Drive.
# [851/5770] ☁️ Skipping 1280.25978.fna — already in Drive.
# [852/5770] ☁️ Skipping 1280.25979.fna — already in Drive.
# [853/5770] ❌ Failed for 1280.2515: <urlopen error 550 genomes/1280.2515: No such file or directory>
# [854/5770] ❌ Failed for 1280.2517: <urlopen error 550 genomes/1280.2517: No such file or directory>
# [855/5770] ❌ Failed for 1280.2516: <urlopen error 550 genomes/1280.2516: No such file or directory>
# [856/5770] ❌ Failed for 1280.2598: <urlopen error 550 genomes/1280.2598: No such file or directory>
# [857/5770] ☁️ Skipping 1280.25981.fna — already in Drive.
# [858/5770] ❌ Failed for 1280.2514: <urlopen error 550 genomes/1280.2514: No such file or directory>
# [859/5770] ☁️ Skipping 1280.25982.fna — already in Drive.
# [860/5770] ☁️ Skipping 1280.25984.fna — already in Drive.
# [861/5770] ☁️ Skipping 1280.25983.fna — already in Drive.
# [862/5770] ☁️ Skipping 1280.25986.fna — already in Drive.
# [863/5770] ☁️ Skipping 1280.25987.fna — already in Drive.
# [864/5770] ☁️ Skipping 1280.25985.fna — already in Drive.
# [865/5770] ☁️ Skipping 1280.25988.fna — already in Drive.
# [866/5770] ☁️ Skipping 1280.25989.fna — already in Drive.
# [867/5770] ☁️ Skipping 1280.25992.fna — already in Drive.
# [868/5770] ☁️ Skipping 1280.25991.fna — already in Drive.
# [869/5770] ☁️ Skipping 1280.25995.fna — already in Drive.
# [870/5770] ☁️ Skipping 1280.25996.fna — already in Drive.
# [871/5770] ☁️ Skipping 1280.25994.fna — already in Drive.
# [872/5770] ☁️ Skipping 1280.25993.fna — already in Drive.
# [873/5770] ☁️ Skipping 1280.25998.fna — already in Drive.
# [874/5770] ☁️ Skipping 1280.25997.fna — already in Drive.
# [875/5770] ☁️ Skipping 1280.26001.fna — already in Drive.
# [876/5770] ☁️ Skipping 1280.25999.fna — already in Drive.
# [877/5770] ☁️ Skipping 1280.26002.fna — already in Drive.
# [878/5770] ☁️ Skipping 1280.26004.fna — already in Drive.
# [879/5770] ☁️ Skipping 1280.26003.fna — already in Drive.
# [880/5770] ☁️ Skipping 1280.26005.fna — already in Drive.
# [881/5770] ☁️ Skipping 1280.26006.fna — already in Drive.
# [882/5770] ☁️ Skipping 1280.26007.fna — already in Drive.
# [883/5770] ☁️ Skipping 1280.26008.fna — already in Drive.
# [884/5770] ☁️ Skipping 1280.26009.fna — already in Drive.
# [885/5770] ☁️ Skipping 1280.26011.fna — already in Drive.
# [886/5770] ☁️ Skipping 1280.26013.fna — already in Drive.
# [887/5770] ☁️ Skipping 1280.26012.fna — already in Drive.
# [888/5770] ☁️ Skipping 1280.26014.fna — already in Drive.
# [889/5770] ☁️ Skipping 1280.26015.fna — already in Drive.
# [890/5770] ☁️ Skipping 1280.26016.fna — already in Drive.
# [891/5770] ☁️ Skipping 1280.26018.fna — already in Drive.
# [892/5770] ☁️ Skipping 1280.26017.fna — already in Drive.
# [893/5770] ☁️ Skipping 1280.26019.fna — already in Drive.
# [894/5770] ☁️ Skipping 1280.26021.fna — already in Drive.
# [895/5770] ☁️ Skipping 1280.26022.fna — already in Drive.
# [896/5770] ☁️ Skipping 1280.26023.fna — already in Drive.
# [897/5770] ☁️ Skipping 1280.26024.fna — already in Drive.
# [898/5770] ☁️ Skipping 1280.26025.fna — already in Drive.
# [899/5770] ☁️ Skipping 1280.26026.fna — already in Drive.
# [900/5770] ☁️ Skipping 1280.26027.fna — already in Drive.
# [901/5770] ☁️ Skipping 1280.26028.fna — already in Drive.
# [902/5770] ☁️ Skipping 1280.26029.fna — already in Drive.
# [903/5770] ❌ Failed for 1280.2599: <urlopen error 550 genomes/1280.2599: No such file or directory>
# [904/5770] ☁️ Skipping 1280.26031.fna — already in Drive.
# [905/5770] ❌ Failed for 1280.2601: <urlopen error 550 genomes/1280.2601: No such file or directory>
# [906/5770] ❌ Failed for 1280.26: <urlopen error 550 genomes/1280.26: No such file or directory>
# [907/5770] ☁️ Skipping 1280.26032.fna — already in Drive.
# [908/5770] ☁️ Skipping 1280.26033.fna — already in Drive.
# [909/5770] ☁️ Skipping 1280.26035.fna — already in Drive.
# [910/5770] ❌ Failed for 1280.2602: <urlopen error 550 genomes/1280.2602: No such file or directory>
# [911/5770] ☁️ Skipping 1280.26034.fna — already in Drive.
# [912/5770] ☁️ Skipping 1280.26037.fna — already in Drive.
# [913/5770] ☁️ Skipping 1280.26036.fna — already in Drive.
# [914/5770] ☁️ Skipping 1280.26038.fna — already in Drive.
# [915/5770] ☁️ Skipping 1280.26039.fna — already in Drive.
# [916/5770] ❌ Failed for 1280.2603: <urlopen error 550 genomes/1280.2603: No such file or directory>
# [917/5770] ☁️ Skipping 1280.26041.fna — already in Drive.
# [918/5770] ☁️ Skipping 1280.26042.fna — already in Drive.
# [919/5770] ☁️ Skipping 1280.26044.fna — already in Drive.
# [920/5770] ☁️ Skipping 1280.26043.fna — already in Drive.
# [921/5770] ☁️ Skipping 1280.26045.fna — already in Drive.
# [922/5770] ☁️ Skipping 1280.26047.fna — already in Drive.
# [923/5770] ☁️ Skipping 1280.26049.fna — already in Drive.
# [924/5770] ☁️ Skipping 1280.26046.fna — already in Drive.
# [925/5770] ☁️ Skipping 1280.26048.fna — already in Drive.
# [926/5770] ☁️ Skipping 1280.26051.fna — already in Drive.
# [927/5770] ☁️ Skipping 1280.26052.fna — already in Drive.
# [928/5770] ☁️ Skipping 1280.26053.fna — already in Drive.
# [929/5770] ☁️ Skipping 1280.26056.fna — already in Drive.
# [930/5770] ☁️ Skipping 1280.26055.fna — already in Drive.
# [931/5770] ☁️ Skipping 1280.26057.fna — already in Drive.
# [932/5770] ☁️ Skipping 1280.26059.fna — already in Drive.
# [933/5770] ☁️ Skipping 1280.26054.fna — already in Drive.
# [934/5770] ☁️ Skipping 1280.26058.fna — already in Drive.
# [935/5770] ☁️ Skipping 1280.26061.fna — already in Drive.
# [936/5770] ☁️ Skipping 1280.26062.fna — already in Drive.
# [937/5770] ☁️ Skipping 1280.26063.fna — already in Drive.
# [938/5770] ☁️ Skipping 1280.26064.fna — already in Drive.
# [939/5770] ☁️ Skipping 1280.26065.fna — already in Drive.
# [940/5770] ☁️ Skipping 1280.26066.fna — already in Drive.
# [941/5770] ☁️ Skipping 1280.26067.fna — already in Drive.
# [942/5770] ☁️ Skipping 1280.26068.fna — already in Drive.
# [943/5770] ☁️ Skipping 1280.26069.fna — already in Drive.
# [944/5770] ☁️ Skipping 1280.26074.fna — already in Drive.
# [945/5770] ☁️ Skipping 1280.26075.fna — already in Drive.
# [946/5770] ☁️ Skipping 1280.26076.fna — already in Drive.
# [947/5770] ☁️ Skipping 1280.26077.fna — already in Drive.
# [948/5770] ☁️ Skipping 1280.26078.fna — already in Drive.
# [949/5770] ☁️ Skipping 1280.26079.fna — already in Drive.
# [950/5770] ❌ Failed for 1280.2604: <urlopen error 550 genomes/1280.2604: No such file or directory>
# [951/5770] ☁️ Skipping 1280.26081.fna — already in Drive.
# [952/5770] ☁️ Skipping 1280.26082.fna — already in Drive.
# [953/5770] ☁️ Skipping 1280.26083.fna — already in Drive.
# [954/5770] ❌ Failed for 1280.2606: <urlopen error 550 genomes/1280.2606: No such file or directory>
# [955/5770] ☁️ Skipping 1280.26084.fna — already in Drive.
# [956/5770] ❌ Failed for 1280.2605: <urlopen error 550 genomes/1280.2605: No such file or directory>
# [957/5770] ☁️ Skipping 1280.26086.fna — already in Drive.
# [958/5770] ☁️ Skipping 1280.26085.fna — already in Drive.
# [959/5770] ❌ Failed for 1280.2607: <urlopen error 550 genomes/1280.2607: No such file or directory>
# [960/5770] ☁️ Skipping 1280.26087.fna — already in Drive.
# [961/5770] ☁️ Skipping 1280.26088.fna — already in Drive.
# [962/5770] ☁️ Skipping 1280.26091.fna — already in Drive.
# [963/5770] ☁️ Skipping 1280.26089.fna — already in Drive.
# [964/5770] ☁️ Skipping 1280.26092.fna — already in Drive.
# [965/5770] ☁️ Skipping 1280.26093.fna — already in Drive.
# [966/5770] ☁️ Skipping 1280.26094.fna — already in Drive.
# [967/5770] ☁️ Skipping 1280.26095.fna — already in Drive.
# [968/5770] ☁️ Skipping 1280.26097.fna — already in Drive.
# [969/5770] ☁️ Skipping 1280.26096.fna — already in Drive.
# [970/5770] ☁️ Skipping 1280.26098.fna — already in Drive.
# [971/5770] ☁️ Skipping 1280.26099.fna — already in Drive.
# [972/5770] ☁️ Skipping 1280.26101.fna — already in Drive.
# [973/5770] ☁️ Skipping 1280.26102.fna — already in Drive.
# [974/5770] ☁️ Skipping 1280.26103.fna — already in Drive.
# [975/5770] ☁️ Skipping 1280.26105.fna — already in Drive.
# [976/5770] ☁️ Skipping 1280.26104.fna — already in Drive.
# [977/5770] ☁️ Skipping 1280.26107.fna — already in Drive.
# [978/5770] ☁️ Skipping 1280.26106.fna — already in Drive.
# [979/5770] ☁️ Skipping 1280.26108.fna — already in Drive.
# [980/5770] ☁️ Skipping 1280.26109.fna — already in Drive.
# [981/5770] ☁️ Skipping 1280.26111.fna — already in Drive.
# [982/5770] ☁️ Skipping 1280.26112.fna — already in Drive.
# [983/5770] ☁️ Skipping 1280.26113.fna — already in Drive.
# [984/5770] ☁️ Skipping 1280.26114.fna — already in Drive.
# [985/5770] ☁️ Skipping 1280.26115.fna — already in Drive.
# [986/5770] ☁️ Skipping 1280.26116.fna — already in Drive.
# [987/5770] ☁️ Skipping 1280.26117.fna — already in Drive.
# [988/5770] ☁️ Skipping 1280.26118.fna — already in Drive.
# [989/5770] ☁️ Skipping 1280.29683.fna — already in Drive.
# [990/5770] ☁️ Skipping 1280.29684.fna — already in Drive.
# [991/5770] ☁️ Skipping 1280.29685.fna — already in Drive.
# [992/5770] ☁️ Skipping 1280.29686.fna — already in Drive.
# [993/5770] ☁️ Skipping 1280.29687.fna — already in Drive.
# [994/5770] ☁️ Skipping 1280.29688.fna — already in Drive.
# [995/5770] ☁️ Skipping 1280.29689.fna — already in Drive.
# [996/5770] ❌ Failed for 1280.2608: <urlopen error 550 genomes/1280.2608: No such file or directory>
# [997/5770] ☁️ Skipping 1280.29691.fna — already in Drive.
# [998/5770] ☁️ Skipping 1280.29692.fna — already in Drive.
# [999/5770] ☁️ Skipping 1280.29693.fna — already in Drive.
# [1000/5770] ☁️ Skipping 1280.29694.fna — already in Drive.
# [1001/5770] ☁️ Skipping 1280.29695.fna — already in Drive.
# [1002/5770] ☁️ Skipping 1280.29696.fna — already in Drive.
# [1003/5770] ☁️ Skipping 1280.29697.fna — already in Drive.
# [1004/5770] ☁️ Skipping 1280.29698.fna — already in Drive.
# [1005/5770] ☁️ Skipping 1280.29699.fna — already in Drive.
# [1006/5770] ❌ Failed for 1280.2611: <urlopen error 550 genomes/1280.2611: No such file or directory>
# [1007/5770] ❌ Failed for 1280.261: <urlopen error 550 genomes/1280.261: No such file or directory>
# [1008/5770] ❌ Failed for 1280.2609: <urlopen error 550 genomes/1280.2609: No such file or directory>
# [1009/5770] ☁️ Skipping 1280.29701.fna — already in Drive.
# [1010/5770] ☁️ Skipping 1280.29702.fna — already in Drive.
# [1011/5770] ☁️ Skipping 1280.29703.fna — already in Drive.
# [1012/5770] ❌ Failed for 1280.2969: <urlopen error 550 genomes/1280.2969: No such file or directory>
# [1013/5770] ☁️ Skipping 1280.29704.fna — already in Drive.
# [1014/5770] ☁️ Skipping 1280.29705.fna — already in Drive.
# [1015/5770] ☁️ Skipping 1280.29706.fna — already in Drive.
# [1016/5770] ☁️ Skipping 1280.29707.fna — already in Drive.
# [1017/5770] ☁️ Skipping 1280.29708.fna — already in Drive.
# [1018/5770] ☁️ Skipping 1280.29709.fna — already in Drive.
# [1019/5770] ☁️ Skipping 1280.29713.fna — already in Drive.
# [1020/5770] ☁️ Skipping 1280.29711.fna — already in Drive.
# [1021/5770] ☁️ Skipping 1280.29712.fna — already in Drive.
# [1022/5770] ☁️ Skipping 1280.29714.fna — already in Drive.
# [1023/5770] ☁️ Skipping 1280.29715.fna — already in Drive.
# [1024/5770] ☁️ Skipping 1280.29716.fna — already in Drive.
# [1025/5770] ☁️ Skipping 1280.29717.fna — already in Drive.
# [1026/5770] ☁️ Skipping 1280.29718.fna — already in Drive.
# [1027/5770] ☁️ Skipping 1280.29719.fna — already in Drive.
# [1028/5770] ☁️ Skipping 1280.29722.fna — already in Drive.
# [1029/5770] ☁️ Skipping 1280.29723.fna — already in Drive.
# [1030/5770] ☁️ Skipping 1280.29721.fna — already in Drive.
# [1031/5770] ☁️ Skipping 1280.29724.fna — already in Drive.
# [1032/5770] ☁️ Skipping 1280.29725.fna — already in Drive.
# [1033/5770] ☁️ Skipping 1280.29726.fna — already in Drive.
# [1034/5770] ☁️ Skipping 1280.29727.fna — already in Drive.
# [1035/5770] ☁️ Skipping 1280.29728.fna — already in Drive.
# [1036/5770] ☁️ Skipping 1280.29729.fna — already in Drive.
# [1037/5770] ☁️ Skipping 1280.29731.fna — already in Drive.
# [1038/5770] ☁️ Skipping 1280.29732.fna — already in Drive.
# [1039/5770] ☁️ Skipping 1280.29733.fna — already in Drive.
# [1040/5770] ☁️ Skipping 1280.29734.fna — already in Drive.
# [1041/5770] ☁️ Skipping 1280.29735.fna — already in Drive.
# [1042/5770] ☁️ Skipping 1280.29736.fna — already in Drive.
# [1043/5770] ☁️ Skipping 1280.29737.fna — already in Drive.
# [1044/5770] ☁️ Skipping 1280.29738.fna — already in Drive.
# [1045/5770] ☁️ Skipping 1280.29739.fna — already in Drive.
# [1046/5770] ❌ Failed for 1280.297: <urlopen error 550 genomes/1280.297: No such file or directory>
# [1047/5770] ❌ Failed for 1280.2971: <urlopen error 550 genomes/1280.2971: No such file or directory>
# [1048/5770] ☁️ Skipping 1280.29741.fna — already in Drive.
# [1049/5770] ❌ Failed for 1280.2972: <urlopen error 550 genomes/1280.2972: No such file or directory>
# [1050/5770] ☁️ Skipping 1280.29743.fna — already in Drive.
# [1051/5770] ❌ Failed for 1280.2973: <urlopen error 550 genomes/1280.2973: No such file or directory>
# [1052/5770] ☁️ Skipping 1280.29744.fna — already in Drive.
# [1053/5770] ☁️ Skipping 1280.29742.fna — already in Drive.
# [1054/5770] ☁️ Skipping 1280.29745.fna — already in Drive.
# [1055/5770] ☁️ Skipping 1280.29746.fna — already in Drive.
# [1056/5770] ☁️ Skipping 1280.29747.fna — already in Drive.
# [1057/5770] ☁️ Skipping 1280.29749.fna — already in Drive.
# [1058/5770] ☁️ Skipping 1280.29748.fna — already in Drive.
# [1059/5770] ☁️ Skipping 1280.29751.fna — already in Drive.
# [1060/5770] ☁️ Skipping 1280.29753.fna — already in Drive.
# [1061/5770] ❌ Failed for 1280.2974: <urlopen error 550 genomes/1280.2974: No such file or directory>
# [1062/5770] ☁️ Skipping 1280.29752.fna — already in Drive.
# [1063/5770] ☁️ Skipping 1280.29754.fna — already in Drive.
# [1064/5770] ☁️ Skipping 1280.29755.fna — already in Drive.
# [1065/5770] ☁️ Skipping 1280.29756.fna — already in Drive.
# [1066/5770] ☁️ Skipping 1280.29757.fna — already in Drive.
# [1067/5770] ☁️ Skipping 1280.29758.fna — already in Drive.
# [1068/5770] ☁️ Skipping 1280.29759.fna — already in Drive.
# [1069/5770] ☁️ Skipping 1280.29761.fna — already in Drive.
# [1070/5770] ☁️ Skipping 1280.29762.fna — already in Drive.
# [1071/5770] ☁️ Skipping 1280.29763.fna — already in Drive.
# [1072/5770] ☁️ Skipping 1280.29764.fna — already in Drive.
# [1073/5770] ☁️ Skipping 1280.29765.fna — already in Drive.
# [1074/5770] ☁️ Skipping 1280.29766.fna — already in Drive.
# [1075/5770] ☁️ Skipping 1280.29767.fna — already in Drive.
# [1076/5770] ☁️ Skipping 1280.29768.fna — already in Drive.
# [1077/5770] ☁️ Skipping 1280.29769.fna — already in Drive.
# [1078/5770] ☁️ Skipping 1280.29771.fna — already in Drive.
# [1079/5770] ☁️ Skipping 1280.29772.fna — already in Drive.
# [1080/5770] ☁️ Skipping 1280.29773.fna — already in Drive.
# [1081/5770] ☁️ Skipping 1280.29775.fna — already in Drive.
# [1082/5770] ☁️ Skipping 1280.29774.fna — already in Drive.
# [1083/5770] ☁️ Skipping 1280.29777.fna — already in Drive.
# [1084/5770] ☁️ Skipping 1280.29776.fna — already in Drive.
# [1085/5770] ☁️ Skipping 1280.29778.fna — already in Drive.
# [1086/5770] ☁️ Skipping 1280.29779.fna — already in Drive.
# [1087/5770] ☁️ Skipping 1280.29781.fna — already in Drive.
# [1088/5770] ☁️ Skipping 1280.29782.fna — already in Drive.
# [1089/5770] ☁️ Skipping 1280.29783.fna — already in Drive.
# [1090/5770] ☁️ Skipping 1280.29784.fna — already in Drive.
# [1091/5770] ☁️ Skipping 1280.29785.fna — already in Drive.
# [1092/5770] ☁️ Skipping 1280.29786.fna — already in Drive.
# [1093/5770] ☁️ Skipping 1280.29787.fna — already in Drive.
# [1094/5770] ☁️ Skipping 1280.29788.fna — already in Drive.
# [1095/5770] ☁️ Skipping 1280.29789.fna — already in Drive.
# [1096/5770] ❌ Failed for 1280.2975: <urlopen error 550 genomes/1280.2975: No such file or directory>
# [1097/5770] ❌ Failed for 1280.2976: <urlopen error 550 genomes/1280.2976: No such file or directory>
# [1098/5770] ❌ Failed for 1280.2977: <urlopen error 550 genomes/1280.2977: No such file or directory>
# [1099/5770] ☁️ Skipping 1280.29791.fna — already in Drive.
# [1100/5770] ☁️ Skipping 1280.29792.fna — already in Drive.
# [1101/5770] ☁️ Skipping 1280.29793.fna — already in Drive.
# [1102/5770] ☁️ Skipping 1280.29794.fna — already in Drive.
# [1103/5770] ❌ Failed for 1280.2978: <urlopen error 550 genomes/1280.2978: No such file or directory>
# [1104/5770] ❌ Failed for 1280.2979: <urlopen error 550 genomes/1280.2979: No such file or directory>
# [1105/5770] ☁️ Skipping 1280.29795.fna — already in Drive.
# [1106/5770] ☁️ Skipping 1280.29797.fna — already in Drive.
# [1107/5770] ☁️ Skipping 1280.29796.fna — already in Drive.
# [1108/5770] ☁️ Skipping 1280.29798.fna — already in Drive.
# [1109/5770] ☁️ Skipping 1280.29799.fna — already in Drive.
# [1110/5770] ☁️ Skipping 1280.29801.fna — already in Drive.
# [1111/5770] ☁️ Skipping 1280.29802.fna — already in Drive.
# [1112/5770] ☁️ Skipping 1280.29803.fna — already in Drive.
# [1113/5770] ☁️ Skipping 1280.29804.fna — already in Drive.
# [1114/5770] ☁️ Skipping 1280.29806.fna — already in Drive.
# [1115/5770] ☁️ Skipping 1280.29808.fna — already in Drive.
# [1116/5770] ☁️ Skipping 1280.29805.fna — already in Drive.
# [1117/5770] ☁️ Skipping 1280.29807.fna — already in Drive.
# [1118/5770] ☁️ Skipping 1280.29809.fna — already in Drive.
# [1119/5770] ☁️ Skipping 1280.29813.fna — already in Drive.
# [1120/5770] ☁️ Skipping 1280.29812.fna — already in Drive.
# [1121/5770] ☁️ Skipping 1280.29811.fna — already in Drive.
# [1122/5770] ☁️ Skipping 1280.29814.fna — already in Drive.
# [1123/5770] ☁️ Skipping 1280.29815.fna — already in Drive.
# [1124/5770] ☁️ Skipping 1280.29816.fna — already in Drive.
# [1125/5770] ☁️ Skipping 1280.29817.fna — already in Drive.
# [1126/5770] ☁️ Skipping 1280.29818.fna — already in Drive.
# [1127/5770] ☁️ Skipping 1280.29819.fna — already in Drive.
# [1128/5770] ☁️ Skipping 1280.29821.fna — already in Drive.
# [1129/5770] ☁️ Skipping 1280.29822.fna — already in Drive.
# [1130/5770] ☁️ Skipping 1280.29823.fna — already in Drive.
# [1131/5770] ☁️ Skipping 1280.29824.fna — already in Drive.
# [1132/5770] ☁️ Skipping 1280.29825.fna — already in Drive.
# [1133/5770] ☁️ Skipping 1280.29826.fna — already in Drive.
# [1134/5770] ☁️ Skipping 1280.29827.fna — already in Drive.
# [1135/5770] ☁️ Skipping 1280.29828.fna — already in Drive.
# [1136/5770] ☁️ Skipping 1280.29829.fna — already in Drive.
# [1137/5770] ☁️ Skipping 1280.29831.fna — already in Drive.
# [1138/5770] ☁️ Skipping 1280.29832.fna — already in Drive.
# [1139/5770] ☁️ Skipping 1280.29833.fna — already in Drive.
# [1140/5770] ☁️ Skipping 1280.29834.fna — already in Drive.
# [1141/5770] ☁️ Skipping 1280.29835.fna — already in Drive.
# [1142/5770] ☁️ Skipping 1280.29836.fna — already in Drive.
# [1143/5770] ☁️ Skipping 1280.29837.fna — already in Drive.
# [1144/5770] ☁️ Skipping 1280.29842.fna — already in Drive.
# [1145/5770] ☁️ Skipping 1280.29843.fna — already in Drive.
# [1146/5770] ☁️ Skipping 1280.29844.fna — already in Drive.
# [1147/5770] ☁️ Skipping 1280.29845.fna — already in Drive.
# [1148/5770] ☁️ Skipping 1280.29846.fna — already in Drive.
# [1149/5770] ☁️ Skipping 1280.29847.fna — already in Drive.
# [1150/5770] ☁️ Skipping 1280.29848.fna — already in Drive.
# [1151/5770] ☁️ Skipping 1280.29849.fna — already in Drive.
# [1152/5770] ❌ Failed for 1280.2982: <urlopen error 550 genomes/1280.2982: No such file or directory>
# [1153/5770] ❌ Failed for 1280.2981: <urlopen error 550 genomes/1280.2981: No such file or directory>
# [1154/5770] ❌ Failed for 1280.2985: <urlopen error 550 genomes/1280.2985: No such file or directory>
# [1155/5770] ❌ Failed for 1280.298: <urlopen error 550 genomes/1280.298: No such file or directory>
# [1156/5770] ☁️ Skipping 1280.29851.fna — already in Drive.
# [1157/5770] ☁️ Skipping 1280.29852.fna — already in Drive.
# [1158/5770] ❌ Failed for 1280.2983: <urlopen error 550 genomes/1280.2983: No such file or directory>
# [1159/5770] ☁️ Skipping 1280.29853.fna — already in Drive.
# [1160/5770] ☁️ Skipping 1280.29854.fna — already in Drive.
# [1161/5770] ☁️ Skipping 1280.29855.fna — already in Drive.
# [1162/5770] ☁️ Skipping 1280.29856.fna — already in Drive.
# [1163/5770] ☁️ Skipping 1280.29857.fna — already in Drive.
# [1164/5770] ☁️ Skipping 1280.29859.fna — already in Drive.
# [1165/5770] ☁️ Skipping 1280.29858.fna — already in Drive.
# [1166/5770] ☁️ Skipping 1280.29861.fna — already in Drive.
# [1167/5770] ☁️ Skipping 1280.29864.fna — already in Drive.
# [1168/5770] ☁️ Skipping 1280.29865.fna — already in Drive.
# [1169/5770] ☁️ Skipping 1280.29862.fna — already in Drive.
# [1170/5770] ☁️ Skipping 1280.29863.fna — already in Drive.
# [1171/5770] ☁️ Skipping 1280.29867.fna — already in Drive.
# [1172/5770] ☁️ Skipping 1280.29866.fna — already in Drive.
# [1173/5770] ☁️ Skipping 1280.29868.fna — already in Drive.
# [1174/5770] ☁️ Skipping 1280.29871.fna — already in Drive.
# [1175/5770] ☁️ Skipping 1280.29869.fna — already in Drive.
# [1176/5770] ☁️ Skipping 1280.29873.fna — already in Drive.
# [1177/5770] ☁️ Skipping 1280.29872.fna — already in Drive.
# [1178/5770] ☁️ Skipping 1280.29874.fna — already in Drive.
# [1179/5770] ☁️ Skipping 1280.29875.fna — already in Drive.
# [1180/5770] ☁️ Skipping 1280.29876.fna — already in Drive.
# [1181/5770] ☁️ Skipping 1280.29877.fna — already in Drive.
# [1182/5770] ☁️ Skipping 1280.29878.fna — already in Drive.
# [1183/5770] ☁️ Skipping 1280.29879.fna — already in Drive.
# [1184/5770] ☁️ Skipping 1280.29882.fna — already in Drive.
# [1185/5770] ☁️ Skipping 1280.29881.fna — already in Drive.
# [1186/5770] ☁️ Skipping 1280.29883.fna — already in Drive.
# [1187/5770] ☁️ Skipping 1280.29884.fna — already in Drive.
# [1188/5770] ☁️ Skipping 1280.29886.fna — already in Drive.
# [1189/5770] ☁️ Skipping 1280.29885.fna — already in Drive.
# [1190/5770] ☁️ Skipping 1280.29888.fna — already in Drive.
# [1191/5770] ☁️ Skipping 1280.29887.fna — already in Drive.
# [1192/5770] ☁️ Skipping 1280.29889.fna — already in Drive.
# [1193/5770] ☁️ Skipping 1280.29891.fna — already in Drive.
# [1194/5770] ☁️ Skipping 1280.29892.fna — already in Drive.
# [1195/5770] ☁️ Skipping 1280.29893.fna — already in Drive.
# [1196/5770] ☁️ Skipping 1280.29894.fna — already in Drive.
# [1197/5770] ☁️ Skipping 1280.29895.fna — already in Drive.
# [1198/5770] ☁️ Skipping 1280.29896.fna — already in Drive.
# [1199/5770] ☁️ Skipping 1280.29897.fna — already in Drive.
# [1200/5770] ☁️ Skipping 1280.29898.fna — already in Drive.
# [1201/5770] ☁️ Skipping 1280.29899.fna — already in Drive.
# [1202/5770] ❌ Failed for 1280.2986: <urlopen error 550 genomes/1280.2986: No such file or directory>
# [1203/5770] ❌ Failed for 1280.2989: <urlopen error 550 genomes/1280.2989: No such file or directory>
# [1204/5770] ☁️ Skipping 1280.29901.fna — already in Drive.
# [1205/5770] ❌ Failed for 1280.2987: <urlopen error 550 genomes/1280.2987: No such file or directory>
# [1206/5770] ❌ Failed for 1280.2988: <urlopen error 550 genomes/1280.2988: No such file or directory>
# [1207/5770] ☁️ Skipping 1280.29902.fna — already in Drive.
# [1208/5770] ❌ Failed for 1280.299: <urlopen error 550 genomes/1280.299: No such file or directory>
# [1209/5770] ☁️ Skipping 1280.29904.fna — already in Drive.
# [1210/5770] ☁️ Skipping 1280.29903.fna — already in Drive.
# [1211/5770] ☁️ Skipping 1280.29905.fna — already in Drive.
# [1212/5770] ☁️ Skipping 1280.29906.fna — already in Drive.
# [1213/5770] ☁️ Skipping 1280.29907.fna — already in Drive.
# [1214/5770] ☁️ Skipping 1280.29908.fna — already in Drive.
# [1215/5770] ☁️ Skipping 1280.29909.fna — already in Drive.
# [1216/5770] ☁️ Skipping 1280.29911.fna — already in Drive.
# [1217/5770] ☁️ Skipping 1280.29912.fna — already in Drive.
# [1218/5770] ☁️ Skipping 1280.29913.fna — already in Drive.
# [1219/5770] ☁️ Skipping 1280.29915.fna — already in Drive.
# [1220/5770] ☁️ Skipping 1280.29917.fna — already in Drive.
# [1221/5770] ☁️ Skipping 1280.29914.fna — already in Drive.
# [1222/5770] ☁️ Skipping 1280.29916.fna — already in Drive.
# [1223/5770] ☁️ Skipping 1280.29918.fna — already in Drive.
# [1224/5770] ☁️ Skipping 1280.29919.fna — already in Drive.
# [1225/5770] ☁️ Skipping 1280.29921.fna — already in Drive.
# [1226/5770] ☁️ Skipping 1280.29922.fna — already in Drive.
# [1227/5770] ☁️ Skipping 1280.29923.fna — already in Drive.
# [1228/5770] ☁️ Skipping 1280.29924.fna — already in Drive.
# [1229/5770] ☁️ Skipping 1280.29925.fna — already in Drive.
# [1230/5770] ☁️ Skipping 1280.29926.fna — already in Drive.
# [1231/5770] ☁️ Skipping 1280.29927.fna — already in Drive.
# [1232/5770] ☁️ Skipping 1280.29929.fna — already in Drive.
# [1233/5770] ☁️ Skipping 1280.29928.fna — already in Drive.
# [1234/5770] ☁️ Skipping 1280.29932.fna — already in Drive.
# [1235/5770] ☁️ Skipping 1280.29931.fna — already in Drive.
# [1236/5770] ☁️ Skipping 1280.29933.fna — already in Drive.
# [1237/5770] ☁️ Skipping 1280.29934.fna — already in Drive.
# [1238/5770] ☁️ Skipping 1280.29935.fna — already in Drive.
# [1239/5770] ☁️ Skipping 1280.29936.fna — already in Drive.
# [1240/5770] ☁️ Skipping 1280.29937.fna — already in Drive.
# [1241/5770] ☁️ Skipping 1280.29938.fna — already in Drive.
# [1242/5770] ☁️ Skipping 1280.29939.fna — already in Drive.
# [1243/5770] ☁️ Skipping 1280.29941.fna — already in Drive.
# [1244/5770] ☁️ Skipping 1280.29942.fna — already in Drive.
# [1245/5770] ☁️ Skipping 1280.29943.fna — already in Drive.
# [1246/5770] ☁️ Skipping 1280.29944.fna — already in Drive.
# [1247/5770] ☁️ Skipping 1280.29945.fna — already in Drive.
# [1248/5770] ☁️ Skipping 1280.29946.fna — already in Drive.
# [1249/5770] ☁️ Skipping 1280.29947.fna — already in Drive.
# [1250/5770] ☁️ Skipping 1280.29948.fna — already in Drive.
# [1251/5770] ☁️ Skipping 1280.29949.fna — already in Drive.
# [1252/5770] ❌ Failed for 1280.2991: <urlopen error 550 genomes/1280.2991: No such file or directory>
# [1253/5770] ❌ Failed for 1280.2995: <urlopen error 550 genomes/1280.2995: No such file or directory>
# [1254/5770] ❌ Failed for 1280.2992: <urlopen error 550 genomes/1280.2992: No such file or directory>
# [1255/5770] ❌ Failed for 1280.2993: <urlopen error 550 genomes/1280.2993: No such file or directory>
# [1256/5770] ☁️ Skipping 1280.29953.fna — already in Drive.
# [1257/5770] ❌ Failed for 1280.2994: <urlopen error 550 genomes/1280.2994: No such file or directory>
# [1258/5770] ☁️ Skipping 1280.29951.fna — already in Drive.
# [1259/5770] ☁️ Skipping 1280.29952.fna — already in Drive.
# [1260/5770] ☁️ Skipping 1280.29954.fna — already in Drive.
# [1261/5770] ☁️ Skipping 1280.29955.fna — already in Drive.
# [1262/5770] ☁️ Skipping 1280.29956.fna — already in Drive.
# [1263/5770] ☁️ Skipping 1280.29957.fna — already in Drive.
# [1264/5770] ☁️ Skipping 1280.29958.fna — already in Drive.
# [1265/5770] ☁️ Skipping 1280.29959.fna — already in Drive.
# [1266/5770] ☁️ Skipping 1280.29961.fna — already in Drive.
# [1267/5770] ☁️ Skipping 1280.29962.fna — already in Drive.
# [1268/5770] ☁️ Skipping 1280.29965.fna — already in Drive.
# [1269/5770] ☁️ Skipping 1280.29963.fna — already in Drive.
# [1270/5770] ☁️ Skipping 1280.29966.fna — already in Drive.
# [1271/5770] ☁️ Skipping 1280.29967.fna — already in Drive.
# [1272/5770] ☁️ Skipping 1280.29964.fna — already in Drive.
# [1273/5770] ☁️ Skipping 1280.29968.fna — already in Drive.
# [1274/5770] ☁️ Skipping 1280.29971.fna — already in Drive.
# [1275/5770] ☁️ Skipping 1280.29969.fna — already in Drive.
# [1276/5770] ☁️ Skipping 1280.29972.fna — already in Drive.
# [1277/5770] ☁️ Skipping 1280.29973.fna — already in Drive.
# [1278/5770] ☁️ Skipping 1280.29974.fna — already in Drive.
# [1279/5770] ☁️ Skipping 1280.29976.fna — already in Drive.
# [1280/5770] ☁️ Skipping 1280.29975.fna — already in Drive.
# [1281/5770] ☁️ Skipping 1280.29977.fna — already in Drive.
# [1282/5770] ☁️ Skipping 1280.29978.fna — already in Drive.
# [1283/5770] ☁️ Skipping 1280.29979.fna — already in Drive.
# [1284/5770] ☁️ Skipping 1280.29981.fna — already in Drive.
# [1285/5770] ☁️ Skipping 1280.29983.fna — already in Drive.
# [1286/5770] ☁️ Skipping 1280.29982.fna — already in Drive.
# [1287/5770] ☁️ Skipping 1280.29984.fna — already in Drive.
# [1288/5770] ☁️ Skipping 1280.29985.fna — already in Drive.
# [1289/5770] ☁️ Skipping 1280.29987.fna — already in Drive.
# [1290/5770] ☁️ Skipping 1280.29986.fna — already in Drive.
# [1291/5770] ☁️ Skipping 1280.29989.fna — already in Drive.
# [1292/5770] ☁️ Skipping 1280.29988.fna — already in Drive.
# [1293/5770] ☁️ Skipping 1280.29991.fna — already in Drive.
# [1294/5770] ☁️ Skipping 1280.29992.fna — already in Drive.
# [1295/5770] ☁️ Skipping 1280.29993.fna — already in Drive.
# [1296/5770] ☁️ Skipping 1280.29994.fna — already in Drive.
# [1297/5770] ☁️ Skipping 1280.29995.fna — already in Drive.
# [1298/5770] ☁️ Skipping 1280.29996.fna — already in Drive.
# [1299/5770] ☁️ Skipping 1280.29997.fna — already in Drive.
# [1300/5770] ☁️ Skipping 1280.29998.fna — already in Drive.
# [1301/5770] ☁️ Skipping 1280.29999.fna — already in Drive.
# [1302/5770] ❌ Failed for 1280.2996: <urlopen error 550 genomes/1280.2996: No such file or directory>
# [1303/5770] ☁️ Skipping 1280.30001.fna — already in Drive.
# [1304/5770] ☁️ Skipping 1280.30002.fna — already in Drive.
# [1305/5770] ☁️ Skipping 1280.30003.fna — already in Drive.
# [1306/5770] ☁️ Skipping 1280.30004.fna — already in Drive.
# [1307/5770] ☁️ Skipping 1280.30005.fna — already in Drive.
# [1308/5770] ☁️ Skipping 1280.30006.fna — already in Drive.
# [1309/5770] ☁️ Skipping 1280.30007.fna — already in Drive.
# [1310/5770] ☁️ Skipping 1280.30008.fna — already in Drive.
# [1311/5770] ☁️ Skipping 1280.30009.fna — already in Drive.
# [1312/5770] ❌ Failed for 1280.2997: <urlopen error 550 genomes/1280.2997: No such file or directory>
# [1313/5770] ☁️ Skipping 1280.30011.fna — already in Drive.
# [1314/5770] ☁️ Skipping 1280.30012.fna — already in Drive.
# [1315/5770] ❌ Failed for 1280.2999: <urlopen error 550 genomes/1280.2999: No such file or directory>
# [1316/5770] ❌ Failed for 1280.2998: <urlopen error 550 genomes/1280.2998: No such file or directory>
# [1317/5770] ☁️ Skipping 1280.30014.fna — already in Drive.
# [1318/5770] ☁️ Skipping 1280.30013.fna — already in Drive.
# [1319/5770] ☁️ Skipping 1280.30015.fna — already in Drive.
# [1320/5770] ❌ Failed for 1280.3: <urlopen error 550 genomes/1280.3: No such file or directory>
# [1321/5770] ☁️ Skipping 1280.30016.fna — already in Drive.
# [1322/5770] ☁️ Skipping 1280.30017.fna — already in Drive.
# [1323/5770] ☁️ Skipping 1280.30018.fna — already in Drive.
# [1324/5770] ☁️ Skipping 1280.30019.fna — already in Drive.
# [1325/5770] ☁️ Skipping 1280.30021.fna — already in Drive.
# [1326/5770] ☁️ Skipping 1280.30024.fna — already in Drive.
# [1327/5770] ☁️ Skipping 1280.30022.fna — already in Drive.
# [1328/5770] ☁️ Skipping 1280.30023.fna — already in Drive.
# [1329/5770] ☁️ Skipping 1280.30026.fna — already in Drive.
# [1330/5770] ☁️ Skipping 1280.30025.fna — already in Drive.
# [1331/5770] ☁️ Skipping 1280.30027.fna — already in Drive.
# [1332/5770] ☁️ Skipping 1280.30028.fna — already in Drive.
# [1333/5770] ☁️ Skipping 1280.30029.fna — already in Drive.
# [1334/5770] ☁️ Skipping 1280.30031.fna — already in Drive.
# [1335/5770] ☁️ Skipping 1280.30032.fna — already in Drive.
# [1336/5770] ☁️ Skipping 1280.30033.fna — already in Drive.
# [1337/5770] ☁️ Skipping 1280.30034.fna — already in Drive.
# [1338/5770] ☁️ Skipping 1280.30035.fna — already in Drive.
# [1339/5770] ☁️ Skipping 1280.30036.fna — already in Drive.
# [1340/5770] ☁️ Skipping 1280.30038.fna — already in Drive.
# [1341/5770] ☁️ Skipping 1280.30037.fna — already in Drive.
# [1342/5770] ☁️ Skipping 1280.30039.fna — already in Drive.
# [1343/5770] ☁️ Skipping 1280.30041.fna — already in Drive.
# [1344/5770] ☁️ Skipping 1280.30042.fna — already in Drive.
# [1345/5770] ☁️ Skipping 1280.30043.fna — already in Drive.
# [1346/5770] ☁️ Skipping 1280.30044.fna — already in Drive.
# [1347/5770] ☁️ Skipping 1280.30045.fna — already in Drive.
# [1348/5770] ☁️ Skipping 1280.30046.fna — already in Drive.
# [1349/5770] ☁️ Skipping 1280.30047.fna — already in Drive.
# [1350/5770] ☁️ Skipping 1280.30048.fna — already in Drive.
# [1351/5770] ☁️ Skipping 1280.30049.fna — already in Drive.
# [1352/5770] ❌ Failed for 1280.3001: <urlopen error 550 genomes/1280.3001: No such file or directory>
# [1353/5770] ❌ Failed for 1280.3004: <urlopen error 550 genomes/1280.3004: No such file or directory>
# [1354/5770] ❌ Failed for 1280.3002: <urlopen error 550 genomes/1280.3002: No such file or directory>
# [1355/5770] ❌ Failed for 1280.3003: <urlopen error 550 genomes/1280.3003: No such file or directory>
# [1356/5770] ☁️ Skipping 1280.30051.fna — already in Drive.
# [1357/5770] ☁️ Skipping 1280.30052.fna — already in Drive.
# [1358/5770] ❌ Failed for 1280.3005: <urlopen error 550 genomes/1280.3005: No such file or directory>
# [1359/5770] ☁️ Skipping 1280.30053.fna — already in Drive.
# [1360/5770] ☁️ Skipping 1280.30055.fna — already in Drive.
# [1361/5770] ☁️ Skipping 1280.30054.fna — already in Drive.
# [1362/5770] ☁️ Skipping 1280.30056.fna — already in Drive.
# [1363/5770] ☁️ Skipping 1280.30057.fna — already in Drive.
# [1364/5770] ☁️ Skipping 1280.30058.fna — already in Drive.
# [1365/5770] ☁️ Skipping 1280.30059.fna — already in Drive.
# [1366/5770] ☁️ Skipping 1280.30061.fna — already in Drive.
# [1367/5770] ☁️ Skipping 1280.30063.fna — already in Drive.
# [1368/5770] ☁️ Skipping 1280.30062.fna — already in Drive.
# [1369/5770] ☁️ Skipping 1280.30064.fna — already in Drive.
# [1370/5770] ☁️ Skipping 1280.30066.fna — already in Drive.
# [1371/5770] ☁️ Skipping 1280.30065.fna — already in Drive.
# [1372/5770] ☁️ Skipping 1280.30067.fna — already in Drive.
# [1373/5770] ☁️ Skipping 1280.30069.fna — already in Drive.
# [1374/5770] ☁️ Skipping 1280.30068.fna — already in Drive.
# [1375/5770] ☁️ Skipping 1280.30071.fna — already in Drive.
# [1376/5770] ☁️ Skipping 1280.30072.fna — already in Drive.
# [1377/5770] ☁️ Skipping 1280.30074.fna — already in Drive.
# [1378/5770] ☁️ Skipping 1280.30075.fna — already in Drive.
# [1379/5770] ☁️ Skipping 1280.30076.fna — already in Drive.
# [1380/5770] ☁️ Skipping 1280.30077.fna — already in Drive.
# [1381/5770] ☁️ Skipping 1280.30078.fna — already in Drive.
# [1382/5770] ☁️ Skipping 1280.30079.fna — already in Drive.
# [1383/5770] ☁️ Skipping 1280.30082.fna — already in Drive.
# [1384/5770] ☁️ Skipping 1280.30081.fna — already in Drive.
# [1385/5770] ☁️ Skipping 1280.30083.fna — already in Drive.
# [1386/5770] ☁️ Skipping 1280.30084.fna — already in Drive.
# [1387/5770] ☁️ Skipping 1280.30085.fna — already in Drive.
# [1388/5770] ☁️ Skipping 1280.30086.fna — already in Drive.
# [1389/5770] ☁️ Skipping 1280.30087.fna — already in Drive.
# [1390/5770] ☁️ Skipping 1280.30088.fna — already in Drive.
# [1391/5770] ☁️ Skipping 1280.30089.fna — already in Drive.
# [1392/5770] ☁️ Skipping 1280.30091.fna — already in Drive.
# [1393/5770] ☁️ Skipping 1280.30092.fna — already in Drive.
# [1394/5770] ☁️ Skipping 1280.30094.fna — already in Drive.
# [1395/5770] ☁️ Skipping 1280.30093.fna — already in Drive.
# [1396/5770] ☁️ Skipping 1280.30096.fna — already in Drive.
# [1397/5770] ☁️ Skipping 1280.30095.fna — already in Drive.
# [1398/5770] ☁️ Skipping 1280.30097.fna — already in Drive.
# [1399/5770] ☁️ Skipping 1280.30098.fna — already in Drive.
# [1400/5770] ☁️ Skipping 1280.30099.fna — already in Drive.
# [1401/5770] ☁️ Skipping 1280.30101.fna — already in Drive.
# [1402/5770] ☁️ Skipping 1280.30102.fna — already in Drive.
# [1403/5770] ☁️ Skipping 1280.30103.fna — already in Drive.
# [1404/5770] ☁️ Skipping 1280.30104.fna — already in Drive.
# [1405/5770] ☁️ Skipping 1280.30105.fna — already in Drive.
# [1406/5770] ☁️ Skipping 1280.30106.fna — already in Drive.
# [1407/5770] ☁️ Skipping 1280.30107.fna — already in Drive.
# [1408/5770] ☁️ Skipping 1280.30108.fna — already in Drive.
# [1409/5770] ☁️ Skipping 1280.30109.fna — already in Drive.
# [1410/5770] ❌ Failed for 1280.3007: <urlopen error 550 genomes/1280.3007: No such file or directory>
# [1411/5770] ❌ Failed for 1280.3006: <urlopen error 550 genomes/1280.3006: No such file or directory>
# [1412/5770] ☁️ Skipping 1280.30111.fna — already in Drive.
# [1413/5770] ☁️ Skipping 1280.30112.fna — already in Drive.
# [1414/5770] ☁️ Skipping 1280.30113.fna — already in Drive.
# [1415/5770] ❌ Failed for 1280.3011: <urlopen error 550 genomes/1280.3011: No such file or directory>
# [1416/5770] ❌ Failed for 1280.3009: <urlopen error 550 genomes/1280.3009: No such file or directory>
# [1417/5770] ❌ Failed for 1280.301: <urlopen error 550 genomes/1280.301: No such file or directory>
# [1418/5770] ☁️ Skipping 1280.30115.fna — already in Drive.
# [1419/5770] ☁️ Skipping 1280.30114.fna — already in Drive.
# [1420/5770] ☁️ Skipping 1280.30117.fna — already in Drive.
# [1421/5770] ☁️ Skipping 1280.30118.fna — already in Drive.
# [1422/5770] ☁️ Skipping 1280.30116.fna — already in Drive.
# [1423/5770] ☁️ Skipping 1280.30119.fna — already in Drive.
# [1424/5770] ☁️ Skipping 1280.30121.fna — already in Drive.
# [1425/5770] ☁️ Skipping 1280.30124.fna — already in Drive.
# [1426/5770] ☁️ Skipping 1280.30123.fna — already in Drive.
# [1427/5770] ☁️ Skipping 1280.30122.fna — already in Drive.
# [1428/5770] ☁️ Skipping 1280.30125.fna — already in Drive.
# [1429/5770] ☁️ Skipping 1280.30126.fna — already in Drive.
# [1430/5770] ☁️ Skipping 1280.30127.fna — already in Drive.
# [1431/5770] ☁️ Skipping 1280.30128.fna — already in Drive.
# [1432/5770] ☁️ Skipping 1280.30129.fna — already in Drive.
# [1433/5770] ☁️ Skipping 1280.30132.fna — already in Drive.
# [1434/5770] ☁️ Skipping 1280.30131.fna — already in Drive.
# [1435/5770] ☁️ Skipping 1280.30133.fna — already in Drive.
# [1436/5770] ☁️ Skipping 1280.30134.fna — already in Drive.
# [1437/5770] ☁️ Skipping 1280.30135.fna — already in Drive.
# [1438/5770] ☁️ Skipping 1280.30136.fna — already in Drive.
# [1439/5770] ☁️ Skipping 1280.30137.fna — already in Drive.
# [1440/5770] ☁️ Skipping 1280.30138.fna — already in Drive.
# [1441/5770] ☁️ Skipping 1280.30141.fna — already in Drive.
# [1442/5770] ☁️ Skipping 1280.30139.fna — already in Drive.
# [1443/5770] ☁️ Skipping 1280.30142.fna — already in Drive.
# [1444/5770] ☁️ Skipping 1280.30143.fna — already in Drive.
# [1445/5770] ☁️ Skipping 1280.30145.fna — already in Drive.
# [1446/5770] ☁️ Skipping 1280.30144.fna — already in Drive.
# [1447/5770] ☁️ Skipping 1280.30146.fna — already in Drive.
# [1448/5770] ☁️ Skipping 1280.30147.fna — already in Drive.
# [1449/5770] ☁️ Skipping 1280.30149.fna — already in Drive.
# [1450/5770] ☁️ Skipping 1280.30148.fna — already in Drive.
# [1451/5770] ☁️ Skipping 1280.30151.fna — already in Drive.
# [1452/5770] ☁️ Skipping 1280.30152.fna — already in Drive.
# [1453/5770] ☁️ Skipping 1280.30153.fna — already in Drive.
# [1454/5770] ☁️ Skipping 1280.30154.fna — already in Drive.
# [1455/5770] ☁️ Skipping 1280.30155.fna — already in Drive.
# [1456/5770] ☁️ Skipping 1280.30156.fna — already in Drive.
# [1457/5770] ☁️ Skipping 1280.30157.fna — already in Drive.
# [1458/5770] ☁️ Skipping 1280.30158.fna — already in Drive.
# [1459/5770] ☁️ Skipping 1280.30159.fna — already in Drive.
# [1460/5770] ❌ Failed for 1280.3012: <urlopen error 550 genomes/1280.3012: No such file or directory>
# [1461/5770] ❌ Failed for 1280.3013: <urlopen error 550 genomes/1280.3013: No such file or directory>
# [1462/5770] ☁️ Skipping 1280.30161.fna — already in Drive.
# [1463/5770] ❌ Failed for 1280.3014: <urlopen error 550 genomes/1280.3014: No such file or directory>
# [1464/5770] ☁️ Skipping 1280.30162.fna — already in Drive.
# [1465/5770] ❌ Failed for 1280.3015: <urlopen error 550 genomes/1280.3015: No such file or directory>
# [1466/5770] ❌ Failed for 1280.3016: <urlopen error 550 genomes/1280.3016: No such file or directory>
# [1467/5770] ☁️ Skipping 1280.30164.fna — already in Drive.
# [1468/5770] ☁️ Skipping 1280.30163.fna — already in Drive.
# [1469/5770] ☁️ Skipping 1280.30165.fna — already in Drive.
# [1470/5770] ☁️ Skipping 1280.30166.fna — already in Drive.
# [1471/5770] ☁️ Skipping 1280.30167.fna — already in Drive.
# [1472/5770] ☁️ Skipping 1280.30171.fna — already in Drive.
# [1473/5770] ☁️ Skipping 1280.30168.fna — already in Drive.
# [1474/5770] ☁️ Skipping 1280.30169.fna — already in Drive.
# [1475/5770] ☁️ Skipping 1280.30172.fna — already in Drive.
# [1476/5770] ☁️ Skipping 1280.30174.fna — already in Drive.
# [1477/5770] ☁️ Skipping 1280.30175.fna — already in Drive.
# [1478/5770] ☁️ Skipping 1280.30173.fna — already in Drive.
# [1479/5770] ☁️ Skipping 1280.30176.fna — already in Drive.
# [1480/5770] ☁️ Skipping 1280.30178.fna — already in Drive.
# [1481/5770] ☁️ Skipping 1280.30177.fna — already in Drive.
# [1482/5770] ☁️ Skipping 1280.30179.fna — already in Drive.
# [1483/5770] ☁️ Skipping 1280.30183.fna — already in Drive.
# [1484/5770] ☁️ Skipping 1280.30181.fna — already in Drive.
# [1485/5770] ☁️ Skipping 1280.30182.fna — already in Drive.
# [1486/5770] ☁️ Skipping 1280.30184.fna — already in Drive.
# [1487/5770] ☁️ Skipping 1280.30185.fna — already in Drive.
# [1488/5770] ☁️ Skipping 1280.30186.fna — already in Drive.
# [1489/5770] ☁️ Skipping 1280.30187.fna — already in Drive.
# [1490/5770] ☁️ Skipping 1280.30188.fna — already in Drive.
# [1491/5770] ☁️ Skipping 1280.30189.fna — already in Drive.
# [1492/5770] ☁️ Skipping 1280.30192.fna — already in Drive.
# [1493/5770] ☁️ Skipping 1280.30191.fna — already in Drive.
# [1494/5770] ☁️ Skipping 1280.30193.fna — already in Drive.
# [1495/5770] ☁️ Skipping 1280.30194.fna — already in Drive.
# [1496/5770] ☁️ Skipping 1280.30195.fna — already in Drive.
# [1497/5770] ☁️ Skipping 1280.30196.fna — already in Drive.
# [1498/5770] ☁️ Skipping 1280.30198.fna — already in Drive.
# [1499/5770] ☁️ Skipping 1280.30197.fna — already in Drive.
# [1500/5770] ☁️ Skipping 1280.30199.fna — already in Drive.
# [1501/5770] ☁️ Skipping 1280.30201.fna — already in Drive.
# [1502/5770] ☁️ Skipping 1280.30202.fna — already in Drive.
# [1503/5770] ☁️ Skipping 1280.30203.fna — already in Drive.
# [1504/5770] ☁️ Skipping 1280.30204.fna — already in Drive.
# [1505/5770] ☁️ Skipping 1280.30205.fna — already in Drive.
# [1506/5770] ☁️ Skipping 1280.30206.fna — already in Drive.
# [1507/5770] ☁️ Skipping 1280.30207.fna — already in Drive.
# [1508/5770] ☁️ Skipping 1280.30208.fna — already in Drive.
# [1509/5770] ☁️ Skipping 1280.30209.fna — already in Drive.
# [1510/5770] ❌ Failed for 1280.3017: <urlopen error 550 genomes/1280.3017: No such file or directory>
# [1511/5770] ❌ Failed for 1280.3018: <urlopen error 550 genomes/1280.3018: No such file or directory>
# [1512/5770] ❌ Failed for 1280.3019: <urlopen error 550 genomes/1280.3019: No such file or directory>
# [1513/5770] ❌ Failed for 1280.302: <urlopen error 550 genomes/1280.302: No such file or directory>
# [1514/5770] ☁️ Skipping 1280.30212.fna — already in Drive.
# [1515/5770] ❌ Failed for 1280.3021: <urlopen error 550 genomes/1280.3021: No such file or directory>
# [1516/5770] ☁️ Skipping 1280.30211.fna — already in Drive.
# [1517/5770] ☁️ Skipping 1280.30213.fna — already in Drive.
# [1518/5770] ☁️ Skipping 1280.30215.fna — already in Drive.
# [1519/5770] ☁️ Skipping 1280.30214.fna — already in Drive.
# [1520/5770] ☁️ Skipping 1280.30217.fna — already in Drive.
# [1521/5770] ☁️ Skipping 1280.30216.fna — already in Drive.
# [1522/5770] ☁️ Skipping 1280.30218.fna — already in Drive.
# [1523/5770] ☁️ Skipping 1280.30219.fna — already in Drive.
# [1524/5770] ☁️ Skipping 1280.30221.fna — already in Drive.
# [1525/5770] ☁️ Skipping 1280.30222.fna — already in Drive.
# [1526/5770] ☁️ Skipping 1280.30225.fna — already in Drive.
# [1527/5770] ☁️ Skipping 1280.30223.fna — already in Drive.
# [1528/5770] ☁️ Skipping 1280.30224.fna — already in Drive.
# [1529/5770] ☁️ Skipping 1280.30226.fna — already in Drive.
# [1530/5770] ☁️ Skipping 1280.30227.fna — already in Drive.
# [1531/5770] ☁️ Skipping 1280.30229.fna — already in Drive.
# [1532/5770] ☁️ Skipping 1280.30228.fna — already in Drive.
# [1533/5770] ☁️ Skipping 1280.30232.fna — already in Drive.
# [1534/5770] ☁️ Skipping 1280.30234.fna — already in Drive.
# ...
# [5473/5770] ✅ Downloaded and uploaded: 1422619.3.fna
# [5474/5770] ✅ Downloaded and uploaded: 1422621.3.fna
# [5475/5770] ✅ Downloaded and uploaded: 1422622.3.fna
# [5476/5770] ✅ Downloaded and uploaded: 1422624.3.fna
# [5477/5770] ✅ Downloaded and uploaded: 1422625.3.fna
# [5478/5770] ✅ Downloaded and uploaded: 1422623.3.fna
# [5479/5770] ✅ Downloaded and uploaded: 1422626.3.fna
# [5480/5770] ✅ Downloaded and uploaded: 1422627.3.fna
# [5481/5770] ✅ Downloaded and uploaded: 1422628.3.fna
# [5482/5770] ✅ Downloaded and uploaded: 1422629.3.fna
# [5483/5770] ✅ Downloaded and uploaded: 1422631.3.fna
# [5484/5770] ✅ Downloaded and uploaded: 1422630.3.fna
# [5485/5770] ✅ Downloaded and uploaded: 1422632.3.fna
# [5486/5770] ✅ Downloaded and uploaded: 1422635.3.fna
# [5487/5770] ✅ Downloaded and uploaded: 1422633.3.fna
# [5488/5770] ✅ Downloaded and uploaded: 1422636.3.fna
# [5489/5770] ✅ Downloaded and uploaded: 1422634.3.fna
# [5490/5770] ✅ Downloaded and uploaded: 1422637.3.fna
# [5491/5770] ✅ Downloaded and uploaded: 1422639.3.fna
# [5492/5770] ✅ Downloaded and uploaded: 1422638.3.fna
# [5493/5770] ✅ Downloaded and uploaded: 1422640.3.fna
# [5494/5770] ✅ Downloaded and uploaded: 1422641.3.fna
# [5495/5770] ✅ Downloaded and uploaded: 1422642.3.fna
# [5496/5770] ✅ Downloaded and uploaded: 1422643.3.fna
# [5497/5770] ✅ Downloaded and uploaded: 1422646.3.fna
# [5498/5770] ✅ Downloaded and uploaded: 1422645.3.fna
# [5499/5770] ✅ Downloaded and uploaded: 1422644.3.fna
# [5500/5770] ✅ Downloaded and uploaded: 1422647.3.fna
# [5501/5770] ✅ Downloaded and uploaded: 1422651.3.fna
# [5502/5770] ✅ Downloaded and uploaded: 1422649.3.fna
# [5503/5770] ✅ Downloaded and uploaded: 1422650.3.fna
# [5504/5770] ✅ Downloaded and uploaded: 1422648.3.fna
# [5505/5770] ✅ Downloaded and uploaded: 1422652.3.fna
# [5506/5770] ✅ Downloaded and uploaded: 1422656.3.fna
# [5507/5770] ✅ Downloaded and uploaded: 1422653.3.fna
# [5508/5770] ✅ Downloaded and uploaded: 1422654.3.fna
# [5509/5770] ✅ Downloaded and uploaded: 1422655.3.fna
# [5510/5770] ✅ Downloaded and uploaded: 1422657.3.fna
# [5511/5770] ✅ Downloaded and uploaded: 1422659.3.fna
# [5512/5770] ✅ Downloaded and uploaded: 1422661.3.fna
# [5513/5770] ✅ Downloaded and uploaded: 1422658.3.fna
# [5514/5770] ✅ Downloaded and uploaded: 1422662.3.fna
# [5515/5770] ✅ Downloaded and uploaded: 1422660.3.fna
# [5516/5770] ✅ Downloaded and uploaded: 1422664.3.fna
# [5517/5770] ✅ Downloaded and uploaded: 1422663.3.fna
# [5518/5770] ✅ Downloaded and uploaded: 1422665.3.fna
# [5519/5770] ✅ Downloaded and uploaded: 1422667.3.fna
# [5520/5770] ✅ Downloaded and uploaded: 1422666.3.fna
# [5521/5770] ✅ Downloaded and uploaded: 1422668.3.fna
# [5522/5770] ✅ Downloaded and uploaded: 1422669.3.fna
# [5523/5770] ✅ Downloaded and uploaded: 1422671.3.fna
# [5524/5770] ✅ Downloaded and uploaded: 1422670.3.fna
# [5525/5770] ✅ Downloaded and uploaded: 1422672.3.fna
# [5526/5770] ✅ Downloaded and uploaded: 1422673.3.fna
# [5527/5770] ✅ Downloaded and uploaded: 1422674.3.fna
# [5528/5770] ✅ Downloaded and uploaded: 1422677.3.fna
# [5529/5770] ✅ Downloaded and uploaded: 1422676.3.fna
# [5530/5770] ✅ Downloaded and uploaded: 1422675.3.fna
# [5531/5770] ✅ Downloaded and uploaded: 1422679.3.fna
# [5532/5770] ✅ Downloaded and uploaded: 1422678.3.fna
# [5533/5770] ✅ Downloaded and uploaded: 1422682.3.fna
# [5534/5770] ✅ Downloaded and uploaded: 1422680.3.fna
# [5535/5770] ✅ Downloaded and uploaded: 1422681.3.fna
# [5536/5770] ✅ Downloaded and uploaded: 1422683.3.fna
# [5537/5770] ✅ Downloaded and uploaded: 1422684.3.fna
# [5538/5770] ✅ Downloaded and uploaded: 1422685.3.fna
# [5539/5770] ✅ Downloaded and uploaded: 1422686.3.fna
# [5540/5770] ✅ Downloaded and uploaded: 1422687.3.fna
# [5541/5770] ✅ Downloaded and uploaded: 1422688.3.fna
# [5542/5770] ✅ Downloaded and uploaded: 1422689.3.fna
# [5543/5770] ✅ Downloaded and uploaded: 1422690.3.fna
# [5544/5770] ✅ Downloaded and uploaded: 1422692.3.fna
# [5545/5770] ✅ Downloaded and uploaded: 1422691.3.fna
# [5546/5770] ✅ Downloaded and uploaded: 1422695.3.fna
# [5547/5770] ✅ Downloaded and uploaded: 1422697.3.fna
# [5548/5770] ✅ Downloaded and uploaded: 1422693.3.fna
# [5549/5770] ✅ Downloaded and uploaded: 1422696.3.fna
# [5550/5770] ✅ Downloaded and uploaded: 1422694.3.fna
# [5551/5770] ✅ Downloaded and uploaded: 1422700.3.fna
# [5552/5770] ✅ Downloaded and uploaded: 1422698.3.fna
# [5553/5770] ✅ Downloaded and uploaded: 1422701.3.fna
# [5554/5770] ✅ Downloaded and uploaded: 1422702.3.fna
# [5555/5770] ✅ Downloaded and uploaded: 1422699.3.fna
# [5556/5770] ✅ Downloaded and uploaded: 1422706.3.fna
# [5557/5770] ✅ Downloaded and uploaded: 1422703.3.fna
# [5558/5770] ✅ Downloaded and uploaded: 1422705.3.fna
# [5559/5770] ✅ Downloaded and uploaded: 1422704.3.fna
# [5560/5770] ✅ Downloaded and uploaded: 1422707.3.fna
# [5561/5770] ✅ Downloaded and uploaded: 1422709.3.fna
# [5562/5770] ✅ Downloaded and uploaded: 1422712.3.fna
# [5563/5770] ✅ Downloaded and uploaded: 1422710.3.fna
# [5564/5770] ✅ Downloaded and uploaded: 1422708.3.fna
# [5565/5770] ✅ Downloaded and uploaded: 1422711.3.fna
# [5566/5770] ✅ Downloaded and uploaded: 1422716.3.fna
# [5567/5770] ✅ Downloaded and uploaded: 1422714.3.fna
# [5568/5770] ✅ Downloaded and uploaded: 1422715.3.fna
# [5569/5770] ✅ Downloaded and uploaded: 1422713.3.fna
# [5570/5770] ✅ Downloaded and uploaded: 1422717.3.fna
# [5571/5770] ✅ Downloaded and uploaded: 1422720.3.fna
# [5572/5770] ✅ Downloaded and uploaded: 1422721.3.fna
# [5573/5770] ✅ Downloaded and uploaded: 1422718.3.fna
# [5574/5770] ✅ Downloaded and uploaded: 1422719.3.fna
# [5575/5770] ✅ Downloaded and uploaded: 1422722.3.fna
# [5576/5770] ✅ Downloaded and uploaded: 1422723.3.fna
# [5577/5770] ✅ Downloaded and uploaded: 1422724.3.fna
# [5578/5770] ✅ Downloaded and uploaded: 1422725.3.fna
# [5579/5770] ✅ Downloaded and uploaded: 1422726.3.fna
# [5580/5770] ✅ Downloaded and uploaded: 1422727.3.fna
# [5581/5770] ✅ Downloaded and uploaded: 1422729.3.fna
# [5582/5770] ✅ Downloaded and uploaded: 1422731.3.fna
# [5583/5770] ✅ Downloaded and uploaded: 1422730.3.fna
# [5584/5770] ✅ Downloaded and uploaded: 1422728.3.fna
# [5585/5770] ✅ Downloaded and uploaded: 1422732.3.fna
# [5586/5770] ✅ Downloaded and uploaded: 1422733.3.fna
# [5587/5770] ✅ Downloaded and uploaded: 1422736.3.fna
# [5588/5770] ✅ Downloaded and uploaded: 1422735.3.fna
# [5589/5770] ✅ Downloaded and uploaded: 1422737.3.fna
# [5590/5770] ✅ Downloaded and uploaded: 1422734.3.fna
# [5591/5770] ✅ Downloaded and uploaded: 1422738.3.fna
# [5592/5770] ✅ Downloaded and uploaded: 1422739.3.fna
# [5593/5770] ✅ Downloaded and uploaded: 1422742.3.fna
# [5594/5770] ✅ Downloaded and uploaded: 1422741.3.fna
# [5595/5770] ✅ Downloaded and uploaded: 1422740.3.fna
# [5596/5770] ✅ Downloaded and uploaded: 1422745.3.fna
# [5597/5770] ✅ Downloaded and uploaded: 1422744.3.fna
# [5598/5770] ✅ Downloaded and uploaded: 1422746.3.fna
# [5599/5770] ✅ Downloaded and uploaded: 1422743.3.fna
# [5600/5770] ✅ Downloaded and uploaded: 1422747.3.fna
# [5601/5770] ✅ Downloaded and uploaded: 1422748.3.fna
# [5602/5770] ✅ Downloaded and uploaded: 1422751.3.fna
# [5603/5770] ✅ Downloaded and uploaded: 1422752.3.fna
# [5604/5770] ✅ Downloaded and uploaded: 1422749.3.fna
# [5605/5770] ✅ Downloaded and uploaded: 1422750.3.fna
# [5606/5770] ✅ Downloaded and uploaded: 1422753.3.fna
# [5607/5770] ✅ Downloaded and uploaded: 1422755.3.fna
# [5608/5770] ✅ Downloaded and uploaded: 1422756.3.fna
# [5609/5770] ✅ Downloaded and uploaded: 1422757.3.fna
# [5610/5770] ✅ Downloaded and uploaded: 1422754.3.fna
# [5611/5770] ✅ Downloaded and uploaded: 1422758.3.fna
# [5612/5770] ✅ Downloaded and uploaded: 1422760.3.fna
# [5613/5770] ✅ Downloaded and uploaded: 1422761.3.fna
# [5614/5770] ✅ Downloaded and uploaded: 1422759.3.fna
# [5615/5770] ✅ Downloaded and uploaded: 1422762.3.fna
# [5616/5770] ✅ Downloaded and uploaded: 1422763.3.fna
# [5617/5770] ✅ Downloaded and uploaded: 1422765.3.fna
# [5618/5770] ✅ Downloaded and uploaded: 1422766.3.fna
# [5619/5770] ✅ Downloaded and uploaded: 1422767.3.fna
# [5620/5770] ✅ Downloaded and uploaded: 1422764.3.fna
# [5621/5770] ✅ Downloaded and uploaded: 1422770.3.fna
# [5622/5770] ✅ Downloaded and uploaded: 1422768.3.fna
# [5623/5770] ✅ Downloaded and uploaded: 1422769.3.fna
# [5624/5770] ✅ Downloaded and uploaded: 1422771.3.fna
# [5625/5770] ✅ Downloaded and uploaded: 1422772.3.fna
# [5626/5770] ✅ Downloaded and uploaded: 1422775.3.fna
# [5627/5770] ✅ Downloaded and uploaded: 1422773.3.fna
# [5628/5770] ✅ Downloaded and uploaded: 1422777.3.fna
# [5629/5770] ✅ Downloaded and uploaded: 1422778.3.fna
# [5630/5770] ✅ Downloaded and uploaded: 1422774.3.fna
# [5631/5770] ✅ Downloaded and uploaded: 1422779.3.fna
# [5632/5770] ✅ Downloaded and uploaded: 1422780.3.fna
# [5633/5770] ✅ Downloaded and uploaded: 1422781.3.fna
# [5634/5770] ✅ Downloaded and uploaded: 1422783.3.fna
# [5635/5770] ✅ Downloaded and uploaded: 1422782.3.fna
# [5636/5770] ✅ Downloaded and uploaded: 1422787.3.fna
# [5637/5770] ✅ Downloaded and uploaded: 1422785.3.fna
# [5638/5770] ✅ Downloaded and uploaded: 1422786.3.fna
# [5639/5770] ✅ Downloaded and uploaded: 1422788.3.fna
# [5640/5770] ✅ Downloaded and uploaded: 1422784.3.fna
# [5641/5770] ✅ Downloaded and uploaded: 1422791.3.fna
# [5642/5770] ✅ Downloaded and uploaded: 1422793.3.fna
# [5643/5770] ✅ Downloaded and uploaded: 1422790.3.fna
# [5644/5770] ✅ Downloaded and uploaded: 1422789.3.fna
# [5645/5770] ✅ Downloaded and uploaded: 1422792.3.fna
# [5646/5770] ✅ Downloaded and uploaded: 1422795.3.fna
# [5647/5770] ✅ Downloaded and uploaded: 1422794.3.fna
# [5648/5770] ✅ Downloaded and uploaded: 1422796.3.fna
# [5649/5770] ✅ Downloaded and uploaded: 1422798.3.fna
# [5650/5770] ✅ Downloaded and uploaded: 1422797.3.fna
# [5651/5770] ✅ Downloaded and uploaded: 1422802.3.fna
# [5652/5770] ✅ Downloaded and uploaded: 1422799.3.fna
# [5653/5770] ✅ Downloaded and uploaded: 1422801.3.fna
# [5654/5770] ✅ Downloaded and uploaded: 1422803.3.fna
# [5655/5770] ✅ Downloaded and uploaded: 1422800.3.fna
# [5656/5770] ✅ Downloaded and uploaded: 1422805.3.fna
# [5657/5770] ✅ Downloaded and uploaded: 1422804.3.fna
# [5658/5770] ✅ Downloaded and uploaded: 1422806.3.fna
# [5659/5770] ✅ Downloaded and uploaded: 1422807.3.fna
# [5660/5770] ✅ Downloaded and uploaded: 1422809.3.fna
# [5661/5770] ✅ Downloaded and uploaded: 1422813.3.fna
# [5662/5770] ✅ Downloaded and uploaded: 1422810.3.fna
# [5663/5770] ✅ Downloaded and uploaded: 1422812.3.fna
# [5664/5770] ✅ Downloaded and uploaded: 426430.24.fna
# [5665/5770] ✅ Downloaded and uploaded: 46170.1112.fna
# [5666/5770] ✅ Downloaded and uploaded: 46170.1114.fna
# [5667/5770] ✅ Downloaded and uploaded: 46170.1115.fna
# [5668/5770] ✅ Downloaded and uploaded: 46170.1113.fna
# [5669/5770] ✅ Downloaded and uploaded: 46170.1116.fna
# [5670/5770] ✅ Downloaded and uploaded: 46170.1117.fna
# [5671/5770] ✅ Downloaded and uploaded: 46170.1118.fna
# [5672/5770] ✅ Downloaded and uploaded: 46170.112.fna
# [5673/5770] ✅ Downloaded and uploaded: 46170.1119.fna
# [5674/5770] ✅ Downloaded and uploaded: 46170.1121.fna
# [5675/5770] ✅ Downloaded and uploaded: 46170.1122.fna
# [5676/5770] ✅ Downloaded and uploaded: 46170.1123.fna
# [5677/5770] ✅ Downloaded and uploaded: 46170.1126.fna
# [5678/5770] ✅ Downloaded and uploaded: 46170.1125.fna
# [5679/5770] ✅ Downloaded and uploaded: 46170.1124.fna
# [5680/5770] ✅ Downloaded and uploaded: 46170.1127.fna
# [5681/5770] ✅ Downloaded and uploaded: 46170.1129.fna
# [5682/5770] ✅ Downloaded and uploaded: 46170.113.fna
# [5683/5770] ✅ Downloaded and uploaded: 46170.1131.fna
# [5684/5770] ✅ Downloaded and uploaded: 46170.1128.fna
# [5685/5770] ✅ Downloaded and uploaded: 46170.1132.fna
# [5686/5770] ✅ Downloaded and uploaded: 46170.1133.fna
# [5687/5770] ✅ Downloaded and uploaded: 46170.1136.fna
# [5688/5770] ✅ Downloaded and uploaded: 46170.1134.fna
# [5689/5770] ✅ Downloaded and uploaded: 46170.1135.fna
# [5690/5770] ✅ Downloaded and uploaded: 46170.1137.fna
# [5691/5770] ✅ Downloaded and uploaded: 46170.1139.fna
# [5692/5770] ✅ Downloaded and uploaded: 46170.1138.fna
# [5693/5770] ✅ Downloaded and uploaded: 46170.114.fna
# [5694/5770] ✅ Downloaded and uploaded: 46170.1141.fna
# [5695/5770] ✅ Downloaded and uploaded: 46170.1142.fna
# [5696/5770] ✅ Downloaded and uploaded: 46170.1143.fna
# [5697/5770] ✅ Downloaded and uploaded: 46170.1145.fna
# [5698/5770] ✅ Downloaded and uploaded: 46170.1146.fna
# [5699/5770] ✅ Downloaded and uploaded: 46170.1144.fna
# [5700/5770] ✅ Downloaded and uploaded: 46170.1147.fna
# [5701/5770] ✅ Downloaded and uploaded: 46170.1151.fna
# [5702/5770] ✅ Downloaded and uploaded: 46170.1148.fna
# [5703/5770] ✅ Downloaded and uploaded: 46170.1149.fna
# [5704/5770] ✅ Downloaded and uploaded: 46170.115.fna
# [5705/5770] ✅ Downloaded and uploaded: 46170.1152.fna
# [5706/5770] ✅ Downloaded and uploaded: 46170.1153.fna
# [5707/5770] ✅ Downloaded and uploaded: 46170.1155.fna
# [5708/5770] ✅ Downloaded and uploaded: 46170.1156.fna
# [5709/5770] ✅ Downloaded and uploaded: 46170.1157.fna
# [5710/5770] ✅ Downloaded and uploaded: 46170.1154.fna
# [5711/5770] ✅ Downloaded and uploaded: 46170.1162.fna
# [5712/5770] ✅ Downloaded and uploaded: 46170.1159.fna
# [5713/5770] ✅ Downloaded and uploaded: 46170.116.fna
# [5714/5770] ✅ Downloaded and uploaded: 46170.1161.fna
# [5715/5770] ✅ Downloaded and uploaded: 46170.1158.fna
# [5716/5770] ✅ Downloaded and uploaded: 46170.1163.fna
# [5717/5770] ✅ Downloaded and uploaded: 46170.1164.fna
# [5718/5770] ✅ Downloaded and uploaded: 46170.1165.fna
# [5719/5770] ✅ Downloaded and uploaded: 46170.1167.fna
# [5720/5770] ✅ Downloaded and uploaded: 46170.1166.fna
# [5721/5770] ✅ Downloaded and uploaded: 46170.1169.fna
# [5722/5770] ✅ Downloaded and uploaded: 46170.117.fna
# [5723/5770] ✅ Downloaded and uploaded: 46170.1172.fna
# [5724/5770] ✅ Downloaded and uploaded: 46170.1168.fna
# [5725/5770] ✅ Downloaded and uploaded: 46170.1171.fna
# [5726/5770] ✅ Downloaded and uploaded: 46170.1177.fna
# [5727/5770] ✅ Downloaded and uploaded: 46170.1174.fna
# [5728/5770] ✅ Downloaded and uploaded: 46170.1175.fna
# [5729/5770] ✅ Downloaded and uploaded: 46170.1173.fna
# [5730/5770] ✅ Downloaded and uploaded: 46170.1176.fna
# [5731/5770] ✅ Downloaded and uploaded: 46170.1179.fna
# [5732/5770] ✅ Downloaded and uploaded: 46170.1178.fna
# [5733/5770] ✅ Downloaded and uploaded: 46170.118.fna
# [5734/5770] ✅ Downloaded and uploaded: 46170.1181.fna
# [5735/5770] ✅ Downloaded and uploaded: 46170.1182.fna
# [5736/5770] ✅ Downloaded and uploaded: 46170.1184.fna
# [5737/5770] ✅ Downloaded and uploaded: 46170.1185.fna
# [5738/5770] ✅ Downloaded and uploaded: 46170.1186.fna
# [5739/5770] ✅ Downloaded and uploaded: 46170.1183.fna
# [5740/5770] ✅ Downloaded and uploaded: 46170.1187.fna
# [5741/5770] ✅ Downloaded and uploaded: 46170.1192.fna
# [5742/5770] ✅ Downloaded and uploaded: 46170.119.fna
# [5743/5770] ✅ Downloaded and uploaded: 46170.1189.fna
# [5744/5770] ✅ Downloaded and uploaded: 46170.1188.fna
# [5745/5770] ✅ Downloaded and uploaded: 46170.1191.fna
# [5746/5770] ✅ Downloaded and uploaded: 46170.1193.fna
# [5747/5770] ✅ Downloaded and uploaded: 46170.1196.fna
# [5748/5770] ✅ Downloaded and uploaded: 46170.1195.fna
# [5749/5770] ✅ Downloaded and uploaded: 46170.1197.fna
# [5750/5770] ✅ Downloaded and uploaded: 46170.1194.fna
# [5751/5770] ✅ Downloaded and uploaded: 46170.176.fna
# [5752/5770] ✅ Downloaded and uploaded: 46170.174.fna
# [5753/5770] ✅ Downloaded and uploaded: 46170.175.fna
# [5754/5770] ✅ Downloaded and uploaded: 46170.178.fna
# [5755/5770] ✅ Downloaded and uploaded: 46170.179.fna
# [5756/5770] ❌ Failed for 72759.2: <urlopen error 550 genomes/72759.2: No such file or directory>
# [5757/5770] ❌ Failed for 46170.18: <urlopen error 550 genomes/46170.18: No such file or directory>
# [5758/5770] ✅ Downloaded and uploaded: 561307.24.fna
# [5759/5770] ✅ Downloaded and uploaded: 867914.5.fna
# [5760/5770] ✅ Downloaded and uploaded: 904313.3.fna
# [5761/5770] ✅ Downloaded and uploaded: 904779.3.fna
# [5762/5770] ✅ Downloaded and uploaded: 904782.3.fna
# [5763/5770] ✅ Downloaded and uploaded: 904785.3.fna
# [5764/5770] ✅ Downloaded and uploaded: 904784.3.fna
# [5765/5770] ✅ Downloaded and uploaded: 904786.3.fna
# [5766/5770] ✅ Downloaded and uploaded: 904792.3.fna
# [5767/5770] ✅ Downloaded and uploaded: 904787.3.fna
# [5768/5770] ✅ Downloaded and uploaded: 904800.3.fna
# [5769/5770] ✅ Downloaded and uploaded: 904799.3.fna
# [5770/5770] ✅ Downloaded and uploaded: 904801.3.fna

# %% [markdown]
# # Klebsiella pneumoniae

# %%
import os
import urllib.request
import pandas as pd
from google.colab import drive
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed

# 🔧 CONFIGURATION
csv_file_path = "001222_2.xlsx"  # Change to your file name
column_name = "Genome_ID"
local_download_dir = "/content/genome_fna_files"
drive_mount_path = "/content/drive"
drive_target_dir = os.path.join(drive_mount_path, "My Drive/MRSA datasets/Datasets/Klebsiella pneumoniae/PATRIC_klebsiella")
MAX_WORKERS = 5  # 🔁 Number of parallel downloads (adjust based on performance)

# 📂 Mount Google Drive
drive.mount(drive_mount_path)
os.makedirs(local_download_dir, exist_ok=True)
os.makedirs(drive_target_dir, exist_ok=True)

# 📄 Load genome IDs
df = pd.read_excel(csv_file_path)
genome_ids = df[column_name].dropna().astype(str).unique()
print(f"🔍 Found {len(genome_ids)} genome IDs to process.")

# 🔁 Function for downloading and uploading
def download_and_upload(genome_id):
    file_name = f"{genome_id}.fna"
    ftp_url = f"ftp://ftp.patricbrc.org/genomes/{genome_id}/{file_name}"
    local_path = os.path.join(local_download_dir, file_name)
    drive_path = os.path.join(drive_target_dir, file_name)

    if os.path.exists(drive_path):
        return f"☁️ Skipping {file_name} — already in Drive."

    try:
        # ⬇️ Download
        urllib.request.urlretrieve(ftp_url, local_path)

        # ☁️ Copy to Drive
        shutil.copy(local_path, drive_path)

        # 🧹 Remove local file
        os.remove(local_path)

        return f"✅ Downloaded and uploaded: {file_name}"
    except Exception as e:
        return f"❌ Failed for {genome_id}: {e}"

# 🚀 Run downloads concurrently
results = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_id = {executor.submit(download_and_upload, gid): gid for gid in genome_ids}
    for i, future in enumerate(as_completed(future_to_id), 1):
        result = future.result()
        print(f"[{i}/{len(genome_ids)}] {result}")

# 🔄 Ensure everything is synced
drive.flush_and_unmount()

# %% [markdown]
# # zip file

# %%
import zipfile
import os
from google.colab import drive

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define the path to your zip file in Drive
zip_path = '/content/drive/MyDrive/MRSA datasets/Datasets_fcgr.zip'  # 🔁 Update this path
extract_dir = '/content/drive/MyDrive/Dataset_fcgr/'  # 🔁 Update this path

# Step 3: Create the target extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Step 4: Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f'✅ Zip file extracted to: {extract_dir}')
# Out:
# Mounted at /content/drive
# ✅ Zip file extracted to: /content/drive/MyDrive/Dataset_fcgr/
